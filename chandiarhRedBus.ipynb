# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('https://www.redbus.in/online-booking/chandigarh-transport-undertaking-ctu')
time.sleep(2)  # Let the page load

body = driver.find_element(By.TAG_NAME, "body")
telangana_buses_list=[]
telangana_buses_links=[] 

for page_num in range(1, 4):  # Loop over pages (or scroll actions)
    # Get all elements with class 'route'
    result1 = driver.find_elements(By.CSS_SELECTOR, "a[class='route']")
    
    # Print the text of each element found
    for element in result1:
        telangana_buses_list.append(element.text)
        telangana_buses_links.append(element.get_attribute('href'))
    
    # Scroll down the page
    body.send_keys(Keys.PAGE_DOWN)
    time.sleep(2)  # Give some time for new elements to load
    
    # Find an element matching the XPATH and click (if needed)
    result = driver.find_elements(By.XPATH, f"//div[contains(text(),'{page_num+1}')]")
    #print(result)
    if result:
        result[0].click()  # Click the first element found with matching XPATH

#driver.quit()  # Close the browser after task completion

# %%
for i in telangana_buses_links:
    print(i)
# Out:
# https://www.redbus.in/bus-tickets/yamuna-nagar-to-chandigarh
# https://www.redbus.in/bus-tickets/chandigarh-to-delhi
# https://www.redbus.in/bus-tickets/delhi-to-chandigarh
# https://www.redbus.in/bus-tickets/ludhiana-to-chandigarh
# https://www.redbus.in/bus-tickets/chandigarh-to-vrindavan
# https://www.redbus.in/bus-tickets/chandigarh-to-yamuna-nagar
# https://www.redbus.in/bus-tickets/vrindavan-to-chandigarh
# https://www.redbus.in/bus-tickets/dehradun-to-chandigarh
# https://www.redbus.in/bus-tickets/hamirpur-himachal-pradesh-to-chandigarh
# https://www.redbus.in/bus-tickets/chandigarh-to-ludhiana
# https://www.redbus.in/bus-tickets/chandigarh-to-dehradun
# https://www.redbus.in/bus-tickets/sujanpur-to-chandigarh
# https://www.redbus.in/bus-tickets/chandigarh-to-shimla
# https://www.redbus.in/bus-tickets/chandigarh-to-hamirpur-himachal-pradesh
# https://www.redbus.in/bus-tickets/dinanagar-punjab-to-chandigarh
# https://www.redbus.in/bus-tickets/chandigarh-to-pathankot
# https://www.redbus.in/bus-tickets/talwara-to-chandigarh
# https://www.redbus.in/bus-tickets/shimla-to-chandigarh
# https://www.redbus.in/bus-tickets/chandigarh-to-dinanagar-punjab
# https://www.redbus.in/bus-tickets/chandigarh-to-dharamshala
# https://www.redbus.in/bus-tickets/chandigarh-to-sujanpur
# https://www.redbus.in/bus-tickets/rohtak-to-chandigarh
# https://www.redbus.in/bus-tickets/pathankot-to-chandigarh
# https://www.redbus.in/bus-tickets/agra-to-chandigarh
# https://www.redbus.in/bus-tickets/chandigarh-to-haridwar
# https://www.redbus.in/bus-tickets/amritsar-to-chandigarh
# https://www.redbus.in/bus-tickets/dharamshala-to-chandigarh
# https://www.redbus.in/bus-tickets/chandigarh-to-talwara

# %%
for i in telangana_buses_list:
    print(i)
# Out:
# Yamuna Nagar to Chandigarh
# Chandigarh to Delhi
# Delhi to Chandigarh
# Ludhiana to Chandigarh
# Chandigarh to Vrindavan
# Chandigarh to Yamuna Nagar
# Vrindavan to Chandigarh
# Dehradun to Chandigarh
# Hamirpur (Himachal Pradesh) to Chandigarh
# Chandigarh to Ludhiana
# Chandigarh to Dehradun
# Sujanpur (himachal pradesh) to Chandigarh
# Chandigarh to Shimla
# Chandigarh to Hamirpur (Himachal Pradesh)
# Dinanagar (punjab) to Chandigarh
# Chandigarh to Pathankot
# Talwara to Chandigarh
# Shimla to Chandigarh
# Chandigarh to Dinanagar (punjab)
# Chandigarh to Dharamshala (Himachal Pradesh)
# Chandigarh to Sujanpur (himachal pradesh)
# Rohtak to Chandigarh
# Pathankot to Chandigarh
# Agra to Chandigarh
# Chandigarh to Haridwar
# Amritsar to Chandigarh
# Dharamshala (Himachal Pradesh) to Chandigarh
# Chandigarh to Talwara

# %%
buses_list=[]
bus_type_list=[]
departing_time_list=[]
reaching_time_list=[]
duration_list=[]
star_rating_list=[]
price_list=[]
seats_available_list=[]
route_name=[]
route_link=[]

# %%
 # Let the page load
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('https://www.redbus.in/bus-tickets/delhi-to-chandigarh?fromCityId=733&toCityId=833&fromCityName=Delhi&toCityName=Chandigarh&busType=Any&onward=22-Nov-2024')
time.sleep(2)  # Let the page load

body = driver.find_element(By.TAG_NAME, "body")
hide_details_TS=driver.find_elements(By.XPATH, "//div[@class='button']")
if hide_details_TS:
    hide_details_TS[0].click()
for i in range(40):
    buses_list_result = driver.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type_result = driver.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    departing_time_result = driver.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    reaching_time_result = driver.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    duration_list_result = driver.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")
    star_rating_result = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
    price_result = driver.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats_available_result = driver.find_elements(By.XPATH, "//div[@class='seat-left m-top-30']")
    body.send_keys(Keys.PAGE_DOWN)

for i in buses_list_result:
    buses_list.append(i.text)
for i in bus_type_result:
    bus_type_list.append(i.text)
for i in departing_time_result:
    departing_time_list.append(i.text)
for i in reaching_time_result:
    reaching_time_list.append(i.text)
for i in duration_list_result:
    duration_list.append(i.text)
for i in star_rating_result:
    star_rating_list.append(i.text)
for i in price_result:
    price_list.append(i.text)
for i in seats_available_result:
    seats_available_list.append(i.text)

# %%
no_of_buses=len(buses_list)
no_of_buses
# Out:
# 101

# %%
for i in range(no_of_buses):
    route_name.append("Delhi to Chandigarh")
    route_link.append("https://www.redbus.in/bus-tickets/delhi-to-chandigarh")

# %%
 # Let the page load
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('https://www.redbus.in/bus-tickets/chandigarh-to-delhi?fromCityId=833&toCityId=733&fromCityName=Chandigarh&toCityName=Delhi&busType=Any&onward=22-Nov-2024')
time.sleep(2)  # Let the page load

body = driver.find_element(By.TAG_NAME, "body")
hide_details_TS=driver.find_elements(By.XPATH, "//div[@class='button']")
if hide_details_TS:
    hide_details_TS[0].click()
for i in range(40):
    buses_list_result = driver.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type_result = driver.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    departing_time_result = driver.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    reaching_time_result = driver.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    duration_list_result = driver.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")
    star_rating_result = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
    price_result = driver.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats_available_result = driver.find_elements(By.XPATH, "//div[@class='seat-left m-top-30']")
    body.send_keys(Keys.PAGE_DOWN)
count=0
for i in buses_list_result:
    buses_list.append(i.text)
    count+=1
for i in bus_type_result:
    bus_type_list.append(i.text)
for i in departing_time_result:
    departing_time_list.append(i.text)
for i in reaching_time_result:
    reaching_time_list.append(i.text)
for i in duration_list_result:
    duration_list.append(i.text)
for i in star_rating_result:
    star_rating_list.append(i.text)
for i in price_result:
    price_list.append(i.text)
for i in seats_available_result:
    seats_available_list.append(i.text)

# %%
for i in range(count):
    route_name.append("Chandigarh to Delhi")
    route_link.append("https://www.redbus.in/bus-tickets/chandigarh-to-delhi")

# %%
 # Let the page load
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('https://www.redbus.in/bus-tickets/yamuna-nagar-to-chandigarh?fromCityId=82156&toCityId=833&fromCityName=Yamuna%20Nagar&toCityName=Chandigarh&busType=Any&srcCountry=null&destCountry=null&onward=22-Nov-2024')
time.sleep(2)  # Let the page load

body = driver.find_element(By.TAG_NAME, "body")
hide_details_TS=driver.find_elements(By.XPATH, "//div[@class='button']")
if hide_details_TS:
    hide_details_TS[0].click()
for i in range(40):
    buses_list_result = driver.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type_result = driver.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    departing_time_result = driver.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    reaching_time_result = driver.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    duration_list_result = driver.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")
    star_rating_result = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
    price_result = driver.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats_available_result = driver.find_elements(By.XPATH, "//div[@class='seat-left m-top-30']")
    body.send_keys(Keys.PAGE_DOWN)
count=0
for i in buses_list_result:
    buses_list.append(i.text)
    count+=1
for i in bus_type_result:
    bus_type_list.append(i.text)
for i in departing_time_result:
    departing_time_list.append(i.text)
for i in reaching_time_result:
    reaching_time_list.append(i.text)
for i in duration_list_result:
    duration_list.append(i.text)
for i in star_rating_result:
    star_rating_list.append(i.text)
for i in price_result:
    price_list.append(i.text)
for i in seats_available_result:
    seats_available_list.append(i.text)

# %%
for i in range(count):
    route_name.append("Yamuna Nagar to Chandigarh")
    route_link.append("https://www.redbus.in/bus-tickets/yamuna-nagar-to-chandigarh")

# %%
 # Let the page load
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('https://www.redbus.in/bus-tickets/chandigarh-to-yamuna-nagar?fromCityId=833&toCityId=82156&fromCityName=Chandigarh&toCityName=Yamuna%20Nagar&busType=Any&onward=22-Nov-2024')
time.sleep(2)  # Let the page load

body = driver.find_element(By.TAG_NAME, "body")
hide_details_TS=driver.find_elements(By.XPATH, "//div[@class='button']")
if hide_details_TS:
    hide_details_TS[0].click()
for i in range(40):
    buses_list_result = driver.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type_result = driver.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    departing_time_result = driver.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    reaching_time_result = driver.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    duration_list_result = driver.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")
    star_rating_result = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
    price_result = driver.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats_available_result = driver.find_elements(By.XPATH, "//div[@class='seat-left m-top-30']")
    body.send_keys(Keys.PAGE_DOWN)
count=0
for i in buses_list_result:
    buses_list.append(i.text)
    count+=1
for i in bus_type_result:
    bus_type_list.append(i.text)
for i in departing_time_result:
    departing_time_list.append(i.text)
for i in reaching_time_result:
    reaching_time_list.append(i.text)
for i in duration_list_result:
    duration_list.append(i.text)
for i in star_rating_result:
    star_rating_list.append(i.text)
for i in price_result:
    price_list.append(i.text)
for i in seats_available_result:
    seats_available_list.append(i.text)

# %%
for i in range(count):
    route_name.append("Ludhiana to Chandigarh")
    route_link.append("https://www.redbus.in/bus-tickets/ludhiana-to-chandigarh")

# %%
 # Let the page load
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('https://www.redbus.in/bus-tickets/chandigarh-to-ludhiana?fromCityId=833&toCityId=736&fromCityName=Chandigarh&toCityName=Ludhiana&busType=Any&onward=22-Nov-2024')
time.sleep(2)  # Let the page load

body = driver.find_element(By.TAG_NAME, "body")
hide_details_TS=driver.find_elements(By.XPATH, "//div[@class='button']")
if hide_details_TS:
    hide_details_TS[0].click()
for i in range(40):
    buses_list_result = driver.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type_result = driver.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    departing_time_result = driver.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    reaching_time_result = driver.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    duration_list_result = driver.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")
    star_rating_result = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
    price_result = driver.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats_available_result = driver.find_elements(By.XPATH, "//div[@class='seat-left m-top-30']")
    body.send_keys(Keys.PAGE_DOWN)
count=0
for i in buses_list_result:
    buses_list.append(i.text)
    count+=1
for i in bus_type_result:
    bus_type_list.append(i.text)
for i in departing_time_result:
    departing_time_list.append(i.text)
for i in reaching_time_result:
    reaching_time_list.append(i.text)
for i in duration_list_result:
    duration_list.append(i.text)
for i in star_rating_result:
    star_rating_list.append(i.text)
for i in price_result:
    price_list.append(i.text)
for i in seats_available_result:
    seats_available_list.append(i.text)

# %%
for i in range(count):
    route_name.append("Chandigarh to Yamuna Nagar")
    route_link.append("https://www.redbus.in/bus-tickets/chandigarh-to-yamunanagar")

# %%
 # Let the page load
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('https://www.redbus.in/bus-tickets/chandigarh-to-dehradun?fromCityId=833&toCityId=777&fromCityName=Chandigarh&toCityName=Dehradun&busType=Any&onward=22-Nov-2024')
time.sleep(2)  # Let the page load

body = driver.find_element(By.TAG_NAME, "body")
hide_details_TS=driver.find_elements(By.XPATH, "//div[@class='button']")
if hide_details_TS:
    hide_details_TS[0].click()
for i in range(40):
    buses_list_result = driver.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type_result = driver.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    departing_time_result = driver.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    reaching_time_result = driver.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    duration_list_result = driver.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")
    star_rating_result = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
    price_result = driver.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats_available_result = driver.find_elements(By.XPATH, "//div[@class='seat-left m-top-30']")
    body.send_keys(Keys.PAGE_DOWN)
count=0
for i in buses_list_result:
    buses_list.append(i.text)
    count+=1
for i in bus_type_result:
    bus_type_list.append(i.text)
for i in departing_time_result:
    departing_time_list.append(i.text)
for i in reaching_time_result:
    reaching_time_list.append(i.text)
for i in duration_list_result:
    duration_list.append(i.text)
for i in star_rating_result:
    star_rating_list.append(i.text)
for i in price_result:
    price_list.append(i.text)
for i in seats_available_result:
    seats_available_list.append(i.text)

# %%
for i in range(count):
    route_name.append("Chandigarh to Hamirpur (Himachal Pradesh)")
    route_link.append("https://www.redbus.in/bus-tickets/chandigarh-to-hamirpur-himachal-pradesh")

# %%
min_value=min(len(buses_list),len(bus_type_list),len(departing_time_list),len(reaching_time_list),len(duration_list),len(star_rating_list),len(price_list),len(seats_available_list),len(route_name),len(route_link))
print(min_value)
# Out:
# 68

# %%
busname=[]
bustype=[]
departing_time=[]
duration=[]
reaching_time=[]
star_rating=[]
price=[]
seats_available=[]
route_link1=[]
route_name1=[]
for i in range(1,min_value):
    busname.append(buses_list[i])
    bustype.append(bus_type_list[i])
    departing_time.append(departing_time_list[i])
    duration.append(duration_list[i])
    reaching_time.append(reaching_time_list[i])
    star_rating.append(star_rating_list[i])
    price.append(price_list[i])
    seats_available.append(seats_available_list[i])
    route_link1.append(route_link[i])
    route_name1.append(route_name[i])

# %%
import pandas as pd

# Dictionary with data
data = {
    'route_name': route_name1,
    'route_link': route_link1,
    'busname':busname,
    'bustype':bustype,
    'duparting_time': departing_time,
    'duration':duration,
    'reaching_time': reaching_time,
    'star_rating': star_rating,
    'Price': price,
    'Seats_Available': seats_available
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Add automated ID column
df['ID'] = range(1, len(df) + 1)

print(df)
# Out:
#              route_name                                         route_link  \
# 0   Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
# 1   Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
# 2   Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
# 3   Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
# 4   Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
# ..                  ...                                                ...
# 62  Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
# 63  Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
# 64  Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
# 65  Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
# 66  Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
#
#                             busname                                bustype  \
# 0                        HRTC - 505             Ordinary 3+2 Non AC Seater
# 1                          HRTC - 6     Himsuta AC Seater Volvo/Scania 2+2
# 2                        HRTC - 533             Ordinary 3+2 Non AC Seater
# 3                        HRTC - 592                    A/C Executive (2+3)
# 4                        HRTC - 513             Ordinary 3+2 Non AC Seater
# ..                              ...                                    ...
# 62                Lucky Bus Service                Volvo A/C Sleeper (2+2)
# 63                          FlixBus          Bharat Benz A/C Sleeper (2+1)
# 64           Vijay Tour and Travels  Bharat Benz A/C Seater /Sleeper (2+1)
# 65  Indo Canadian Transport Company        Mercedes A/C Semi Sleeper (2+2)
# 66  Indo Canadian Transport Company        Mercedes A/C Semi Sleeper (2+2)
#
#    duparting_time duration reaching_time star_rating       Price  \
# 0           06:40  05h 40m         12:20         3.3     INR 275
# 1           06:45  04h 15m         11:00         3.6     INR 543
# 2           07:20  05h 10m         12:30         3.1     INR 290
# 3           08:05  06h 00m         14:05         2.2     INR 400
# 4           10:30  04h 30m         15:00         1.7     INR 290
# ..            ...      ...           ...         ...         ...
# 62          19:30  06h 15m         01:45         3.8        1619
# 63          17:45  05h 20m         23:05         2.0  INR 943.75
# 64          02:40  05h 00m         07:40         1.5         450
# 65          02:00  08h 30m         10:30         4.2    INR 3300
# 66          02:00  08h 15m         10:15         4.2    INR 3300
#
#        Seats_Available  ID
# 0   38 Seats available   1
# 1   28 Seats available   2
# 2   36 Seats available   3
# 3   27 Seats available   4
# 4   37 Seats available   5
# ..                 ...  ..
# 62  44 Seats available  63
# 63  31 Seats available  64
# 64  41 Seats available  65
# 65  29 Seats available  66
# 66  44 Seats available  67
#
# [67 rows x 11 columns]

# %%
df.to_csv(r'C:/Users/Dell/OneDrive/Desktop/scraping/chandiarhbuses.csv', index=False)

# %%
import pandas as pd
read_value=pd.read_csv("C:/Users/Dell/OneDrive/Desktop/scraping/chandiarhbuses.csv")
read_value
# Out:
#              route_name                                         route_link  \
# 0   Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
# 1   Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
# 2   Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
# 3   Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
# 4   Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
# ..                  ...                                                ...
# 62  Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
# 63  Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
# 64  Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
# 65  Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
# 66  Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
#
#                             busname                                bustype  \
# 0                        HRTC - 505             Ordinary 3+2 Non AC Seater
# 1                          HRTC - 6     Himsuta AC Seater Volvo/Scania 2+2
# 2                        HRTC - 533             Ordinary 3+2 Non AC Seater
# 3                        HRTC - 592                    A/C Executive (2+3)
# 4                        HRTC - 513             Ordinary 3+2 Non AC Seater
# ..                              ...                                    ...
# 62                Lucky Bus Service                Volvo A/C Sleeper (2+2)
# 63                          FlixBus          Bharat Benz A/C Sleeper (2+1)
# 64           Vijay Tour and Travels  Bharat Benz A/C Seater /Sleeper (2+1)
# 65  Indo Canadian Transport Company        Mercedes A/C Semi Sleeper (2+2)
# 66  Indo Canadian Transport Company        Mercedes A/C Semi Sleeper (2+2)
#
#    duparting_time duration reaching_time  star_rating       Price  \
# 0           06:40  05h 40m         12:20          3.3     INR 275
# 1           06:45  04h 15m         11:00          3.6     INR 543
# 2           07:20  05h 10m         12:30          3.1     INR 290
# 3           08:05  06h 00m         14:05          2.2     INR 400
# 4           10:30  04h 30m         15:00          1.7     INR 290
# ..            ...      ...           ...          ...         ...
# 62          19:30  06h 15m         01:45          3.8        1619
# 63          17:45  05h 20m         23:05          2.0  INR 943.75
# 64          02:40  05h 00m         07:40          1.5         450
# 65          02:00  08h 30m         10:30          4.2    INR 3300
# 66          02:00  08h 15m         10:15          4.2    INR 3300
#
#        Seats_Available  ID
# 0   38 Seats available   1
# 1   28 Seats available   2
# 2   36 Seats available   3
# 3   27 Seats available   4
# 4   37 Seats available   5
# ..                 ...  ..
# 62  44 Seats available  63
# 63  31 Seats available  64
# 64  41 Seats available  65
# 65  29 Seats available  66
# 66  44 Seats available  67
#
# [67 rows x 11 columns]

# %%
read_value.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   route_name       67 non-null     object
#  1   route_link       67 non-null     object
#  2   busname          67 non-null     object
#  3   bustype          67 non-null     object
#  4   duparting_time   67 non-null     object
#  5   duration         67 non-null     object
#  6   reaching_time    67 non-null     object
#  7   star_rating      67 non-null     float64
#  8   Price            67 non-null     object
#  9   Seats_Available  67 non-null     object
#  10  ID               67 non-null     int64
# dtypes: float64(1), int64(1), object(9)
# memory usage: 5.9+ KB

# %%
for i in range(len(read_value.Price)):
  length_each_data=len(read_value.Price[i])
  if length_each_data>=7:
      read_value.Price[i]=read_value.Price[i][4:]
  elif length_each_data==3:
      read_value.Price[i]=read_value.Price[i]
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# ...
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i][4:]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\2458959016.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read_value.Price[i]=read_value.Price[i][4:]

# %%
read_value['Price'] = read_value['Price'].astype(float).astype(int)

# %%
type(read_value.Price[0])
# Out:
# numpy.int32

# %%
read_value.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   route_name       67 non-null     object
#  1   route_link       67 non-null     object
#  2   busname          67 non-null     object
#  3   bustype          67 non-null     object
#  4   duparting_time   67 non-null     object
#  5   duration         67 non-null     object
#  6   reaching_time    67 non-null     object
#  7   star_rating      67 non-null     float64
#  8   Price            67 non-null     int32
#  9   Seats_Available  67 non-null     object
#  10  ID               67 non-null     int64
# dtypes: float64(1), int32(1), int64(1), object(8)
# memory usage: 5.6+ KB

# %%
type(read_value.Seats_Available[0])
# Out:
# str

# %%
# Convert to string, extract digits, and convert to integer

read_value['Seats_Available'] = read_value['Seats_Available'].str.extract('(\d+)').astype(int)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41600\3569223348.py:3: SyntaxWarning: invalid escape sequence '\d'
#   read_value['Seats_Available'] = read_value['Seats_Available'].str.extract('(\d+)').astype(int)

# %%
read_value.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   route_name       67 non-null     object
#  1   route_link       67 non-null     object
#  2   busname          67 non-null     object
#  3   bustype          67 non-null     object
#  4   duparting_time   67 non-null     object
#  5   duration         67 non-null     object
#  6   reaching_time    67 non-null     object
#  7   star_rating      67 non-null     float64
#  8   Price            67 non-null     int32
#  9   Seats_Available  67 non-null     int32
#  10  ID               67 non-null     int64
# dtypes: float64(1), int32(2), int64(1), object(7)
# memory usage: 5.4+ KB

# %%
read_value['bustype']=read_value['bustype'].str.upper()
read_value
# Out:
#              route_name                                         route_link  \
# 0   Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
# 1   Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
# 2   Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
# 3   Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
# 4   Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
# ..                  ...                                                ...
# 62  Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
# 63  Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
# 64  Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
# 65  Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
# 66  Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
#
#                             busname                                bustype  \
# 0                        HRTC - 505             ORDINARY 3+2 NON AC SEATER
# 1                          HRTC - 6     HIMSUTA AC SEATER VOLVO/SCANIA 2+2
# 2                        HRTC - 533             ORDINARY 3+2 NON AC SEATER
# 3                        HRTC - 592                    A/C EXECUTIVE (2+3)
# 4                        HRTC - 513             ORDINARY 3+2 NON AC SEATER
# ..                              ...                                    ...
# 62                Lucky Bus Service                VOLVO A/C SLEEPER (2+2)
# 63                          FlixBus          BHARAT BENZ A/C SLEEPER (2+1)
# 64           Vijay Tour and Travels  BHARAT BENZ A/C SEATER /SLEEPER (2+1)
# 65  Indo Canadian Transport Company        MERCEDES A/C SEMI SLEEPER (2+2)
# 66  Indo Canadian Transport Company        MERCEDES A/C SEMI SLEEPER (2+2)
#
#    duparting_time duration reaching_time  star_rating  Price  Seats_Available  \
# 0           06:40  05h 40m         12:20          3.3    275               38
# 1           06:45  04h 15m         11:00          3.6    543               28
# 2           07:20  05h 10m         12:30          3.1    290               36
# 3           08:05  06h 00m         14:05          2.2    400               27
# 4           10:30  04h 30m         15:00          1.7    290               37
# ..            ...      ...           ...          ...    ...              ...
# 62          19:30  06h 15m         01:45          3.8   1619               44
# 63          17:45  05h 20m         23:05          2.0    943               31
# 64          02:40  05h 00m         07:40          1.5    450               41
# 65          02:00  08h 30m         10:30          4.2   3300               29
# 66          02:00  08h 15m         10:15          4.2   3300               44
#
#     ID
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# ..  ..
# 62  63
# 63  64
# 64  65
# 65  66
# 66  67
#
# [67 rows x 11 columns]

# %%
read_value['bustype']= read_value['bustype'].apply(lambda x: 'NON A/C' if 'non a/c'.upper() in x else 'A/C')
read_value
# Out:
#              route_name                                         route_link  \
# 0   Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
# 1   Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
# 2   Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
# 3   Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
# 4   Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
# ..                  ...                                                ...
# 62  Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
# 63  Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
# 64  Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
# 65  Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
# 66  Delhi to Chandigarh  https://www.redbus.in/bus-tickets/delhi-to-cha...
#
#                             busname bustype duparting_time duration  \
# 0                        HRTC - 505     A/C          06:40  05h 40m
# 1                          HRTC - 6     A/C          06:45  04h 15m
# 2                        HRTC - 533     A/C          07:20  05h 10m
# 3                        HRTC - 592     A/C          08:05  06h 00m
# 4                        HRTC - 513     A/C          10:30  04h 30m
# ..                              ...     ...            ...      ...
# 62                Lucky Bus Service     A/C          19:30  06h 15m
# 63                          FlixBus     A/C          17:45  05h 20m
# 64           Vijay Tour and Travels     A/C          02:40  05h 00m
# 65  Indo Canadian Transport Company     A/C          02:00  08h 30m
# 66  Indo Canadian Transport Company     A/C          02:00  08h 15m
#
#    reaching_time  star_rating  Price  Seats_Available  ID
# 0          12:20          3.3    275               38   1
# 1          11:00          3.6    543               28   2
# 2          12:30          3.1    290               36   3
# 3          14:05          2.2    400               27   4
# 4          15:00          1.7    290               37   5
# ..           ...          ...    ...              ...  ..
# 62         01:45          3.8   1619               44  63
# 63         23:05          2.0    943               31  64
# 64         07:40          1.5    450               41  65
# 65         10:30          4.2   3300               29  66
# 66         10:15          4.2   3300               44  67
#
# [67 rows x 11 columns]

# %%
read_value.to_csv(r'C:/Users/Dell/OneDrive/Desktop/scraping/chandiarhbuses2.csv', index=False)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
