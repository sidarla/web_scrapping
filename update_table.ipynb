# %%
import pandas as pd
read_value=pd.read_csv("C:/Users/Dell/OneDrive/Desktop/scraping/telanagana_buses.csv")
read_value
# Out:
#                   route_name  \
# 0       Khammam to Hyderabad
# 1       Khammam to Hyderabad
# 2       Khammam to Hyderabad
# 3       Khammam to Hyderabad
# 4       Khammam to Hyderabad
# ..                       ...
# 421  Hyderabad to Vijayawada
# 422  Hyderabad to Vijayawada
# 423  Hyderabad to Vijayawada
# 424  Hyderabad to Vijayawada
# 425  Hyderabad to Vijayawada
#
#                                             route_link  \
# 0    https://www.redbus.in/bus-tickets/khammam-to-h...
# 1    https://www.redbus.in/bus-tickets/khammam-to-h...
# 2    https://www.redbus.in/bus-tickets/khammam-to-h...
# 3    https://www.redbus.in/bus-tickets/khammam-to-h...
# 4    https://www.redbus.in/bus-tickets/khammam-to-h...
# ..                                                 ...
# 421  https://www.redbus.in/bus-tickets/hyderabad-to...
# 422  https://www.redbus.in/bus-tickets/hyderabad-to...
# 423  https://www.redbus.in/bus-tickets/hyderabad-to...
# ...

# %%
read_value.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426 entries, 0 to 425
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   route_name       426 non-null    object
#  1   route_link       426 non-null    object
#  2   busname          426 non-null    object
#  3   bustype          426 non-null    object
#  4   duparting_time   426 non-null    object
#  5   duration         426 non-null    object
#  6   reaching_time    426 non-null    object
#  7   star_rating      426 non-null    float64
#  8   Price            426 non-null    object
#  9   Seats_Available  426 non-null    object
#  10  ID               426 non-null    int64
# dtypes: float64(1), int64(1), object(9)
# memory usage: 36.7+ KB

# %%
len(read_value.Price[0]),len(read_value.Price[1])
# Out:
# (7, 3)

# %%
for i in range(len(read_value.Price)):
  length_each_data=len(read_value.Price[i])
  if length_each_data>=7:
      read_value.Price[i]=read_value.Price[i][4:]
  elif length_each_data==3:
      read_value.Price[i]=read_value.Price[i]
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_3556\2458959016.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value.Price[i]=read_value.Price[i][4:]
# ...

# %%
type(read_value.Price)
# Out:
# pandas.core.series.Series

# %%
read_value['Price'] = read_value['Price'].astype(int)

# %%
read_value.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426 entries, 0 to 425
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   route_name       426 non-null    object
#  1   route_link       426 non-null    object
#  2   busname          426 non-null    object
#  3   bustype          426 non-null    object
#  4   duparting_time   426 non-null    object
#  5   duration         426 non-null    object
#  6   reaching_time    426 non-null    object
#  7   star_rating      426 non-null    float64
#  8   Price            426 non-null    int32
#  9   Seats_Available  426 non-null    object
#  10  ID               426 non-null    int64
# dtypes: float64(1), int32(1), int64(1), object(8)
# memory usage: 35.1+ KB

# %%
# Convert to string, extract digits, and convert to integer
read_value['Seats_Available'] = read_value['Seats_Available'].astype(str)
read_value['Seats_Available'] = read_value['Seats_Available'].str.extract('(\d+)').astype(int)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Dell\AppData\Local\Temp\ipykernel_3556\3156470556.py:3: SyntaxWarning: invalid escape sequence '\d'
#   read_value['Seats_Available'] = read_value['Seats_Available'].str.extract('(\d+)').astype(int)

# %%
read_value.nunique()
# Out:
# route_name           2
# route_link           2
# busname            134
# bustype             30
# duparting_time     156
# duration           106
# reaching_time      123
# star_rating         39
# Price              166
# Seats_Available     38
# ID                 426
# dtype: int64

# %%
read_value.busname.unique()
# Out:
# array(['Siri Tours and Travels', 'Bharathi Tours & Travels',
#        'Sri Rama Travels', 'Mythri Tours And Travels',
#        'Sri Sai Balaji Travels', 'DMR Travels', 'Mahadevv travels',
#        'MAHABAHUSRIKVRTRAVELS', 'SVN TOURS & TRAVELS',
#        'Sri Venkateswara Travels', 'Sri KVR Travels',
#        'Sri Krishna Travels(VGN)', 'SAIRAJ TRAVELS',
#        'BSR Tours And Travels', 'Nani’s Sai Krishna Travels',
#        'Orange Tours And Travels', 'Mozo travels', 'Morning Star Travels',
#        'Sri Krishna Travels', 'SRI VEERANJANEYA TOURS AND TRAVELS',
#        'FRESHBUS', 'AdYolo Bus', 'NueGo', 'IntrCity SmartBus',
#        'Svkdt travels', 'Sri Sanvi Tours and Travels', 'Zingbus Plus',
#        'Yolo Bus', 'Sri Durga Malleswari Travels', 'Tirumala Xpress',
#        'LVR Travels', 'Go Tour Travels and Holidays', 'V Kaveri Travels',
#        'LVP Travels', 'Anjani Bus', 'Sai RK Travels',
#        'Sri Venkata Padmavathi Travels', 'Tirumala Travels',
# ...

# %%
read_value.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426 entries, 0 to 425
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   route_name       426 non-null    object
#  1   route_link       426 non-null    object
#  2   busname          426 non-null    object
#  3   bustype          426 non-null    object
#  4   duparting_time   426 non-null    object
#  5   duration         426 non-null    object
#  6   reaching_time    426 non-null    object
#  7   star_rating      426 non-null    float64
#  8   Price            426 non-null    int32
#  9   Seats_Available  426 non-null    int32
#  10  ID               426 non-null    int64
# dtypes: float64(1), int32(2), int64(1), object(7)
# memory usage: 33.4+ KB

# %%
read_value['bustype']=read_value['bustype'].str.upper()
read_value
# Out:
#                   route_name  \
# 0       Khammam to Hyderabad
# 1       Khammam to Hyderabad
# 2       Khammam to Hyderabad
# 3       Khammam to Hyderabad
# 4       Khammam to Hyderabad
# ..                       ...
# 421  Hyderabad to Vijayawada
# 422  Hyderabad to Vijayawada
# 423  Hyderabad to Vijayawada
# 424  Hyderabad to Vijayawada
# 425  Hyderabad to Vijayawada
#
#                                             route_link  \
# 0    https://www.redbus.in/bus-tickets/khammam-to-h...
# 1    https://www.redbus.in/bus-tickets/khammam-to-h...
# 2    https://www.redbus.in/bus-tickets/khammam-to-h...
# 3    https://www.redbus.in/bus-tickets/khammam-to-h...
# 4    https://www.redbus.in/bus-tickets/khammam-to-h...
# ..                                                 ...
# 421  https://www.redbus.in/bus-tickets/hyderabad-to...
# 422  https://www.redbus.in/bus-tickets/hyderabad-to...
# 423  https://www.redbus.in/bus-tickets/hyderabad-to...
# ...

# %%
read_value['bustype']= read_value['bustype'].apply(lambda x: 'NON A/C' if 'non a/c'.upper() in x else 'A/C')
read_value
# Out:
#                   route_name  \
# 0       Khammam to Hyderabad
# 1       Khammam to Hyderabad
# 2       Khammam to Hyderabad
# 3       Khammam to Hyderabad
# 4       Khammam to Hyderabad
# ..                       ...
# 421  Hyderabad to Vijayawada
# 422  Hyderabad to Vijayawada
# 423  Hyderabad to Vijayawada
# 424  Hyderabad to Vijayawada
# 425  Hyderabad to Vijayawada
#
#                                             route_link  \
# 0    https://www.redbus.in/bus-tickets/khammam-to-h...
# 1    https://www.redbus.in/bus-tickets/khammam-to-h...
# 2    https://www.redbus.in/bus-tickets/khammam-to-h...
# 3    https://www.redbus.in/bus-tickets/khammam-to-h...
# 4    https://www.redbus.in/bus-tickets/khammam-to-h...
# ..                                                 ...
# 421  https://www.redbus.in/bus-tickets/hyderabad-to...
# 422  https://www.redbus.in/bus-tickets/hyderabad-to...
# 423  https://www.redbus.in/bus-tickets/hyderabad-to...
# ...

# %%
read_value.to_csv(r'C:/Users/Dell/OneDrive/Desktop/scraping/telanganabuses2.csv', index=False)

# %%
read_value1=pd.read_csv("C:/Users/Dell/OneDrive/Desktop/streamlit/Andhra_buses.csv")
read_value1
# Out:
#                   route_name  \
# 0    Hyderabad to Vijayawada
# 1    Hyderabad to Vijayawada
# 2    Hyderabad to Vijayawada
# 3    Hyderabad to Vijayawada
# 4    Hyderabad to Vijayawada
# ..                       ...
# 530    Tirupati to Bangalore
# 531    Tirupati to Bangalore
# 532    Tirupati to Bangalore
# 533    Tirupati to Bangalore
# 534    Tirupati to Bangalore
#
#                                             route_link             busname  \
# 0    https://www.redbus.in/bus-tickets/hyderabad-to...            FRESHBUS
# 1    https://www.redbus.in/bus-tickets/hyderabad-to...            FRESHBUS
# 2    https://www.redbus.in/bus-tickets/hyderabad-to...          AdYolo Bus
# 3    https://www.redbus.in/bus-tickets/hyderabad-to...            FRESHBUS
# 4    https://www.redbus.in/bus-tickets/hyderabad-to...            FRESHBUS
# ..                                                 ...                 ...
# 530  https://www.redbus.in/bus-tickets/tirupati-to-...      CHOPPA TRAVELS
# ...

# %%
read_value1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 535 entries, 0 to 534
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   route_name       535 non-null    object
#  1   route_link       535 non-null    object
#  2   busname          535 non-null    object
#  3   bustype          535 non-null    object
#  4   duparting_time   535 non-null    object
#  5   duration         535 non-null    object
#  6   reaching_time    535 non-null    object
#  7   star_rating      535 non-null    float64
#  8   Price            535 non-null    object
#  9   Seats_Available  535 non-null    object
#  10  ID               535 non-null    int64
# dtypes: float64(1), int64(1), object(9)
# memory usage: 46.1+ KB

# %%
type(read_value1.Price[0])
# Out:
# str

# %%
for i in range(len(read_value1.Price)):
  length_each_data=len(read_value1.Price[i])
  if length_each_data>=7:
      read_value1.Price[i]=read_value1.Price[i][4:]
  elif length_each_data==3:
      read_value1.Price[i]=read_value1.Price[i]
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_3556\3820072491.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   read_value1.Price[i]=read_value1.Price[i]
# ...

# %%
type(read_value1.Price[0])
# Out:
# str

# %%
read_value1['Seats_Available'] = read_value1['Seats_Available'].astype(str)
read_value1['Seats_Available'] = read_value1['Seats_Available'].str.extract('(\d+)').astype(int)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Dell\AppData\Local\Temp\ipykernel_3556\1099449619.py:2: SyntaxWarning: invalid escape sequence '\d'
#   read_value1['Seats_Available'] = read_value1['Seats_Available'].str.extract('(\d+)').astype(int)

# %%
type(read_value1.Seats_Available[0])
# Out:
# numpy.int32

# %%
read_value1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 535 entries, 0 to 534
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   route_name       535 non-null    object
#  1   route_link       535 non-null    object
#  2   busname          535 non-null    object
#  3   bustype          535 non-null    object
#  4   duparting_time   535 non-null    object
#  5   duration         535 non-null    object
#  6   reaching_time    535 non-null    object
#  7   star_rating      535 non-null    float64
#  8   Price            535 non-null    object
#  9   Seats_Available  535 non-null    int32
#  10  ID               535 non-null    int64
# dtypes: float64(1), int32(1), int64(1), object(8)
# memory usage: 44.0+ KB

# %%
read_value1.to_csv(r'C:/Users/Dell/OneDrive/Desktop/scraping/andhrabuses11.csv', index=False)

# %%
import pandas as pd
read_value2=pd.read_csv(r'C:/Users/Dell/OneDrive/Desktop/scraping/andhrabuses11.csv')
read_value2
# Out:
#                   route_name  \
# 0    Hyderabad to Vijayawada
# 1    Hyderabad to Vijayawada
# 2    Hyderabad to Vijayawada
# 3    Hyderabad to Vijayawada
# 4    Hyderabad to Vijayawada
# ..                       ...
# 530    Tirupati to Bangalore
# 531    Tirupati to Bangalore
# 532    Tirupati to Bangalore
# 533    Tirupati to Bangalore
# 534    Tirupati to Bangalore
#
#                                             route_link             busname  \
# 0    https://www.redbus.in/bus-tickets/hyderabad-to...            FRESHBUS
# 1    https://www.redbus.in/bus-tickets/hyderabad-to...            FRESHBUS
# 2    https://www.redbus.in/bus-tickets/hyderabad-to...          AdYolo Bus
# 3    https://www.redbus.in/bus-tickets/hyderabad-to...            FRESHBUS
# 4    https://www.redbus.in/bus-tickets/hyderabad-to...            FRESHBUS
# ..                                                 ...                 ...
# 530  https://www.redbus.in/bus-tickets/tirupati-to-...      CHOPPA TRAVELS
# ...

# %%
read_value2['bustype']=read_value2['bustype'].str.upper()
read_value2
# Out:
#                   route_name  \
# 0    Hyderabad to Vijayawada
# 1    Hyderabad to Vijayawada
# 2    Hyderabad to Vijayawada
# 3    Hyderabad to Vijayawada
# 4    Hyderabad to Vijayawada
# ..                       ...
# 530    Tirupati to Bangalore
# 531    Tirupati to Bangalore
# 532    Tirupati to Bangalore
# 533    Tirupati to Bangalore
# 534    Tirupati to Bangalore
#
#                                             route_link             busname  \
# 0    https://www.redbus.in/bus-tickets/hyderabad-to...            FRESHBUS
# 1    https://www.redbus.in/bus-tickets/hyderabad-to...            FRESHBUS
# 2    https://www.redbus.in/bus-tickets/hyderabad-to...          AdYolo Bus
# 3    https://www.redbus.in/bus-tickets/hyderabad-to...            FRESHBUS
# 4    https://www.redbus.in/bus-tickets/hyderabad-to...            FRESHBUS
# ..                                                 ...                 ...
# 530  https://www.redbus.in/bus-tickets/tirupati-to-...      CHOPPA TRAVELS
# ...

# %%
read_value2['bustype']= read_value2['bustype'].apply(lambda x: 'NON A/C' if 'non a/c'.upper() in x else 'A/C')
read_value2
# Out:
#                   route_name  \
# 0    Hyderabad to Vijayawada
# 1    Hyderabad to Vijayawada
# 2    Hyderabad to Vijayawada
# 3    Hyderabad to Vijayawada
# 4    Hyderabad to Vijayawada
# ..                       ...
# 530    Tirupati to Bangalore
# 531    Tirupati to Bangalore
# 532    Tirupati to Bangalore
# 533    Tirupati to Bangalore
# 534    Tirupati to Bangalore
#
#                                             route_link             busname  \
# 0    https://www.redbus.in/bus-tickets/hyderabad-to...            FRESHBUS
# 1    https://www.redbus.in/bus-tickets/hyderabad-to...            FRESHBUS
# 2    https://www.redbus.in/bus-tickets/hyderabad-to...          AdYolo Bus
# 3    https://www.redbus.in/bus-tickets/hyderabad-to...            FRESHBUS
# 4    https://www.redbus.in/bus-tickets/hyderabad-to...            FRESHBUS
# ..                                                 ...                 ...
# 530  https://www.redbus.in/bus-tickets/tirupati-to-...      CHOPPA TRAVELS
# ...

# %%
read_value2.to_csv(r'C:/Users/Dell/OneDrive/Desktop/scraping/andhrabuses4.csv', index=False)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
