# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('https://www.redbus.in/online-booking/west-bengal-transport-corporation?utm_source=rtchometile')
time.sleep(2)  # Let the page load

body = driver.find_element(By.TAG_NAME, "body")
telangana_buses_list=[] 
telangana_buses_links=[]

 # Loop over pages (or scroll actions)
    # Get all elements with class 'route'
result1 = driver.find_elements(By.CSS_SELECTOR, "a[class='route']")
    
    # Print the text of each element found
for element in result1:
    telangana_buses_list.append(element.text)
    telangana_buses_links.append(element.get_attribute('href'))
    
    # Scroll down the page
    #body.send_keys(Keys.PAGE_DOWN)
time.sleep(2)  # Give some time for new elements to load
    
    # Find an element matching the XPATH and click (if needed)
    #result = driver.find_elements(By.XPATH, f"//div[contains(text(),'{page_num+1}')]")
    #print(result)
    #if result:
        #result[0].click()  # Click the first element found with matching XPATH

#driver.quit()  # Close the browser after task completion

# %%
for i in telangana_buses_links:
    print(i)
# Out:
# https://www.redbus.in/bus-tickets/digha-to-kolkata
# https://www.redbus.in/bus-tickets/kolkata-to-digha
# https://www.redbus.in/bus-tickets/mandarmani-to-kolkata
# https://www.redbus.in/bus-tickets/kolkata-to-mandarmani

# %%
for i in telangana_buses_list:
    print(i)
# Out:
# Digha to Kolkata
# Kolkata to Digha
# Mandarmani to Kolkata
# Kolkata to Mandarmani

# %%
 # Let the page load
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('https://www.redbus.in/bus-tickets/digha-to-kolkata?fromCityId=74706&toCityId=74820&fromCityName=Digha&toCityName=Kolkata&busType=Any&srcCountry=IND&destCountry=IND&onward=22-Nov-2024')
time.sleep(2)  # Let the page load

body = driver.find_element(By.TAG_NAME, "body")
hide_details_TS=driver.find_elements(By.XPATH, "//div[@class='button']")
if hide_details_TS:
    hide_details_TS[0].click()
for i in range(50):
    buses_list_result = driver.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type_result = driver.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    departing_time_result = driver.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    reaching_time_result = driver.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    duration_list_result = driver.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")
    star_rating_result = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
    price_result = driver.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats_available_result = driver.find_elements(By.XPATH, "//div[@class='seat-left m-top-30']")
    body.send_keys(Keys.PAGE_DOWN)
buses_list=[]
bus_type_list=[]
departing_time_list=[]
reaching_time_list=[]
duration_list=[]
star_rating_list=[]
price_list=[]
seats_available_list=[]
for i in buses_list_result:
    buses_list.append(i.text)
for i in bus_type_result:
    bus_type_list.append(i.text)
for i in departing_time_result:
    departing_time_list.append(i.text)
for i in reaching_time_result:
    reaching_time_list.append(i.text)
for i in duration_list_result:
    duration_list.append(i.text)
for i in star_rating_result:
    star_rating_list.append(i.text)
for i in price_result:
    price_list.append(i.text)
for i in seats_available_result:
    seats_available_list.append(i.text)

# %%
min_value=min(len(buses_list),len(bus_type_list),len(departing_time_list),len(reaching_time_list),len(duration_list),len(star_rating_list),len(price_list),len(seats_available_list))
print(min_value)
# Out:
# 13

# %%
busname=[]
bustype=[]
departing_time=[]
duration=[]
reaching_time=[]
star_rating=[]
price=[]
seats_available=[]
route_link=[]
route_name=[]
for i in range(min_value):
    busname.append(buses_list[i])
    bustype.append(bus_type_list[i])
    departing_time.append(departing_time_list[i])
    duration.append(duration_list[i])
    reaching_time.append(reaching_time_list[i])
    star_rating.append(star_rating_list[i])
    price.append(price_list[i])
    seats_available.append(seats_available_list[i])
    route_link.append("https://www.redbus.in/bus-tickets/digha-to-kolkata")
    route_name.append("Digha to Kolkata")

# %%
import pandas as pd

# Dictionary with data
data = {
    'route_name': route_name,
    'route_link': route_link,
    'busname':busname,
    'bustype':bustype,
    'duparting_time': departing_time,
    'duration':duration,
    'reaching_time': reaching_time,
    'star_rating': star_rating,
    'Price': price,
    'Seats Available': seats_available
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Add automated ID column
df['ID'] = range(1, len(df) + 1)

print(df)
# Out:
#           route_name                                         route_link  \
# 0   Digha to Kolkata  https://www.redbus.in/bus-tickets/digha-to-kol...
# 1   Digha to Kolkata  https://www.redbus.in/bus-tickets/digha-to-kol...
# 2   Digha to Kolkata  https://www.redbus.in/bus-tickets/digha-to-kol...
# 3   Digha to Kolkata  https://www.redbus.in/bus-tickets/digha-to-kol...
# 4   Digha to Kolkata  https://www.redbus.in/bus-tickets/digha-to-kol...
# 5   Digha to Kolkata  https://www.redbus.in/bus-tickets/digha-to-kol...
# 6   Digha to Kolkata  https://www.redbus.in/bus-tickets/digha-to-kol...
# 7   Digha to Kolkata  https://www.redbus.in/bus-tickets/digha-to-kol...
# 8   Digha to Kolkata  https://www.redbus.in/bus-tickets/digha-to-kol...
# 9   Digha to Kolkata  https://www.redbus.in/bus-tickets/digha-to-kol...
# 10  Digha to Kolkata  https://www.redbus.in/bus-tickets/digha-to-kol...
# 11  Digha to Kolkata  https://www.redbus.in/bus-tickets/digha-to-kol...
# 12  Digha to Kolkata  https://www.redbus.in/bus-tickets/digha-to-kol...
#
#                         busname                                   bustype  \
# 0                  Express Line  Volvo 9600 Multi Axle Semi-Sleeper (2+2)
# 1    Shyamoli Paribahan Pvt Ltd                       VE A/C Seater (2+2)
# 2    Shyamoli Paribahan Pvt Ltd                    Volvo A/C Seater (2+2)
# 3                     Greenline                    Volvo A/C Seater (2+2)
# 4               Samanta Travels                          A/C Seater (2+3)
# 5            Maa Chandi Travels                A/C Seater / Sleeper (2+2)
# 6   Snemita Paribahan(Shinjini)                          A/C Seater (2+3)
# 7      Ankita Paribahan(Atithi)                A/C Seater Push Back (2+3)
# 8       City Express (Shinjini)                           AC Seater (2+3)
# 9            Parameswar Travels                A/C Seater Push Back (2+3)
# 10      Monikanchan Bus Service                          A/C Seater (2+3)
# 11            Snemita Paribahan                           AC Seater (2+3)
# 12              Satya Paribahan                          A/C Seater (2+3)
#
#    duparting_time duration reaching_time star_rating    Price  \
# 0           13:45  04h 30m         18:15         4.5  INR 299
# 1           13:45  05h 10m         18:55         4.3  INR 299
# 2           13:30  04h 55m         18:25         4.5  INR 299
# 3           13:40  04h 45m         18:25         4.2  INR 300
# 4           14:30  04h 50m         19:20         3.3  INR 300
# 5           12:35  04h 40m         17:15         3.8  INR 300
# 6           22:45  05h 25m         04:10         3.8      288
# 7           13:35  04h 15m         17:50         3.1      288
# 8           22:45  05h 25m         04:10         3.6      288
# 9           20:00  05h 35m         01:35         3.4      238
# 10          13:30  04h 15m         17:45         4.5      338
# 11          11:35  04h 50m         16:25         3.6      351
# 12          23:00  04h 45m         03:45         3.0  INR 320
#
#        Seats Available  ID
# 0   26 Seats available   1
# 1   23 Seats available   2
# 2   20 Seats available   3
# 3   38 Seats available   4
# 4   53 Seats available   5
# 5   28 Seats available   6
# 6   46 Seats available   7
# 7   15 Seats available   8
# 8   45 Seats available   9
# 9   71 Seats available  10
# 10  21 Seats available  11
# 11  53 Seats available  12
# 12  13 Seats available  13

# %%
 # Let the page load
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('https://www.redbus.in/bus-tickets/kolkata-to-digha?fromCityId=74820&toCityId=74706&fromCityName=Kolkata&toCityName=Digha&busType=Any&onward=22-Nov-2024')
time.sleep(2)  # Let the page load

body = driver.find_element(By.TAG_NAME, "body")
hide_details_TS=driver.find_elements(By.XPATH, "//div[@class='button']")
if hide_details_TS:
    hide_details_TS[0].click()
for i in range(50):
    buses_list_result = driver.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type_result = driver.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    departing_time_result = driver.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    reaching_time_result = driver.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    duration_list_result = driver.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")
    star_rating_result = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
    price_result = driver.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats_available_result = driver.find_elements(By.XPATH, "//div[@class='seat-left m-top-30']")
    body.send_keys(Keys.PAGE_DOWN)
buses_list=[]
bus_type_list=[]
departing_time_list=[]
reaching_time_list=[]
duration_list=[]
star_rating_list=[]
price_list=[]
seats_available_list=[]
for i in buses_list_result:
    buses_list.append(i.text)
for i in bus_type_result:
    bus_type_list.append(i.text)
for i in departing_time_result:
    departing_time_list.append(i.text)
for i in reaching_time_result:
    reaching_time_list.append(i.text)
for i in duration_list_result:
    duration_list.append(i.text)
for i in star_rating_result:
    star_rating_list.append(i.text)
for i in price_result:
    price_list.append(i.text)
for i in seats_available_result:
    seats_available_list.append(i.text)

# %%
min_value=min(len(buses_list),len(bus_type_list),len(departing_time_list),len(reaching_time_list),len(duration_list),len(star_rating_list),len(price_list),len(seats_available_list))
print(min_value)
# Out:
# 40

# %%
busname=[]
bustype=[]
departing_time=[]
duration=[]
reaching_time=[]
star_rating=[]
price=[]
seats_available=[]
route_link=[]
route_name=[]
for i in range(min_value):
    busname.append(buses_list[i])
    bustype.append(bus_type_list[i])
    departing_time.append(departing_time_list[i])
    duration.append(duration_list[i])
    reaching_time.append(reaching_time_list[i])
    star_rating.append(star_rating_list[i])
    price.append(price_list[i])
    seats_available.append(seats_available_list[i])
    route_link.append("https://www.redbus.in/bus-tickets/kolkata-to-digha")
    route_name.append("Kolkata to Digha")

# %%
import pandas as pd

# Dictionary with data
data = {
    'route_name': route_name,
    'route_link': route_link,
    'busname':busname,
    'bustype':bustype,
    'duparting_time': departing_time,
    'duration':duration,
    'reaching_time': reaching_time,
    'star_rating': star_rating,
    'Price': price,
    'Seats Available': seats_available
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Add automated ID column
df['ID'] = range(1, len(df) + 1)

print(df)
# Out:
#           route_name                                         route_link  \
# 0   Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 1   Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 2   Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 3   Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 4   Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 5   Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 6   Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 7   Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 8   Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 9   Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 10  Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 11  Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 12  Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 13  Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 14  Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 15  Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 16  Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 17  Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 18  Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 19  Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 20  Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 21  Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 22  Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 23  Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 24  Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 25  Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 26  Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 27  Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 28  Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 29  Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 30  Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 31  Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 32  Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 33  Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 34  Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 35  Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 36  Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 37  Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 38  Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 39  Kolkata to Digha  https://www.redbus.in/bus-tickets/kolkata-to-d...
#
#                                        busname                     bustype  \
# 0   West bengal transport corporation - 123496         Non AC Seater (2+3)
# 1                   Shyamoli Paribahan Pvt Ltd         VE A/C Seater (2+2)
# 2                   Shyamoli Paribahan Pvt Ltd      Volvo A/C Seater (2+2)
# 3                     AdSagufta Travels(Angel)            A/C Seater (2+2)
# 4                               Mayuri Express             AC Seater (2+2)
# 5                  Sagufta Travels(Maa Chandi)  A/C Seater / Sleeper (2+2)
# 6                                 Express Line         VE A/C Seater (2+2)
# 7                           Parameswar Travels  A/C Seater Push Back (2+3)
# 8                           Parameswar Travels  A/C Seater Push Back (2+3)
# 9                           Parameswar Travels  A/C Seater Push Back (2+3)
# 10                          Maa Chandi Travels  A/C Seater / Sleeper (2+2)
# 11                     City Express (Shinjini)             AC Seater (2+2)
# 12                  Snemita Parisheba(Samanta)             AC Seater (2+3)
# 13                                Basu Travels  A/C Seater / Sleeper (2+2)
# 14                    Sagufta Travels (Mayuri)            A/C Seater (2+2)
# 15                    Bengal Surface Transport  A/C Seater / Sleeper (2+2)
# 16                     City Express (Shinjini)             AC Seater (2+3)
# 17                     Sagufta Travels (Maity)            A/C Seater (2+3)
# 18                          Parameswar Travels  A/C Seater Push Back (2+3)
# 19                   Snemita Paribahan (ANGEL)  A/C Seater Push Back (2+2)
# 20                   Snemita Paribahan (Sathi)            A/C Seater (2+3)
# 21                      City Express (BHORPET)             AC Seater (2+3)
# 22                    Sagufta Travels (Atithi)  A/C Seater Push Back (2+3)
# 23                Sagufta Travels (Maa Chandi)  A/C Seater Push Back (2+3)
# 24                              Mayuri Express            A/C Seater (2+3)
# 25                          ADHIKARY PARIBAHAN            A/C Seater (2+3)
# 26                  Snemita Parisheba (Bhunia)             AC Seater (2+3)
# 27                          Parameswar Travels  A/C Seater Push Back (2+3)
# 28                    Bengal Surface Transport  A/C Seater Push Back (2+3)
# 29               Snemita Paribahan(Maa Chandi)             AC Seater (2+3)
# 30                      City Express (Ruposhi)             AC Seater (2+3)
# 31                 Snemita Paribahan(Shinjini)            A/C Seater (2+3)
# 32                 Snemita Paribahan (Bhorpet)             AC Seater (2+2)
# 33                          Purusottam Travels            A/C Seater (2+3)
# 34               Sagufta Travels (Sagar Kanya)  A/C Seater Push Back (2+3)
# 35                   Sagufta Travels (Kojagor)            A/C Seater (2+3)
# 36                           Arunita Paribahan             AC Seater (2+2)
# 37                        Haimanti Bus Service             AC Seater (2+3)
# 38                   Sagufta Travels (Samanta)            A/C Seater (2+3)
# 39                           Snemita Parisheba         A/C Push Back (2+3)
#
#    duparting_time duration reaching_time star_rating    Price  \
# 0           16:15  04h 30m         20:45         3.5  INR 145
# 1           23:30  05h 00m         04:30         4.6  INR 775
# 2           23:45  05h 00m         04:45         4.5  INR 775
# 3           23:58  05h 12m         05:10         4.2      394
# 4           23:15  05h 15m         04:30         4.1      431
# 5           23:57  05h 13m         05:10         4.2      489
# 6           23:45  05h 00m         04:45         4.3  INR 629
# 7           23:45  05h 15m         05:00         3.2      285
# 8           23:59  05h 01m         05:00         3.2      285
# 9           13:10  04h 46m         17:56         3.5      285
# 10          23:57  05h 13m         05:10         4.1  INR 500
# 11          23:45  04h 50m         04:35         3.9      420
# 12          18:00  04h 25m         22:25         3.6      333
# 13          23:59  05h 01m         05:00         3.5  INR 599
# 14          23:15  04h 45m         04:00         3.8      442
# 15          23:55  05h 05m         05:00         3.0      440
# 16          23:50  05h 05m         04:55         2.8      432
# 17          00:55  04h 55m         05:50         3.1      347
# 18          23:55  05h 05m         05:00         2.5      285
# 19          23:58  05h 02m         05:00         1.7      370
# 20          17:40  04h 20m         22:00         1.6      320
# 21          17:40  04h 20m         22:00         1.7      320
# 22          23:59  05h 01m         05:00         2.8      347
# 23          13:30  04h 35m         18:05         2.4      384
# 24          18:20  04h 30m         22:50         3.9      315
# 25          15:15  04h 45m         20:00         5.0      254
# 26          16:00  04h 40m         20:40         3.9      333
# 27          21:50  05h 55m         03:45         2.2      285
# 28          23:59  05h 01m         05:00         2.0      319
# 29          13:35  04h 30m         18:05         1.2      320
# 30          15:55  04h 55m         20:50         3.6      320
# 31          23:50  04h 40m         04:30         2.6      420
# 32          23:55  04h 50m         04:45         3.7      420
# 33          14:39  05h 26m         20:05         2.6  INR 300
# 34          23:30  04h 35m         04:05         2.5      347
# 35          15:50  04h 30m         20:20         2.9      384
# 36          23:45  05h 00m         04:45         4.1      370
# 37          19:50  05h 40m         01:30         1.8  INR 300
# 38          18:00  04h 50m         22:50         2.6      384
# 39          15:15  04h 30m         19:45         2.1      333
#
#        Seats Available  ID
# 0   10 Seats available   1
# 1   25 Seats available   2
# 2   22 Seats available   3
# 3    6 Seats available   4
# 4    4 Seats available   5
# 5   20 Seats available   6
# 6   42 Seats available   7
# 7   30 Seats available   8
# 8    5 Seats available   9
# 9   12 Seats available  10
# 10  32 Seats available  11
# 11  11 Seats available  12
# 12  29 Seats available  13
# 13  35 Seats available  14
# 14  22 Seats available  15
# 15  49 Seats available  16
# 16  25 Seats available  17
# 17  20 Seats available  18
# 18  50 Seats available  19
# 19  18 Seats available  20
# 20  20 Seats available  21
# 21  29 Seats available  22
# 22  20 Seats available  23
# 23  21 Seats available  24
# 24  20 Seats available  25
# 25  22 Seats available  26
# 26  20 Seats available  27
# 27  20 Seats available  28
# 28  21 Seats available  29
# 29  16 Seats available  30
# 30  41 Seats available  31
# 31  20 Seats available  32
# 32  16 Seats available  33
# 33  26 Seats available  34
# 34  31 Seats available  35
# 35  21 Seats available  36
# 36  45 Seats available  37
# 37  41 Seats available  38
# 38  60 Seats available  39
# 39  41 Seats available  40

# %%
 # Let the page load
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('https://www.redbus.in/bus-tickets/mandarmani-to-kolkata?fromCityId=82467&toCityId=74820&fromCityName=Mandarmani&toCityName=Kolkata&busType=Any&onward=22-Nov-2024')
time.sleep(2)  # Let the page load

body = driver.find_element(By.TAG_NAME, "body")
hide_details_TS=driver.find_elements(By.XPATH, "//div[@class='button']")
if hide_details_TS:
    hide_details_TS[0].click()
for i in range(50):
    buses_list_result = driver.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type_result = driver.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    departing_time_result = driver.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    reaching_time_result = driver.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    duration_list_result = driver.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")
    star_rating_result = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
    price_result = driver.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats_available_result = driver.find_elements(By.XPATH, "//div[@class='seat-left m-top-30']")
    body.send_keys(Keys.PAGE_DOWN)
buses_list=[]
bus_type_list=[]
departing_time_list=[]
reaching_time_list=[]
duration_list=[]
star_rating_list=[]
price_list=[]
seats_available_list=[]
for i in buses_list_result:
    buses_list.append(i.text)
for i in bus_type_result:
    bus_type_list.append(i.text)
for i in departing_time_result:
    departing_time_list.append(i.text)
for i in reaching_time_result:
    reaching_time_list.append(i.text)
for i in duration_list_result:
    duration_list.append(i.text)
for i in star_rating_result:
    star_rating_list.append(i.text)
for i in price_result:
    price_list.append(i.text)
for i in seats_available_result:
    seats_available_list.append(i.text)

# %%
min_value=min(len(buses_list),len(bus_type_list),len(departing_time_list),len(reaching_time_list),len(duration_list),len(star_rating_list),len(price_list),len(seats_available_list))
print(min_value)
# Out:
# 10

# %%
busname=[]
bustype=[]
departing_time=[]
duration=[]
reaching_time=[]
star_rating=[]
price=[]
seats_available=[]
route_link=[]
route_name=[]
for i in range(min_value):
    busname.append(buses_list[i])
    bustype.append(bus_type_list[i])
    departing_time.append(departing_time_list[i])
    duration.append(duration_list[i])
    reaching_time.append(reaching_time_list[i])
    star_rating.append(star_rating_list[i])
    price.append(price_list[i])
    seats_available.append(seats_available_list[i])
    route_link.append("https://www.redbus.in/bus-tickets/mandarmani-to-kolkata")
    route_name.append("Mandarmani to Kolkata")

# %%
import pandas as pd

# Dictionary with data
data = {
    'route_name': route_name,
    'route_link': route_link,
    'busname':busname,
    'bustype':bustype,
    'duparting_time': departing_time,
    'duration':duration,
    'reaching_time': reaching_time,
    'star_rating': star_rating,
    'Price': price,
    'Seats Available': seats_available
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Add automated ID column
df['ID'] = range(1, len(df) + 1)

print(df)
# Out:
#               route_name                                         route_link  \
# 0  Mandarmani to Kolkata  https://www.redbus.in/bus-tickets/mandarmani-t...
# 1  Mandarmani to Kolkata  https://www.redbus.in/bus-tickets/mandarmani-t...
# 2  Mandarmani to Kolkata  https://www.redbus.in/bus-tickets/mandarmani-t...
# 3  Mandarmani to Kolkata  https://www.redbus.in/bus-tickets/mandarmani-t...
# 4  Mandarmani to Kolkata  https://www.redbus.in/bus-tickets/mandarmani-t...
# 5  Mandarmani to Kolkata  https://www.redbus.in/bus-tickets/mandarmani-t...
# 6  Mandarmani to Kolkata  https://www.redbus.in/bus-tickets/mandarmani-t...
# 7  Mandarmani to Kolkata  https://www.redbus.in/bus-tickets/mandarmani-t...
# 8  Mandarmani to Kolkata  https://www.redbus.in/bus-tickets/mandarmani-t...
# 9  Mandarmani to Kolkata  https://www.redbus.in/bus-tickets/mandarmani-t...
#
#                           busname                                   bustype  \
# 0                    Express Line  Volvo 9600 Multi Axle Semi-Sleeper (2+2)
# 1      Shyamoli Paribahan Pvt Ltd                       VE A/C Seater (2+2)
# 2      Shyamoli Paribahan Pvt Ltd                    Volvo A/C Seater (2+2)
# 3                       Greenline                    Volvo A/C Seater (2+2)
# 4                  Mayuri Express                          A/C Seater (2+3)
# 5                   Royal Cruiser   Scania Multi-Axle AC Semi Sleeper (2+2)
# 6        Ankita Paribahan(Atithi)                A/C Seater Push Back (2+3)
# 7         City Express (Shinjini)                           AC Seater (2+3)
# 8  Ankita Paribahan (Maity Motor)                A/C Seater Push Back (2+3)
# 9                 Samanta Travels                          A/C Seater (2+3)
#
#   duparting_time duration reaching_time star_rating    Price  \
# 0          14:30  03h 45m         18:15         4.7  INR 299
# 1          14:30  04h 25m         18:55         4.3  INR 299
# 2          14:15  04h 10m         18:25         4.3  INR 299
# 3          14:10  04h 15m         18:25         4.0  INR 300
# 4          11:45  04h 15m         16:00         4.1  INR 250
# 5          13:45  03h 45m         17:30         3.7      352
# 6          14:05  03h 45m         17:50         4.9      288
# 7          16:00  03h 55m         19:55         3.2      270
# 8          13:45  03h 45m         17:30         3.3      270
# 9          15:15  04h 05m         19:20         2.8  INR 300
#
#       Seats Available  ID
# 0  15 Seats available   1
# 1  26 Seats available   2
# 2  38 Seats available   3
# 3  25 Seats available   4
# 4  26 Seats available   5
# 5  20 Seats available   6
# 6  45 Seats available   7
# 7  28 Seats available   8
# 8  13 Seats available   9
# 9  71 Seats available  10

# %%
 # Let the page load
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('https://www.redbus.in/bus-tickets/kolkata-to-mandarmani?fromCityId=74820&toCityId=82467&fromCityName=Kolkata&toCityName=Mandarmani&busType=Any&onward=22-Nov-2024')
time.sleep(2)  # Let the page load

body = driver.find_element(By.TAG_NAME, "body")
hide_details_TS=driver.find_elements(By.XPATH, "//div[@class='button']")
if hide_details_TS:
    hide_details_TS[0].click()
for i in range(50):
    buses_list_result = driver.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type_result = driver.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    departing_time_result = driver.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    reaching_time_result = driver.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    duration_list_result = driver.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")
    star_rating_result = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
    price_result = driver.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats_available_result = driver.find_elements(By.XPATH, "//div[@class='seat-left m-top-30']")
    body.send_keys(Keys.PAGE_DOWN)
buses_list=[]
bus_type_list=[]
departing_time_list=[]
reaching_time_list=[]
duration_list=[]
star_rating_list=[]
price_list=[]
seats_available_list=[]
for i in buses_list_result:
    buses_list.append(i.text)
for i in bus_type_result:
    bus_type_list.append(i.text)
for i in departing_time_result:
    departing_time_list.append(i.text)
for i in reaching_time_result:
    reaching_time_list.append(i.text)
for i in duration_list_result:
    duration_list.append(i.text)
for i in star_rating_result:
    star_rating_list.append(i.text)
for i in price_result:
    price_list.append(i.text)
for i in seats_available_result:
    seats_available_list.append(i.text)

# %%
min_value=min(len(buses_list),len(bus_type_list),len(departing_time_list),len(reaching_time_list),len(duration_list),len(star_rating_list),len(price_list),len(seats_available_list))
print(min_value)
# Out:
# 40

# %%
busname=[]
bustype=[]
departing_time=[]
duration=[]
reaching_time=[]
star_rating=[]
price=[]
seats_available=[]
route_link=[]
route_name=[]
for i in range(min_value):
    busname.append(buses_list[i])
    bustype.append(bus_type_list[i])
    departing_time.append(departing_time_list[i])
    duration.append(duration_list[i])
    reaching_time.append(reaching_time_list[i])
    star_rating.append(star_rating_list[i])
    price.append(price_list[i])
    seats_available.append(seats_available_list[i])
    route_link.append("https://www.redbus.in/bus-tickets/kolkata-to-mandarmani")
    route_name.append("Kolkata to Mandarmani")

# %%
import pandas as pd

# Dictionary with data
data = {
    'route_name': route_name,
    'route_link': route_link,
    'busname':busname,
    'bustype':bustype,
    'duparting_time': departing_time,
    'duration':duration,
    'reaching_time': reaching_time,
    'star_rating': star_rating,
    'Price': price,
    'Seats Available': seats_available
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Add automated ID column
df['ID'] = range(1, len(df) + 1)

print(df)
# Out:
#                route_name                                         route_link  \
# 0   Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 1   Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 2   Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 3   Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 4   Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 5   Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 6   Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 7   Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 8   Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 9   Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 10  Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 11  Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 12  Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 13  Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 14  Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 15  Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 16  Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 17  Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 18  Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 19  Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 20  Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 21  Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 22  Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 23  Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 24  Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 25  Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 26  Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 27  Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 28  Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 29  Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 30  Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 31  Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 32  Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 33  Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 34  Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 35  Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 36  Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 37  Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 38  Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
# 39  Kolkata to Mandarmani  https://www.redbus.in/bus-tickets/kolkata-to-m...
#
#                                        busname                     bustype  \
# 0   West bengal transport corporation - 123496         Non AC Seater (2+3)
# 1   West bengal transport corporation - 157764         Non AC Seater (2+3)
# 2                   Shyamoli Paribahan Pvt Ltd         VE A/C Seater (2+2)
# 3                   Shyamoli Paribahan Pvt Ltd      Volvo A/C Seater (2+2)
# 4                                 Express Line         VE A/C Seater (2+2)
# 5                AdSagufta Travels(Maa Chandi)  A/C Seater / Sleeper (2+2)
# 6                                 Basu Travels  A/C Seater / Sleeper (2+2)
# 7                           Maa Chandi Travels  A/C Seater / Sleeper (2+2)
# 8                           Parameswar Travels  A/C Seater Push Back (2+3)
# 9                       City Express (BHORPET)             AC Seater (2+3)
# 10                          ADHIKARY PARIBAHAN            A/C Seater (2+3)
# 11                   Snemita Paribahan (ANGEL)  A/C Seater Push Back (2+2)
# 12                 Snemita Paribahan (BHORPET)            A/C Seater (2+3)
# 13                              Mayuri Express             AC Seater (2+2)
# 14                   Sagufta Travels (Kojagor)            A/C Seater (2+3)
# 15                 Snemita Paribahan(Shinjini)            A/C Seater (2+3)
# 16                    Sagufta Travels (Atithi)  A/C Seater Push Back (2+3)
# 17                 Snemita Parisheba (Samanta)             AC Seater (2+3)
# 18                    City Express (Maa Gauri)             AC Seater (2+3)
# 19                          Parameswar Travels  A/C Seater Push Back (2+3)
# 20               Sagufta Travels (Sagar Kanya)  A/C Seater Push Back (2+3)
# 21                Sagufta Travels (Maa Chandi)  A/C Seater Push Back (2+3)
# 22                     City Express (Shinjini)             AC Seater (2+2)
# 23                     City Express (Shinjini)             AC Seater (2+3)
# 24                             Samanta Travels            A/C Seater (2+3)
# 25                         SANTOSH BUS SERVICE             AC Seater (2+3)
# 26                              Mayuri Express            A/C Seater (2+3)
# 27                          Parameswar Travels  A/C Seater Push Back (2+3)
# 28                           Snemita Parisheba             AC Seater (2+3)
# 29                    Bengal Surface Transport  A/C Seater Push Back (2+3)
# 30                   City Express (Maa Chandi)             AC Seater (2+3)
# 31                      City Express (Ruposhi)             AC Seater (2+3)
# 32                 Snemita Paribahan (Ruposhi)             AC Seater (2+3)
# 33                          Parameswar Travels  A/C Seater Push Back (2+3)
# 34                    Bengal Surface Transport  A/C Seater Push Back (2+3)
# 35                         SANTOSH BUS SERVICE             AC Seater (2+3)
# 36                          Parameswar Travels  A/C Seater Push Back (2+3)
# 37                   Snemita Pariseba(Santosh)             AC Seater (2+3)
# 38                    Bengal Surface Transport  A/C Seater Push Back (2+3)
# 39                   Sagufta Travels (Kojagor)  A/C Seater Push Back (2+3)
#
#    duparting_time duration reaching_time star_rating    Price  \
# 0           16:15  04h 00m         20:15         3.9  INR 145
# 1           17:15  04h 00m         21:15         3.1  INR 145
# 2           23:30  04h 15m         03:45         4.7  INR 775
# 3           23:45  04h 15m         04:00         4.7  INR 775
# 4           23:45  04h 20m         04:05         4.4  INR 629
# 5           23:57  04h 30m         04:27         4.5      489
# 6           23:59  04h 01m         04:00         4.5  INR 599
# 7           23:57  04h 23m         04:20         3.9  INR 500
# 8           23:59  04h 31m         04:30         3.0      285
# 9           17:40  04h 05m         21:45         3.9      320
# 10          15:15  04h 00m         19:15         3.0      254
# 11          23:58  04h 02m         04:00         3.0      370
# 12          17:40  03h 35m         21:15         3.9      320
# 13          23:15  03h 45m         03:00         3.1      431
# 14          15:50  04h 00m         19:50         3.0      384
# 15          23:50  04h 10m         04:00         3.0      420
# 16          23:59  04h 31m         04:30         1.6      347
# 17          14:15  04h 00m         18:15         2.3      333
# 18          12:40  03h 50m         16:30         2.7      320
# 19          23:55  04h 35m         04:30         2.8      285
# 20          23:30  04h 30m         04:00         1.7      347
# 21          13:30  04h 15m         17:45         3.9      384
# 22          23:45  04h 15m         04:00         3.9      420
# 23          23:50  04h 20m         04:10         3.7      432
# 24          18:50  03h 40m         22:30         3.7  INR 370
# 25          19:25  03h 55m         23:20         3.6  INR 299
# 26          18:20  04h 10m         22:30         2.8      315
# 27          23:45  04h 45m         04:30         1.1      285
# 28          16:10  03h 50m         20:00         2.1      333
# 29          23:20  03h 55m         03:15         3.9      335
# 30          13:35  03h 55m         17:30         3.9      320
# 31          15:55  04h 25m         20:20         3.0      320
# 32          15:55  04h 15m         20:10         2.8      320
# 33          21:50  05h 10m         03:00         2.1      285
# 34          23:59  04h 01m         04:00         3.7      319
# 35          19:25  03h 55m         23:20         2.8  INR 349
# 36          13:10  04h 20m         17:30         2.2      285
# 37          18:30  03h 30m         22:00         2.1      333
# 38          14:29  03h 41m         18:10         3.2      303
# 39          17:00  04h 30m         21:30         3.2      384
#
#        Seats Available  ID
# 0   10 Seats available   1
# 1   25 Seats available   2
# 2   20 Seats available   3
# 3    4 Seats available   4
# 4   32 Seats available   5
# 5    5 Seats available   6
# 6   30 Seats available   7
# 7   25 Seats available   8
# 8    9 Seats available   9
# 9   20 Seats available  10
# 10  20 Seats available  11
# 11  49 Seats available  12
# 12  20 Seats available  13
# 13  12 Seats available  14
# 14  35 Seats available  15
# 15  46 Seats available  16
# 16  21 Seats available  17
# 17  50 Seats available  18
# 18  20 Seats available  19
# 19  22 Seats available  20
# 20  29 Seats available  21
# 21  24 Seats available  22
# 22  22 Seats available  23
# 23   6 Seats available  24
# 24  11 Seats available  25
# 25  21 Seats available  26
# 26  20 Seats available  27
# 27  25 Seats available  28
# 28  16 Seats available  29
# 29  37 Seats available  30
# 30  45 Seats available  31
# 31  41 Seats available  32
# 32  40 Seats available  33
# 33  61 Seats available  34
# 34  20 Seats available  35
# 35  20 Seats available  36
# 36  20 Seats available  37
# 37  15 Seats available  38
# 38  60 Seats available  39
# 39  26 Seats available  40
