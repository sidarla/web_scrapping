# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('https://www.redbus.in/online-booking/ktcl/?utm_source=rtchometile')
time.sleep(2)  # Let the page load

body = driver.find_element(By.TAG_NAME, "body")
telangana_buses_list=[]
telangana_buses_links=[]

for page_num in range(1, 6):  # Loop over pages (or scroll actions)
    # Get all elements with class 'route'
    result1 = driver.find_elements(By.CSS_SELECTOR, "a[class='route']")
    
    # Print the text of each element found
    for element in result1:
        telangana_buses_list.append(element.text)
        telangana_buses_links.append(element.get_attribute('href'))
    
    # Scroll down the page
    body.send_keys(Keys.PAGE_DOWN)
    time.sleep(2)  # Give some time for new elements to load
    
    # Find an element matching the XPATH and click (if needed)
    result = driver.find_elements(By.XPATH, f"//div[contains(text(),'{page_num+1}')]")
    #print(result)
    if result:
        result[0].click()  # Click the first element found with matching XPATH

#driver.quit()  # Close the browser after task completion

# %%
for i in telangana_buses_links:
    print(i)
# Out:
# https://www.redbus.in/bus-tickets/pune-to-goa
# https://www.redbus.in/bus-tickets/goa-to-pune
# https://www.redbus.in/bus-tickets/mumbai-to-goa
# https://www.redbus.in/bus-tickets/goa-to-mumbai
# https://www.redbus.in/bus-tickets/belagavi-to-goa
# https://www.redbus.in/bus-tickets/bangalore-to-goa
# https://www.redbus.in/bus-tickets/goa-to-bangalore
# https://www.redbus.in/bus-tickets/pandharpur-to-goa
# https://www.redbus.in/bus-tickets/goa-to-belagavi
# https://www.redbus.in/bus-tickets/goa-to-kolhapur-maharashtra
# https://www.redbus.in/bus-tickets/solapur-to-goa
# https://www.redbus.in/bus-tickets/goa-to-pandharpur
# https://www.redbus.in/bus-tickets/goa-to-solapur
# https://www.redbus.in/bus-tickets/calangute-goa-to-goa-airport
# https://www.redbus.in/bus-tickets/goa-to-sangola
# https://www.redbus.in/bus-tickets/sangola-to-goa
# https://www.redbus.in/bus-tickets/calangute-goa-to-mopa-airport
# https://www.redbus.in/bus-tickets/goa-airport-to-calangute-goa
# https://www.redbus.in/bus-tickets/mopa-airport-to-calangute-goa
# https://www.redbus.in/bus-tickets/shimoga-to-goa
# https://www.redbus.in/bus-tickets/marcel-to-belagavi
# https://www.redbus.in/bus-tickets/ponda-to-belagavi
# https://www.redbus.in/bus-tickets/belagavi-to-marcel
# https://www.redbus.in/bus-tickets/belagavi-to-ponda
# https://www.redbus.in/bus-tickets/panaji-to-goa-airport
# https://www.redbus.in/bus-tickets/goa-to-sangli
# https://www.redbus.in/bus-tickets/goa-to-mopa-airport
# https://www.redbus.in/bus-tickets/goa-to-miraj
# https://www.redbus.in/bus-tickets/margoa-to-mopa-airport
# https://www.redbus.in/bus-tickets/mopa-airport-to-goa
# https://www.redbus.in/bus-tickets/mopa-airport-to-margoa
# https://www.redbus.in/bus-tickets/goa-airport-to-panaji
# https://www.redbus.in/bus-tickets/shirdi-to-goa
# https://www.redbus.in/bus-tickets/goa-to-shimoga
# https://www.redbus.in/bus-tickets/goa-to-satara
# https://www.redbus.in/bus-tickets/panaji-to-mopa-airport
# https://www.redbus.in/bus-tickets/saquelim-to-belagavi
# https://www.redbus.in/bus-tickets/goa-to-goa-airport
# https://www.redbus.in/bus-tickets/goa-to-shirdi
# https://www.redbus.in/bus-tickets/goa-airport-to-goa
# https://www.redbus.in/bus-tickets/calangute-goa-to-goa
# https://www.redbus.in/bus-tickets/mopa-airport-to-panaji
# https://www.redbus.in/bus-tickets/goa-to-calangute-goa
# https://www.redbus.in/bus-tickets/belagavi-to-saquelim
# https://www.redbus.in/bus-tickets/calangute-goa-to-panaji

# %%
for i in telangana_buses_list:
    print(i)
# Out:
# Pune to Goa
# Goa to Pune
# Mumbai to Goa
# Goa to Mumbai
# Belagavi to Goa
# Bangalore to Goa
# Goa to Bangalore
# Pandharpur to Goa
# Goa to Belagavi
# Goa to Kolhapur(Maharashtra)
# Solapur to Goa
# Goa to Pandharpur
# Goa to Solapur
# Calangute (goa) to Goa Airport
# Goa to Sangola (Solapur)
# Sangola (Solapur) to Goa
# Calangute (goa) to Mopa Airport
# Goa Airport to Calangute (goa)
# Mopa Airport to Calangute (goa)
# Shivamogga to Goa
# Marcel to Belagavi
# Ponda to Belagavi
# Belagavi to Marcel
# Belagavi to Ponda
# Panaji to Goa Airport
# Goa to Sangli
# Goa to Mopa Airport
# Goa to Miraj
# Margao to Mopa Airport
# Mopa Airport to Goa
# Mopa Airport to Margao
# Goa Airport to Panaji
# Shirdi to Goa
# Goa to Shivamogga
# Goa to Satara
# Panaji to Mopa Airport
# Saquelim to Belagavi
# Goa to Goa Airport
# Goa to Shirdi
# Goa Airport to Goa
# Calangute (goa) to Goa
# Mopa Airport to Panaji
# Goa to Calangute (goa)
# Belagavi to Saquelim
# Calangute (goa) to Panaji

# %%
 # Let the page load
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('https://www.redbus.in/bus-tickets/pune-to-goa?fromCityId=130&toCityId=210&fromCityName=Pune&toCityName=Goa&busType=Any&srcCountry=IND&destCountry=IND&onward=22-Nov-2024')
time.sleep(2)  # Let the page load

body = driver.find_element(By.TAG_NAME, "body")
#hide_details_TS=driver.find_elements(By.XPATH, "//div[@class='button']")
#if hide_details_TS:
    #hide_details_TS[0].click()
for i in range(40):
    buses_list_result = driver.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type_result = driver.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    departing_time_result = driver.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    reaching_time_result = driver.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    duration_list_result = driver.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")
    star_rating_result = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
    price_result = driver.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats_available_result = driver.find_elements(By.XPATH, "//div[@class='seat-left m-top-30']")
    body.send_keys(Keys.PAGE_DOWN)
buses_list=[]
bus_type_list=[]
departing_time_list=[]
reaching_time_list=[]
duration_list=[]
star_rating_list=[]
price_list=[]
seats_available_list=[]
for i in buses_list_result:
    buses_list.append(i.text)
for i in bus_type_result:
    bus_type_list.append(i.text)
for i in departing_time_result:
    departing_time_list.append(i.text)
for i in reaching_time_result:
    reaching_time_list.append(i.text)
for i in duration_list_result:
    duration_list.append(i.text)
for i in star_rating_result:
    star_rating_list.append(i.text)
for i in price_result:
    price_list.append(i.text)
for i in seats_available_result:
    seats_available_list.append(i.text)

# %%
min_value=min(len(buses_list),len(bus_type_list),len(departing_time_list),len(reaching_time_list),len(duration_list),len(star_rating_list),len(price_list),len(seats_available_list))
print(min_value)
# Out:
# 59

# %%
busname=[]
bustype=[]
departing_time=[]
duration=[]
reaching_time=[]
star_rating=[]
price=[]
seats_available=[]
route_link=[]
route_name=[]
for i in range(min_value):
    busname.append(buses_list[i])
    bustype.append(bus_type_list[i])
    departing_time.append(departing_time_list[i])
    duration.append(duration_list[i])
    reaching_time.append(reaching_time_list[i])
    star_rating.append(star_rating_list[i])
    price.append(price_list[i])
    seats_available.append(seats_available_list[i])
    route_link.append("https://www.redbus.in/bus-tickets/pune-to-goa")
    route_name.append("Pune to Goa")

# %%
import pandas as pd

# Dictionary with data
data = {
    'route_name': route_name,
    'route_link': route_link,
    'busname':busname,
    'bustype':bustype,
    'duparting_time': departing_time,
    'duration':duration,
    'reaching_time': reaching_time,
    'star_rating': star_rating,
    'Price': price,
    'Seats Available': seats_available
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Add automated ID column
df['ID'] = range(1, len(df) + 1)

print(df)
# Out:
#      route_name                                     route_link  \
# 0   Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 1   Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 2   Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 3   Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 4   Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 5   Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 6   Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 7   Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 8   Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 9   Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 10  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 11  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 12  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 13  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 14  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 15  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 16  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 17  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 18  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 19  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 20  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 21  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 22  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 23  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 24  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 25  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 26  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 27  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 28  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 29  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 30  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 31  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 32  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 33  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 34  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 35  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 36  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 37  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 38  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 39  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 40  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 41  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 42  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 43  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 44  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 45  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 46  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 47  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 48  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 49  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 50  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 51  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 52  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 53  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 54  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 55  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 56  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 57  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
# 58  Pune to Goa  https://www.redbus.in/bus-tickets/pune-to-goa
#
#                                 busname  \
# 0                   Laxmi-Princess Nova
# 1                     IntrCity SmartBus
# 2                     IntrCity SmartBus
# 3                     IntrCity SmartBus
# 4                        Ashray Travels
# 5                     IntrCity SmartBus
# 6             Dolphin Travel House (37)
# 7                     IntrCity SmartBus
# 8                   Gogte Anand Travels
# 9                          Ashray Grand
# 10           Sangitam Travels Tanzanite
# 11                        Gogte Travels
# 12                  Gogte Anand Travels
# 13                    IntrCity SmartBus
# 14                         Zingbus Plus
# 15                        Atmaram Gobus
# 16                Prasanna - Purple Bus
# 17                   Ashray Vip Yellows
# 18                      Ashray Amrutyog
# 19            Dolphin Travel House (38)
# 20                        Atmaram Gobus
# 21                         Zingbus Plus
# 22                     Indumati Travels
# 23                        Gogte Travels
# 24                    IntrCity SmartBus
# 25                     KVT Narmada Benz
# 26                Laxmi Empress Stellar
# 27                     Shreyash Travels
# 28                Prasanna - Purple Bus
# 29                Prasanna - Purple Bus
# 30                Prasanna - Purple Bus
# 31              Abhishek Vishal Travels
# 32               Gogte Travels (Manish)
# 33  Traveltime Travels (St.Christopher)
# 34                     Humsafar Travels
# 35          Traveltime Travels (Kelkar)
# 36                        Atmaram Gobus
# 37                    Laxmi Queen Prime
# 38                        Gogte Shreyas
# 39              Abhishek Vishal Travels
# 40                     KVT Narmada Benz
# 41                Ashray Atmaram Divine
# 42                     Laxmi Queen Asta
# 43                          VRL Travels
# 44                 Dolphin travel house
# 45              Abhishek Vishal Travels
# 46                      PSR Travels Goa
# 47                     Humsafar Travels
# 48                      Gujarat Travels
# 49            Dolphin Travel House (39)
# 50                        Gogte Travels
# 51                        Gogte Travels
# 52  Traveltime Travels (St.Christopher)
# 53                       Kokan Holidays
# 54                       Laxmi holidays
# 55                       Laxmi holidays
# 56   Shivrameshwar Bane Tours & Travels
# 57                PVS Tours and Travels
# 58                  SAI BHAKTI HOLIDAYS
#
#                                        bustype duparting_time duration  \
# 0               Non A/C Seater / Sleeper (2+1)          20:00  11h 15m
# 1        Bharat Benz A/C Seater /Sleeper (2+1)          21:15  10h 50m
# 2                             AC Sleeper (2+1)          22:15  10h 30m
# 3                Bharat Benz A/C Sleeper (2+1)          22:30  11h 05m
# 4                Bharat Benz A/C Sleeper (2+1)          21:05  11h 25m
# 5                             AC Sleeper (2+1)          22:00  11h 35m
# 6                Bharat Benz A/C Sleeper (2+1)          19:45  10h 15m
# 7                             AC Sleeper (2+1)          22:15  10h 30m
# 8   Volvo Multi-Axle I-Shift A/C Sleeper (2+1)          21:15  10h 40m
# 9           Volvo Multi-Axle A/C Sleeper (2+1)          23:00  11h 45m
# 10                           A/C Sleeper (2+1)          21:00  09h 45m
# 11                           A/C Sleeper (2+1)          20:15  10h 45m
# 12          Volvo Multi-Axle A/C Sleeper (2+1)          23:30  10h 55m
# 13               Bharat Benz A/C Sleeper (2+1)          20:30  10h 55m
# 14                            AC Sleeper (2+1)          22:45  11h 10m
# 15                        VE A/C Sleeper (2+1)          22:30  10h 15m
# 16                        VE A/C Sleeper (2+1)          22:30  11h 00m
# 17                           A/C Sleeper (2+1)          20:35  11h 25m
# 18                           A/C Sleeper (2+1)          22:05  11h 25m
# 19               Bharat Benz A/C Sleeper (2+1)          20:30  11h 00m
# 20                        VE A/C Sleeper (2+1)          21:00  10h 30m
# 21               Bharat Benz A/C Sleeper (2+1)          22:50  11h 30m
# 22                           A/C Sleeper (2+1)          22:20  10h 10m
# 23                           A/C Sleeper (2+1)          20:40  10h 45m
# 24                            AC Sleeper (2+1)          23:35  10h 40m
# 25               Bharat Benz A/C Sleeper (2+1)          22:00  10h 00m
# 26                       NON A/C Sleeper (2+1)          21:00  11h 00m
# 27               Bharat Benz A/C Sleeper (2+1)          21:45  10h 45m
# 28                        VE A/C Sleeper (2+1)          21:45  11h 00m
# 29                        VE A/C Sleeper (2+1)          21:30  11h 00m
# 30                        VE A/C Sleeper (2+1)          22:15  11h 15m
# 31                     NON A/C Push Back (2+2)          21:25  09h 45m
# 32                         Non AC Seater (2+2)          19:20  12h 10m
# 33                         Non AC Seater (2+2)          20:00  11h 00m
# 34               Bharat Benz A/C Sleeper (2+1)          22:50  10h 40m
# 35               NON A/C Seater/ Sleeper (2+1)          21:15  11h 30m
# 36                       NON A/C Sleeper (2+1)          20:30  10h 30m
# 37                           A/C Sleeper (2+1)          20:30  11h 00m
# 38                           A/C Sleeper (2+1)          21:45  11h 15m
# 39                           A/C Sleeper (2+1)          00:15  10h 00m
# 40               Bharat Benz A/C Sleeper (2+1)          21:25  10h 36m
# 41                       NON A/C Sleeper (2+1)          19:50  10h 55m
# 42                           A/C Sleeper (2+1)          21:30  10h 30m
# 43                           A/C Sleeper (2+1)          23:30  10h 15m
# 44                           A/C Sleeper (2+1)          23:45  11h 00m
# 45                           A/C Sleeper (2+1)          23:00  09h 40m
# 46                           A/C Sleeper (2+1)          23:45  09h 45m
# 47               Bharat Benz A/C Sleeper (2+1)          22:15  10h 45m
# 48                            AC Sleeper (2+1)          23:55  10h 45m
# 49                           A/C Sleeper (2+1)          21:45  10h 45m
# 50                           A/C Sleeper (2+1)          20:15  11h 30m
# 51                           A/C Sleeper (2+1)          20:40  11h 30m
# 52                         Non AC Seater (2+2)          20:00  11h 00m
# 53              NON A/C Seater Push Back (2+2)          21:30  12h 15m
# 54       Bharat Benz A/C Seater /Sleeper (2+1)          20:30  11h 50m
# 55       Bharat Benz A/C Seater /Sleeper (2+1)          19:00  15h 45m
# 56                           A/C Sleeper (2+1)          00:20  09h 55m
# 57                  A/C Seater Push Back (2+2)          22:45  10h 00m
# 58                           A/C Sleeper (2+1)          21:10  10h 35m
#
#    reaching_time star_rating     Price     Seats Available  ID
# 0          07:15         4.1   INR 999  10 Seats available   1
# 1          08:05         4.5  INR 1068  12 Seats available   2
# 2          08:45         4.1  INR 1083  10 Seats available   3
# 3          09:35         4.2  INR 1440  11 Seats available   4
# 4          08:30         4.2  INR 1599   8 Seats available   5
# 5          09:35         4.4  INR 1503  11 Seats available   6
# 6          06:00         4.1  INR 1521  11 Seats available   7
# 7          08:45         4.3  INR 1563   8 Seats available   8
# 8          07:55         4.0  INR 1499  10 Seats available   9
# 9          10:45         4.1  INR 1700  13 Seats available  10
# 10         06:45         4.3  INR 1457   6 Seats available  11
# 11         07:00         4.2  INR 1409   8 Seats available  12
# 12         10:25         4.1  INR 1599  11 Seats available  13
# 13         07:25         4.2  INR 1520   7 Seats available  14
# 14         09:55         4.2      1287  24 Seats available  15
# 15         08:45         4.6  INR 1499   3 Seats available  16
# 16         09:30         4.2  INR 1820   4 Seats available  17
# 17         08:00         4.2  INR 2020   7 Seats available  18
# 18         09:30         4.4  INR 1599   9 Seats available  19
# 19         07:30         4.4  INR 1419  21 Seats available  20
# 20         07:30         4.7  INR 1450   4 Seats available  21
# 21         10:20         4.3      1810  10 Seats available  22
# 22         08:30         4.2      1330   7 Seats available  23
# 23         07:25         4.0  INR 1499   2 Seats available  24
# 24         10:15         4.4  INR 1843   7 Seats available  25
# 25         08:00         4.0  INR 1600   9 Seats available  26
# 26         08:00         3.8  INR 1499  18 Seats available  27
# 27         08:30         3.6      1273   2 Seats available  28
# 28         08:45         3.2  INR 2020  15 Seats available  29
# 29         08:30         3.7  INR 1820  14 Seats available  30
# 30         09:30         3.7  INR 1820  10 Seats available  31
# 31         07:10         3.2   INR 800  17 Seats available  32
# 32         07:30         3.0   INR 601  12 Seats available  33
# 33         07:00         3.2   INR 900  23 Seats available  34
# 34         09:30         3.4  INR 1440   6 Seats available  35
# 35         08:45         3.3  INR 1050   6 Seats available  36
# 36         07:00         3.8  INR 1400   6 Seats available  37
# 37         07:30         3.7  INR 1999   9 Seats available  38
# 38         09:00         3.5  INR 1399   5 Seats available  39
# 39         10:15         3.2  INR 1499   7 Seats available  40
# 40         08:01         3.7  INR 1600   9 Seats available  41
# 41         06:45         3.8  INR 1600    1 Seat available  42
# 42         08:00         3.8  INR 2099  10 Seats available  43
# 43         09:45         3.0  INR 1370   8 Seats available  44
# 44         10:45         3.7  INR 1419  24 Seats available  45
# 45         08:40         3.4  INR 1499  12 Seats available  46
# 46         09:30         3.6  INR 1399  12 Seats available  47
# 47         09:00         3.4  INR 1430   6 Seats available  48
# 48         10:40         2.6  INR 1200   6 Seats available  49
# 49         08:30         2.5  INR 1419  19 Seats available  50
# 50         07:45         3.9  INR 1809   3 Seats available  51
# 51         08:10         3.9  INR 1499   2 Seats available  52
# 52         07:00         3.2   INR 900  18 Seats available  53
# 53         09:45         1.1  INR 3000   2 Seats available  54
# 54         08:20         4.4  INR 2817    1 Seat available  55
# 55         10:45         4.4  INR 1433    1 Seat available  56
# 56         10:15         3.9  INR 5000  30 Seats available  57
# 57         08:45         3.4  INR 3000  45 Seats available  58
# 58         07:45         2.2  INR 5000  30 Seats available  59

# %%
 # Let the page load
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('https://www.redbus.in/bus-tickets/goa-to-pune?fromCityId=210&toCityId=130&fromCityName=Goa&toCityName=Pune&busType=Any&srcCountry=IND&destCountry=IND&onward=22-Nov-2024')
time.sleep(2)  # Let the page load

body = driver.find_element(By.TAG_NAME, "body")
#hide_details_TS=driver.find_elements(By.XPATH, "//div[@class='button']")
#if hide_details_TS:
    #hide_details_TS[0].click()
for i in range(40):
    buses_list_result = driver.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type_result = driver.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    departing_time_result = driver.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    reaching_time_result = driver.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    duration_list_result = driver.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")
    star_rating_result = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
    price_result = driver.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats_available_result = driver.find_elements(By.XPATH, "//div[@class='seat-left m-top-30']")
    body.send_keys(Keys.PAGE_DOWN)
buses_list=[]
bus_type_list=[]
departing_time_list=[]
reaching_time_list=[]
duration_list=[]
star_rating_list=[]
price_list=[]
seats_available_list=[]
for i in buses_list_result:
    buses_list.append(i.text)
for i in bus_type_result:
    bus_type_list.append(i.text)
for i in departing_time_result:
    departing_time_list.append(i.text)
for i in reaching_time_result:
    reaching_time_list.append(i.text)
for i in duration_list_result:
    duration_list.append(i.text)
for i in star_rating_result:
    star_rating_list.append(i.text)
for i in price_result:
    price_list.append(i.text)
for i in seats_available_result:
    seats_available_list.append(i.text)

# %%
min_value=min(len(buses_list),len(bus_type_list),len(departing_time_list),len(reaching_time_list),len(duration_list),len(star_rating_list),len(price_list),len(seats_available_list))
print(min_value)
# Out:
# 74

# %%
busname=[]
bustype=[]
departing_time=[]
duration=[]
reaching_time=[]
star_rating=[]
price=[]
seats_available=[]
route_link=[]
route_name=[]
for i in range(min_value):
    busname.append(buses_list[i])
    bustype.append(bus_type_list[i])
    departing_time.append(departing_time_list[i])
    duration.append(duration_list[i])
    reaching_time.append(reaching_time_list[i])
    star_rating.append(star_rating_list[i])
    price.append(price_list[i])
    seats_available.append(seats_available_list[i])
    route_link.append("https://www.redbus.in/bus-tickets/goa-to-pune")
    route_name.append("Goa to Pune")

# %%
import pandas as pd

# Dictionary with data
data = {
    'route_name': route_name,
    'route_link': route_link,
    'busname':busname,
    'bustype':bustype,
    'duparting_time': departing_time,
    'duration':duration,
    'reaching_time': reaching_time,
    'star_rating': star_rating,
    'Price': price,
    'Seats Available': seats_available
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Add automated ID column
df['ID'] = range(1, len(df) + 1)

print(df)
# Out:
#      route_name                                     route_link  \
# 0   Goa to Pune  https://www.redbus.in/bus-tickets/goa-to-pune
# 1   Goa to Pune  https://www.redbus.in/bus-tickets/goa-to-pune
# 2   Goa to Pune  https://www.redbus.in/bus-tickets/goa-to-pune
# 3   Goa to Pune  https://www.redbus.in/bus-tickets/goa-to-pune
# 4   Goa to Pune  https://www.redbus.in/bus-tickets/goa-to-pune
# ..          ...                                            ...
# 69  Goa to Pune  https://www.redbus.in/bus-tickets/goa-to-pune
# 70  Goa to Pune  https://www.redbus.in/bus-tickets/goa-to-pune
# 71  Goa to Pune  https://www.redbus.in/bus-tickets/goa-to-pune
# 72  Goa to Pune  https://www.redbus.in/bus-tickets/goa-to-pune
# 73  Goa to Pune  https://www.redbus.in/bus-tickets/goa-to-pune
#
#                                               busname  \
# 0   Kadamba Transport Corporation Limited (KTCL) -...
# 1                                      Ashray Travels
# 2                          Sangitam Travels Tanzanite
# 3                                        Ashray Grand
# 4                                   IntrCity SmartBus
# ..                                                ...
# 69                                    AAINATH TRAVELS
# 70                                     Laxmi holidays
# 71                            Jolly Tours and Travels
# 72                              PVS Tours and Travels
# 73                                     Kokan Holidays
#
#                                     bustype duparting_time duration  \
# 0                         Non AC Seater 2+2          18:00  14h 00m
# 1            Non A/C Seater / Sleeper (2+1)          20:00  10h 30m
# 2                         A/C Sleeper (2+1)          21:00  10h 30m
# 3        Volvo Multi-Axle A/C Sleeper (2+1)          22:00  11h 30m
# 4                          AC Sleeper (2+1)          18:30  10h 55m
# ..                                      ...            ...      ...
# 69                        A/C Sleeper (2+1)          21:30  09h 00m
# 70    Bharat Benz A/C Seater /Sleeper (2+1)          21:00  10h 00m
# 71                         A/C Seater (2+2)          18:30  11h 15m
# 72  Volvo 9600 Multi-Axle A/C Sleeper (2+1)          20:00  10h 00m
# 73                    NON A/C Sleeper (2+1)          18:02  11h 58m
#
#    reaching_time star_rating     Price     Seats Available  ID
# 0          08:00         4.0   INR 600  22 Seats available   1
# 1          06:30         4.4   INR 500  19 Seats available   2
# 2          07:30         4.4   INR 905  17 Seats available   3
# 3          09:30         4.1  INR 1000  24 Seats available   4
# 4          05:25         4.6   INR 900  14 Seats available   5
# ..           ...         ...       ...                 ...  ..
# 69         06:30         1.2   INR 900    1 Seat available  70
# 70         07:00         4.4  INR 4510  40 Seats available  71
# 71         05:45         3.6  INR 1799  36 Seats available  72
# 72         06:00         3.4  INR 4000  32 Seats available  73
# 73         06:00         1.8  INR 3000  28 Seats available  74
#
# [74 rows x 11 columns]

# %%
 # Let the page load
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('https://www.redbus.in/bus-tickets/mumbai-to-goa?fromCityId=462&toCityId=210&fromCityName=Mumbai&toCityName=Goa&busType=Any&onward=22-Nov-2024')
time.sleep(2)  # Let the page load

body = driver.find_element(By.TAG_NAME, "body")
#hide_details_TS=driver.find_elements(By.XPATH, "//div[@class='button']")
#if hide_details_TS:
    #hide_details_TS[0].click()
for i in range(40):
    buses_list_result = driver.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type_result = driver.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    departing_time_result = driver.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    reaching_time_result = driver.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    duration_list_result = driver.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")
    star_rating_result = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
    price_result = driver.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats_available_result = driver.find_elements(By.XPATH, "//div[@class='seat-left m-top-30']")
    body.send_keys(Keys.PAGE_DOWN)
buses_list=[]
bus_type_list=[]
departing_time_list=[]
reaching_time_list=[]
duration_list=[]
star_rating_list=[]
price_list=[]
seats_available_list=[]
for i in buses_list_result:
    buses_list.append(i.text)
for i in bus_type_result:
    bus_type_list.append(i.text)
for i in departing_time_result:
    departing_time_list.append(i.text)
for i in reaching_time_result:
    reaching_time_list.append(i.text)
for i in duration_list_result:
    duration_list.append(i.text)
for i in star_rating_result:
    star_rating_list.append(i.text)
for i in price_result:
    price_list.append(i.text)
for i in seats_available_result:
    seats_available_list.append(i.text)

# %%
min_value=min(len(buses_list),len(bus_type_list),len(departing_time_list),len(reaching_time_list),len(duration_list),len(star_rating_list),len(price_list),len(seats_available_list))
print(min_value)
# Out:
# 50

# %%
busname=[]
bustype=[]
departing_time=[]
duration=[]
reaching_time=[]
star_rating=[]
price=[]
seats_available=[]
route_link=[]
route_name=[]
for i in range(min_value):
    busname.append(buses_list[i])
    bustype.append(bus_type_list[i])
    departing_time.append(departing_time_list[i])
    duration.append(duration_list[i])
    reaching_time.append(reaching_time_list[i])
    star_rating.append(star_rating_list[i])
    price.append(price_list[i])
    seats_available.append(seats_available_list[i])
    route_link.append("https://www.redbus.in/bus-tickets/mumbai-to-goa")
    route_name.append("Mumbai to Goa")

# %%
import pandas as pd

# Dictionary with data
data = {
    'route_name': route_name,
    'route_link': route_link,
    'busname':busname,
    'bustype':bustype,
    'duparting_time': departing_time,
    'duration':duration,
    'reaching_time': reaching_time,
    'star_rating': star_rating,
    'Price': price,
    'Seats Available': seats_available
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Add automated ID column
df['ID'] = range(1, len(df) + 1)

print(df)
# Out:
#        route_name                                       route_link  \
# 0   Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 1   Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 2   Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 3   Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 4   Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 5   Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 6   Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 7   Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 8   Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 9   Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 10  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 11  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 12  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 13  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 14  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 15  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 16  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 17  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 18  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 19  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 20  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 21  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 22  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 23  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 24  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 25  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 26  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 27  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 28  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 29  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 30  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 31  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 32  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 33  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 34  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 35  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 36  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 37  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 38  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 39  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 40  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 41  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 42  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 43  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 44  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 45  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 46  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 47  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 48  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
# 49  Mumbai to Goa  https://www.redbus.in/bus-tickets/mumbai-to-goa
#
#                                busname                                bustype  \
# 0                    IntrCity SmartBus                       AC Sleeper (2+1)
# 1                    IntrCity SmartBus                       AC Sleeper (2+1)
# 2               Atmaram Manish Travels                   NON A/C Seater (2+2)
# 3    AdShubhra Sharma Tourist Services                      A/C Sleeper (2+1)
# 4            Dolphin Travel House (38)          Bharat Benz A/C Sleeper (2+1)
# 5                    IntrCity SmartBus                       AC Sleeper (2+1)
# 6          Shubham Vailankanni Travels                   VE A/C Sleeper (2+1)
# 7              AdMascot Travels(M.Dev)                      A/C Sleeper (2+1)
# 8                         Zingbus Plus                   VE A/C Sleeper (2+1)
# 9            Dolphin Travel House (37)          Bharat Benz A/C Sleeper (2+1)
# 10                        Zingbus Plus                       AC Sleeper (2+1)
# 11             Konkan Travels National                      A/C Sleeper (2+1)
# 12              Atmaram Manish Travels                      A/C Sleeper (2+1)
# 13                        Zingbus Plus          Bharat Benz A/C Sleeper (2+1)
# 14        Rajdhani Travels Corporation                      A/C Sleeper (2+1)
# 15                      Laxmi holidays  Bharat Benz A/C Seater /Sleeper (2+1)
# 16         Shubham Vailankanni Travels                   VE A/C Sleeper (2+1)
# 17           Dolphin Travel House (39)                      A/C Sleeper (2+1)
# 18            Shubham Saijyoti Travels                      A/C Sleeper (2+1)
# 19          Global Travel Agency (GTA)                      A/C Sleeper (2+1)
# 20             Konkan Travels National                  NON A/C Sleeper (2+1)
# 21                Dolphin travel house          Bharat Benz A/C Sleeper (2+1)
# 22                Dolphin travel house                      A/C Sleeper (2+1)
# 23               Mascot Travels(M.Dev)                      A/C Sleeper (2+1)
# 24                     Vaibhav travels                      A/C Sleeper (2+1)
# 25           Dolphin Travel House (40)                      A/C Sleeper (2+1)
# 26              Naik Tours And Travels                  NON A/C Sleeper (2+1)
# 27  Shivrameshwar Bane Tours & Travels                      A/C Sleeper (2+1)
# 28               Sanvi Travels - Shree                      A/C Sleeper (2+1)
# 29              Konkan Travels Mujawar                  NON A/C Sleeper (2+1)
# 30              Atmaram Manish Travels                      A/C Sleeper (2+1)
# 31             Abhishek Vishal Travels                      A/C Sleeper (2+1)
# 32                Dolphin travel house                      A/C Sleeper (2+1)
# 33      Shubhra Sharma Tourist Service                      A/C Sleeper (2+1)
# 34                     Vaibhav travels                      A/C Sleeper (2+1)
# 35               PVS Tours and Travels             A/C Seater Push Back (2+2)
# 36              Konkan Tours & Travels             A/C Seater / Sleeper (2+1)
# 37             Abhishek Vishal Travels                NON A/C Push Back (2+2)
# 38                      Roshan Travels                      A/C Sleeper (2+1)
# 39                     Gujarat Travels                       AC Sleeper (2+1)
# 40                         VRL Travels                      A/C Sleeper (2+1)
# 41             Abhishek Vishal Travels                      A/C Sleeper (2+1)
# 42                       Anand Travels                  NON A/C Sleeper (2+1)
# 43                   Karmarkar Travels             A/C Seater / Sleeper (2+1)
# 44               Mascot Travels(Patil)                      A/C Sleeper (2+1)
# 45                 SAI BHAKTI HOLIDAYS                      A/C Sleeper (2+1)
# 46                 SAI BHAKTI HOLIDAYS                      A/C Sleeper (2+1)
# 47              Manish Muskaan Travels                  NON A/C Sleeper (2+1)
# 48               GANESH PRASAD TRAVELS                   NON A/C Seater (2+2)
# 49               GANESH PRASAD TRAVELS                       A/C Seater (2+2)
#
#    duparting_time duration reaching_time star_rating     Price  \
# 0           16:30  16h 15m         08:45         4.5  INR 1091
# 1           17:15  15h 30m         08:45         4.4  INR 1404
# 2           15:00  16h 15m         07:15         4.6   INR 800
# 3           16:46  17h 45m         10:31         4.0  INR 1400
# 4           14:30  17h 00m         07:30         4.0  INR 1419
# 5           19:40  14h 35m         10:15         4.4  INR 1843
# 6           17:30  16h 45m         10:15         4.5  INR 1500
# 7           17:30  17h 15m         10:45         3.7  INR 1300
# 8           20:00  15h 55m         11:55         4.4      1484
# 9           13:00  17h 00m         06:00         4.4  INR 1521
# 10          17:00  16h 55m         09:55         4.3  INR 1391
# 11          18:00  16h 55m         10:55         4.1  INR 1199
# 12          16:50  16h 25m         09:15         4.1  INR 1400
# 13          18:00  16h 55m         10:55         4.4      1754
# 14          20:55  13h 10m         10:05         5.0      1999
# 15          18:05  16h 40m         10:45         4.4  INR 1429
# 16          21:00  15h 35m         12:35         3.4  INR 1600
# 17          15:45  16h 45m         08:30         3.5  INR 1419
# 18          19:30  16h 00m         11:30         3.8  INR 1400
# 19          17:50  17h 45m         11:35         3.9  INR 1099
# 20          19:25  14h 20m         09:45         3.8  INR 1199
# 21          21:30  15h 45m         13:15         3.7  INR 1519
# 22          19:00  16h 45m         11:45         3.4  INR 1419
# 23          19:00  17h 00m         12:00         3.6  INR 1351
# 24          18:00  18h 00m         12:00         3.8  INR 1500
# 25          20:00  17h 15m         13:15         3.3  INR 1419
# 26          14:25  16h 20m         06:45         3.8  INR 1200
# 27          18:00  16h 15m         10:15         3.9  INR 5000
# 28          17:00  16h 30m         09:30         3.6  INR 1400
# 29          18:50  16h 55m         11:45         3.6  INR 1099
# 30          16:50  16h 15m         09:05         3.3  INR 1400
# 31          17:20  16h 55m         10:15         3.3  INR 1499
# 32          17:45  17h 00m         10:45         3.6  INR 1419
# 33          16:50  17h 30m         10:20         3.8  INR 1400
# 34          19:15  16h 15m         11:30         3.1  INR 3000
# 35          18:35  14h 10m         08:45         3.4  INR 3000
# 36          20:00  16h 55m         12:55         3.5  INR 1199
# 37          14:50  16h 20m         07:10         2.5   INR 800
# 38          16:45  16h 30m         09:15         2.7  INR 1400
# 39          20:30  14h 10m         10:40         2.9  INR 1300
# 40          19:00  14h 45m         09:45         2.8  INR 1370
# 41          16:00  16h 40m         08:40         1.9  INR 1499
# 42          19:00  13h 00m         08:00         2.3  INR 1000
# 43          17:30  17h 45m         11:15         2.5  INR 1000
# 44          16:15  17h 00m         09:15         2.1  INR 1300
# 45          15:30  16h 15m         07:45         2.2  INR 5000
# 46          19:15  15h 00m         10:15         2.2  INR 5000
# 47          18:00  15h 00m         09:00         2.4  INR 3000
# 48          20:00  13h 55m         09:55         2.5  INR 2500
# 49          21:00  13h 55m         10:55         2.5  INR 2500
#
#        Seats Available  ID
# 0    4 Seats available   1
# 1    7 Seats available   2
# 2   11 Seats available   3
# 3   17 Seats available   4
# 4   18 Seats available   5
# 5    7 Seats available   6
# 6    4 Seats available   7
# 7   23 Seats available   8
# 8   10 Seats available   9
# 9   11 Seats available  10
# 10  24 Seats available  11
# 11   8 Seats available  12
# 12  11 Seats available  13
# 13  10 Seats available  14
# 14    1 Seat available  15
# 15    1 Seat available  16
# 16  23 Seats available  17
# 17  18 Seats available  18
# 18  19 Seats available  19
# 19  19 Seats available  20
# 20   8 Seats available  21
# 21  26 Seats available  22
# 22  24 Seats available  23
# 23  16 Seats available  24
# 24   2 Seats available  25
# 25  18 Seats available  26
# 26   8 Seats available  27
# 27  30 Seats available  28
# 28  17 Seats available  29
# 29  16 Seats available  30
# 30   4 Seats available  31
# 31   7 Seats available  32
# 32  24 Seats available  33
# 33  17 Seats available  34
# 34  36 Seats available  35
# 35  45 Seats available  36
# 36  34 Seats available  37
# 37  15 Seats available  38
# 38  17 Seats available  39
# 39   5 Seats available  40
# 40   8 Seats available  41
# 41  12 Seats available  42
# 42   6 Seats available  43
# 43  31 Seats available  44
# 44  20 Seats available  45
# 45  30 Seats available  46
# 46  30 Seats available  47
# 47  30 Seats available  48
# 48  49 Seats available  49
# 49  49 Seats available  50

# %%
 # Let the page load
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('https://www.redbus.in/bus-tickets/goa-to-mumbai?fromCityId=210&toCityId=462&fromCityName=Goa&toCityName=Mumbai&busType=Any&srcCountry=IND&destCountry=IND&onward=22-Nov-2024')
time.sleep(2)  # Let the page load

body = driver.find_element(By.TAG_NAME, "body")
#hide_details_TS=driver.find_elements(By.XPATH, "//div[@class='button']")
#if hide_details_TS:
    #hide_details_TS[0].click()
for i in range(40):
    buses_list_result = driver.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type_result = driver.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    departing_time_result = driver.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    reaching_time_result = driver.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    duration_list_result = driver.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")
    star_rating_result = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
    price_result = driver.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats_available_result = driver.find_elements(By.XPATH, "//div[@class='seat-left m-top-30']")
    body.send_keys(Keys.PAGE_DOWN)
buses_list=[]
bus_type_list=[]
departing_time_list=[]
reaching_time_list=[]
duration_list=[]
star_rating_list=[]
price_list=[]
seats_available_list=[]
for i in buses_list_result:
    buses_list.append(i.text)
for i in bus_type_result:
    bus_type_list.append(i.text)
for i in departing_time_result:
    departing_time_list.append(i.text)
for i in reaching_time_result:
    reaching_time_list.append(i.text)
for i in duration_list_result:
    duration_list.append(i.text)
for i in star_rating_result:
    star_rating_list.append(i.text)
for i in price_result:
    price_list.append(i.text)
for i in seats_available_result:
    seats_available_list.append(i.text)

# %%
min_value=min(len(buses_list),len(bus_type_list),len(departing_time_list),len(reaching_time_list),len(duration_list),len(star_rating_list),len(price_list),len(seats_available_list))
print(min_value)
# Out:
# 49

# %%
busname=[]
bustype=[]
departing_time=[]
duration=[]
reaching_time=[]
star_rating=[]
price=[]
seats_available=[]
route_link=[]
route_name=[]
for i in range(min_value):
    busname.append(buses_list[i])
    bustype.append(bus_type_list[i])
    departing_time.append(departing_time_list[i])
    duration.append(duration_list[i])
    reaching_time.append(reaching_time_list[i])
    star_rating.append(star_rating_list[i])
    price.append(price_list[i])
    seats_available.append(seats_available_list[i])
    route_link.append("https://www.redbus.in/bus-tickets/goa-to-mumbai")
    route_name.append("Goa to Mumbai")

# %%
import pandas as pd

# Dictionary with data
data = {
    'route_name': route_name,
    'route_link': route_link,
    'busname':busname,
    'bustype':bustype,
    'duparting_time': departing_time,
    'duration':duration,
    'reaching_time': reaching_time,
    'star_rating': star_rating,
    'Price': price,
    'Seats Available': seats_available
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Add automated ID column
df['ID'] = range(1, len(df) + 1)

print(df)
# Out:
#        route_name                                       route_link  \
# 0   Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 1   Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 2   Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 3   Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 4   Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 5   Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 6   Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 7   Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 8   Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 9   Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 10  Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 11  Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 12  Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 13  Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 14  Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 15  Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 16  Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 17  Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 18  Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 19  Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 20  Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 21  Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 22  Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 23  Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 24  Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 25  Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 26  Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 27  Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 28  Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 29  Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 30  Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 31  Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 32  Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 33  Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 34  Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 35  Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 36  Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 37  Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 38  Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 39  Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 40  Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 41  Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 42  Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 43  Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 44  Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 45  Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 46  Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 47  Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
# 48  Goa to Mumbai  https://www.redbus.in/bus-tickets/goa-to-mumbai
#
#                                               busname  \
# 0   Kadamba Transport Corporation Limited (KTCL) -...
# 1                                        Zingbus Plus
# 2                             Atmaram Travels (Unity)
# 3                       Vailankanni Travels - Mujawar
# 4                                 VAILANKANNI TRAVELS
# 5                                      Manish Travels
# 6                           Atmaram Travels (Dolphin)
# 7                                        Zingbus Plus
# 8                                National Travels,Goa
# 9                                   IntrCity SmartBus
# 10                                  IntrCity SmartBus
# 11                       Rajdhani Travels Corporation
# 12                                  IntrCity SmartBus
# 13                          Atmaram Travels (Dolphin)
# 14                               Atmaram Travels(GTA)
# 15                               Manish Patil Travels
# 16                               National Travels,Goa
# 17                           Atmaram Travels (Vishal)
# 18                          Atmaram Travels (Dolphin)
# 19                                     Laxmi holidays
# 20                                     Laxmi holidays
# 21                          Atmaram Travels (Vaibhav)
# 22                            Sai Travels - SaI Jyoti
# 23                                      Anand Travels
# 24                          Atmaram Travels (Dolphin)
# 25                            Jolly Tours and Travels
# 26                       Rajdhani Travels Corporation
# 27                                     Manish Travels
# 28                                        VRL Travels
# 29                             Naik Tours And Travels
# 30                              Manish Roshan Travels
# 31                                VAILANKANNI TRAVELS
# 32                              PSR Travels (Vaibhav)
# 33                             Atmaram Travels(M.Dev)
# 34                           Atmaram Travels (Vishal)
# 35                          Atmaram Travels (Dolphin)
# 36                             Atmaram Travels(M.Dev)
# 37                          Atmaram Travels (Dolphin)
# 38                            Jolly Tours and Travels
# 39                              PVS Tours and Travels
# 40                                    AAINATH TRAVELS
# 41                             Naik Tours And Travels
# 42                            Jolly Tours and Travels
# 43                                    Gujarat Travels
# 44                              Manish Sharma Travels
# 45                            Kokan Holidays - Muskan
# 46                              GANESH PRASAD TRAVELS
# 47                                     Roshan Travels
# 48                              GANESH PRASAD TRAVELS
#
#                                     bustype duparting_time duration  \
# 0                       Volvo AC Seater 2+2          18:30  13h 30m
# 1             Bharat Benz A/C Sleeper (2+1)          19:40  14h 35m
# 2                         A/C Sleeper (2+1)          20:00  15h 05m
# 3                     NON A/C Sleeper (2+1)          19:40  13h 20m
# 4                      VE A/C Sleeper (2+1)          16:25  14h 30m
# 5                         A/C Sleeper (2+1)          19:30  14h 00m
# 6                         A/C Sleeper (2+1)          19:30  14h 40m
# 7                      VE A/C Sleeper (2+1)          20:25  15h 30m
# 8                         A/C Sleeper (2+1)          19:30  15h 00m
# 9                          AC Sleeper (2+1)          21:00  14h 20m
# 10                         AC Sleeper (2+1)          18:30  14h 30m
# 11                     VE A/C Sleeper (2+1)          19:30  12h 40m
# 12                         AC Sleeper (2+1)          19:30  14h 10m
# 13                        A/C Sleeper (2+1)          14:00  15h 00m
# 14                        A/C Sleeper (2+1)          19:00  14h 35m
# 15                        A/C Sleeper (2+1)          17:00  15h 30m
# 16                    NON A/C Sleeper (2+1)          18:30  13h 00m
# 17                      Non AC Seater (2+2)          18:10  15h 10m
# 18                        A/C Sleeper (2+1)          15:00  14h 50m
# 19    Bharat Benz A/C Seater /Sleeper (2+1)          20:50  09h 10m
# 20    Bharat Benz A/C Seater /Sleeper (2+1)          21:00  14h 20m
# 21                        A/C Sleeper (2+1)          22:31  14h 10m
# 22                        A/C Sleeper (2+1)          18:30  13h 30m
# 23                    NON A/C Sleeper (2+1)          19:30  13h 00m
# 24                         AC Sleeper (2+1)          18:30  16h 35m
# 25                     VE A/C Sleeper (2+1)          18:25  12h 05m
# 26                        A/C Sleeper (2+1)          18:30  11h 45m
# 27                      Non AC Seater (2+2)          18:30  14h 30m
# 28                        A/C Sleeper (2+1)          19:30  15h 30m
# 29                    NON A/C Sleeper (2+1)          16:20  14h 25m
# 30                        A/C Sleeper (2+1)          20:30  14h 00m
# 31                     VE A/C Sleeper (2+1)          20:40  14h 20m
# 32                        A/C Sleeper (2+1)          22:30  14h 00m
# 33                        A/C Sleeper (2+1)          21:02  14h 10m
# 34                        A/C Sleeper (2+1)          17:30  15h 00m
# 35                        A/C Sleeper (2+1)          16:30  14h 45m
# 36                        A/C Sleeper (2+1)          22:00  14h 35m
# 37                        A/C Sleeper (2+1)          15:30  14h 45m
# 38                         A/C Seater (2+2)          19:25  12h 05m
# 39  Volvo 9600 Multi-Axle A/C Sleeper (2+1)          20:30  12h 50m
# 40                        A/C Sleeper (2+1)          21:30  14h 40m
# 41                    NON A/C Sleeper (2+1)          18:20  13h 10m
# 42                        A/C Sleeper (2+1)          19:25  12h 05m
# 43                         AC Sleeper (2+1)          12:40  14h 25m
# 44                        A/C Sleeper (2+1)          21:30  13h 50m
# 45                    NON A/C Sleeper (2+1)          16:00  14h 30m
# 46                         A/C Seater (2+2)          18:20  13h 50m
# 47                   Benz A/C Sleeper (2+1)          17:00  15h 20m
# 48                     NON A/C Seater (2+2)          17:00  15h 10m
#
#    reaching_time star_rating     Price     Seats Available  ID
# 0          08:00         4.0  INR 1000  25 Seats available   1
# 1          10:15         4.4       932  21 Seats available   2
# 2          11:05         4.2  INR 1000  27 Seats available   3
# 3          09:00         4.1   INR 800  20 Seats available   4
# 4          06:55         4.8  INR 1000  18 Seats available   5
# 5          09:30         4.3  INR 1000  21 Seats available   6
# 6          10:10         4.1  INR 1000  29 Seats available   7
# 7          11:55         4.5      1000  16 Seats available   8
# 8          10:30         4.2  INR 1000  14 Seats available   9
# 9          11:20         4.2  INR 1015  14 Seats available  10
# 10         09:00         4.2  INR 1000  14 Seats available  11
# 11         08:10         4.2  INR 1000  15 Seats available  12
# 12         09:40         4.4  INR 1000  13 Seats available  13
# 13         05:00         4.2  INR 1199  11 Seats available  14
# 14         09:35         4.0  INR 1000  29 Seats available  15
# 15         08:30         4.0  INR 1000  29 Seats available  16
# 16         07:30         4.0   INR 800  10 Seats available  17
# 17         09:20         4.0   INR 600  27 Seats available  18
# 18         05:50         4.0  INR 1000  21 Seats available  19
# 19         06:00         4.4  INR 4510    1 Seat available  20
# 20         11:20         4.4  INR 4510    1 Seat available  21
# 21         12:41         3.3  INR 1111  21 Seats available  22
# 22         08:00         3.1  INR 1000  23 Seats available  23
# 23         08:30         3.4   INR 800  17 Seats available  24
# 24         11:05         3.5  INR 1000  20 Seats available  25
# 25         06:30         3.9  INR 1199  19 Seats available  26
# 26         06:15         3.0      1000  21 Seats available  27
# 27         09:00         3.0   INR 600  23 Seats available  28
# 28         11:00         3.4  INR 1100   8 Seats available  29
# 29         06:45         3.9   INR 800  13 Seats available  30
# 30         10:30         3.6  INR 1000  28 Seats available  31
# 31         11:00         3.8  INR 1000  23 Seats available  32
# 32         12:30         3.8  INR 1100  20 Seats available  33
# 33         11:12         3.4  INR 1000  28 Seats available  34
# 34         08:30         3.8  INR 1000  28 Seats available  35
# 35         07:15         3.9  INR 1000  30 Seats available  36
# 36         12:35         3.9  INR 1000  29 Seats available  37
# 37         06:15         3.1  INR 1000  29 Seats available  38
# 38         07:30         3.6  INR 1799  40 Seats available  39
# 39         09:20         3.4  INR 4000  36 Seats available  40
# 40         12:10         1.7   INR 999  22 Seats available  41
# 41         07:30         2.7   INR 800  22 Seats available  42
# 42         07:30         2.3  INR 1000  30 Seats available  43
# 43         03:05         2.3  INR 1100  19 Seats available  44
# 44         11:20         2.4  INR 1000  30 Seats available  45
# 45         06:30         2.2   INR 800  28 Seats available  46
# 46         08:10         2.5  INR 2500  49 Seats available  47
# 47         08:20         2.8  INR 3500  30 Seats available  48
# 48         08:10         2.5  INR 2000  49 Seats available  49

# %%
 # Let the page load
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('https://www.redbus.in/bus-tickets/bangalore-to-goa?fromCityId=122&toCityId=210&fromCityName=Bangalore&toCityName=Goa&busType=Any&onward=22-Nov-2024')
time.sleep(2)  # Let the page load

body = driver.find_element(By.TAG_NAME, "body")
#hide_details_TS=driver.find_elements(By.XPATH, "//div[@class='button']")
#if hide_details_TS:
    #hide_details_TS[0].click()
for i in range(40):
    buses_list_result = driver.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type_result = driver.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    departing_time_result = driver.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    reaching_time_result = driver.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    duration_list_result = driver.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")
    star_rating_result = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
    price_result = driver.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats_available_result = driver.find_elements(By.XPATH, "//div[@class='seat-left m-top-30']")
    body.send_keys(Keys.PAGE_DOWN)
buses_list=[]
bus_type_list=[]
departing_time_list=[]
reaching_time_list=[]
duration_list=[]
star_rating_list=[]
price_list=[]
seats_available_list=[]
for i in buses_list_result:
    buses_list.append(i.text)
for i in bus_type_result:
    bus_type_list.append(i.text)
for i in departing_time_result:
    departing_time_list.append(i.text)
for i in reaching_time_result:
    reaching_time_list.append(i.text)
for i in duration_list_result:
    duration_list.append(i.text)
for i in star_rating_result:
    star_rating_list.append(i.text)
for i in price_result:
    price_list.append(i.text)
for i in seats_available_result:
    seats_available_list.append(i.text)

# %%
min_value=min(len(buses_list),len(bus_type_list),len(departing_time_list),len(reaching_time_list),len(duration_list),len(star_rating_list),len(price_list),len(seats_available_list))
print(min_value)
# Out:
# 42

# %%
busname=[]
bustype=[]
departing_time=[]
duration=[]
reaching_time=[]
star_rating=[]
price=[]
seats_available=[]
route_link=[]
route_name=[]
for i in range(min_value):
    busname.append(buses_list[i])
    bustype.append(bus_type_list[i])
    departing_time.append(departing_time_list[i])
    duration.append(duration_list[i])
    reaching_time.append(reaching_time_list[i])
    star_rating.append(star_rating_list[i])
    price.append(price_list[i])
    seats_available.append(seats_available_list[i])
    route_link.append("https://www.redbus.in/bus-tickets/bangalore-to-goa")
    route_name.append("Bangalore to Goa")

# %%
import pandas as pd

# Dictionary with data
data = {
    'route_name': route_name,
    'route_link': route_link,
    'busname':busname,
    'bustype':bustype,
    'duparting_time': departing_time,
    'duration':duration,
    'reaching_time': reaching_time,
    'star_rating': star_rating,
    'Price': price,
    'Seats Available': seats_available
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Add automated ID column
df['ID'] = range(1, len(df) + 1)

print(df)
# Out:
#           route_name                                         route_link  \
# 0   Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 1   Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 2   Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 3   Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 4   Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 5   Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 6   Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 7   Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 8   Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 9   Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 10  Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 11  Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 12  Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 13  Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 14  Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 15  Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 16  Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 17  Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 18  Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 19  Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 20  Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 21  Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 22  Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 23  Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 24  Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 25  Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 26  Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 27  Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 28  Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 29  Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 30  Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 31  Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 32  Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 33  Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 34  Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 35  Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 36  Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 37  Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 38  Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 39  Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 40  Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
# 41  Bangalore to Goa  https://www.redbus.in/bus-tickets/bangalore-to...
#
#                                               busname  \
# 0   Kadamba Transport Corporation Limited (KTCL) -...
# 1                        Streamline tours and travels
# 2                                   IntrCity SmartBus
# 3                           Sunrise Tours and Travels
# 4                                      Nathi Holidays
# 5                                   Intercity travels
# 6                           Sunrise Tours and Travels
# 7                                      Sugama Tourist
# 8                                  Butterfly Holidays
# 9                           Sunrise Tours and Travels
# 10                                Savistara roadlines
# 11                                  IntrCity SmartBus
# 12                          Deepika Tours And Travels
# 13                       Streamline tours and travels
# 14                                       KMBT Travels
# 15                                     Shanta Travels
# 16                                        AGR Travels
# 17                                  Sri Sai Logistics
# 18                                   National travels
# 19                                  Intercity travels
# 20                                      Rajat Travels
# 21                       Streamline tours and travels
# 22                       Streamline tours and travels
# 23                                        VKV Travels
# 24                                   Sea Bird Tourist
# 25                                        VRL Travels
# 26                                      DA Transports
# 27                     GreenLine Travels And Holidays
# 28                          Limousine Tours & Travels
# 29                                        Sam Tourist
# 30                                    GR Travels (RJ)
# 31                                        SRS Travels
# 32                                   Sea Bird Tourist
# 33                         GOWTHAMI TOURS AND TRAVELS
# 34                                        Sri Tourist
# 35                                      Anand Travels
# 36                                        VRL Travels
# 37                                        VRL Travels
# 38                                   Sea Bird Tourist
# 39                                        VRL Travels
# 40                         GOWTHAMI TOURS AND TRAVELS
# 41                                     Sugama Tourist
#
#                                              bustype duparting_time duration  \
# 0                                Volvo AC Seater 2+2          19:45  12h 30m
# 1                                  A/C Sleeper (2+1)          21:00  13h 00m
# 2                                   AC Sleeper (2+1)          21:30  13h 50m
# 3                      Bharat Benz A/C Sleeper (2+1)          21:50  12h 00m
# 4                                  A/C Sleeper (2+1)          22:15  13h 15m
# 5                      Bharat Benz A/C Sleeper (2+1)          21:00  13h 15m
# 6                                  A/C Sleeper (2+1)          20:15  12h 30m
# 7                              NON A/C Sleeper (2+1)          20:00  12h 15m
# 8                               VE A/C Sleeper (2+1)          21:10  12h 25m
# 9                                  A/C Sleeper (2+1)          21:20  12h 05m
# 10           Scania Multi-Axle AC Semi Sleeper (2+2)          21:20  12h 25m
# 11                                  AC Sleeper (2+1)          20:30  14h 10m
# 12                                 A/C Sleeper (2+1)          20:30  11h 45m
# 13                                 A/C Sleeper (2+1)          22:20  12h 05m
# 14                        A/C Seater / Sleeper (2+1)          21:00  11h 00m
# 15                             NON A/C Sleeper (2+1)          19:30  12h 50m
# 16                                 A/C Sleeper (2+1)          22:32  09h 43m
# 17                                 A/C Sleeper (2+1)          21:05  12h 25m
# 18                     Bharat Benz A/C Sleeper (2+1)          22:15  11h 45m
# 19                     Bharat Benz A/C Sleeper (2+1)          22:05  13h 00m
# 20                        A/C Seater / Sleeper (2+1)          21:20  13h 10m
# 21                     Bharat Benz A/C Sleeper (2+1)          23:00  12h 00m
# 22                     Bharat Benz A/C Sleeper (2+1)          20:00  13h 00m
# 23                                 A/C Sleeper (2+1)          22:55  11h 05m
# 24                                 A/C Sleeper (2+1)          22:30  13h 00m
# 25                             NON A/C Sleeper (2+1)          20:00  13h 30m
# 26                                 A/C Sleeper (2+1)          20:15  11h 45m
# 27                                 A/C Sleeper (2+1)          21:10  11h 50m
# 28                                 A/C Sleeper (2+1)          20:20  13h 30m
# 29                                 A/C Sleeper (2+1)          22:30  11h 00m
# 30                                 A/C Sleeper (2+1)          20:15  10h 55m
# 31                       NON AC Seater / Sleeper 2+1          20:00  13h 30m
# 32                             NON A/C Sleeper (2+1)          20:30  14h 00m
# 33                        Volvo Multi-Axle A/C (2+1)          20:25  10h 35m
# 34                                 A/C Sleeper (2+1)          20:05  12h 25m
# 35                             NON A/C Sleeper (2+1)          18:30  11h 00m
# 36                                 A/C Sleeper (2+1)          21:00  13h 45m
# 37                        A/C Seater / Sleeper (2+1)          19:30  13h 45m
# 38  Volvo Multi-Axle I-Shift B11R Semi Sleeper (2+2)          23:30  13h 00m
# 39                             NON A/C Sleeper (2+1)          20:10  13h 30m
# 40            Volvo Multi Axle B9R A/C Sleeper (2+1)          21:25  11h 35m
# 41                             NON A/C Sleeper (2+1)          20:00  11h 45m
#
#    reaching_time star_rating     Price     Seats Available  ID
# 0          08:15         3.8  INR 1200   7 Seats available   1
# 1          10:00         4.3  INR 1800  16 Seats available   2
# 2          11:20         4.0  INR 1547  21 Seats available   3
# 3          09:50         4.4  INR 1499  13 Seats available   4
# 4          11:30         5.0  INR 1499  16 Seats available   5
# 5          10:15         4.5  INR 1999   4 Seats available   6
# 6          08:45         4.1  INR 1499   9 Seats available   7
# 7          08:15         4.1  INR 1500   4 Seats available   8
# 8          09:35         4.5  INR 1599   5 Seats available   9
# 9          09:25         4.5  INR 1499   5 Seats available  10
# 10         09:45         3.2       999  38 Seats available  11
# 11         10:40         3.8  INR 1413  19 Seats available  12
# 12         08:15         3.7  INR 1599  23 Seats available  13
# 13         10:25         3.9  INR 1440  19 Seats available  14
# 14         08:00         3.7      1282  15 Seats available  15
# 15         08:20         3.9  INR 1710  12 Seats available  16
# 16         08:15         3.8  INR 1699  21 Seats available  17
# 17         09:30         3.1  INR 2500  22 Seats available  18
# 18         10:00         3.9  INR 1429  14 Seats available  19
# 19         11:05         3.3  INR 1699   9 Seats available  20
# 20         10:30         3.3      1169  23 Seats available  21
# 21         11:00         3.6  INR 1699  27 Seats available  22
# 22         09:00         3.9  INR 1799  23 Seats available  23
# 23         10:00         3.6      2290  19 Seats available  24
# 24         11:30         3.0  INR 1500  22 Seats available  25
# 25         09:30         3.9  INR 1800   6 Seats available  26
# 26         08:00         3.6      1500  11 Seats available  27
# 27         09:00         3.6  INR 2499   5 Seats available  28
# 28         09:50         3.9  INR 2000  12 Seats available  29
# 29         09:30         3.1      1614  21 Seats available  30
# 30         07:10         3.1  INR 3999  34 Seats available  31
# 31         09:30         2.3  INR 1199  11 Seats available  32
# 32         10:30         2.8  INR 1400  10 Seats available  33
# 33         07:00         2.7      1614  24 Seats available  34
# 34         08:30         2.7  INR 1599  20 Seats available  35
# 35         05:30         2.6      1435   8 Seats available  36
# 36         10:45         2.7  INR 2400   6 Seats available  37
# 37         09:15         2.1  INR 1000   3 Seats available  38
# 38         12:30         2.7  INR 1500  34 Seats available  39
# 39         09:40         2.2  INR 1800  20 Seats available  40
# 40         09:00         2.7      1519  36 Seats available  41
# 41         07:45         2.5  INR 1500   4 Seats available  42

# %%
 # Let the page load
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('https://www.redbus.in/bus-tickets/goa-to-bangalore?fromCityId=210&toCityId=122&fromCityName=Goa&toCityName=Bangalore&busType=Any&onward=22-Nov-2024')
time.sleep(2)  # Let the page load

body = driver.find_element(By.TAG_NAME, "body")
#hide_details_TS=driver.find_elements(By.XPATH, "//div[@class='button']")
#if hide_details_TS:
    #hide_details_TS[0].click()
for i in range(40):
    buses_list_result = driver.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type_result = driver.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    departing_time_result = driver.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    reaching_time_result = driver.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    duration_list_result = driver.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")
    star_rating_result = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
    price_result = driver.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats_available_result = driver.find_elements(By.XPATH, "//div[@class='seat-left m-top-30']")
    body.send_keys(Keys.PAGE_DOWN)
buses_list=[]
bus_type_list=[]
departing_time_list=[] 
reaching_time_list=[]
duration_list=[]
star_rating_list=[]
price_list=[]
seats_available_list=[]
for i in buses_list_result:
    buses_list.append(i.text)
for i in bus_type_result:
    bus_type_list.append(i.text)
for i in departing_time_result:
    departing_time_list.append(i.text)
for i in reaching_time_result:
    reaching_time_list.append(i.text)
for i in duration_list_result:
    duration_list.append(i.text)
for i in star_rating_result:
    star_rating_list.append(i.text)
for i in price_result:
    price_list.append(i.text)
for i in seats_available_result:
    seats_available_list.append(i.text)

# %%
min_value=min(len(buses_list),len(bus_type_list),len(departing_time_list),len(reaching_time_list),len(duration_list),len(star_rating_list),len(price_list),len(seats_available_list))
print(min_value)
# Out:
# 32

# %%
busname=[]
bustype=[]
departing_time=[]
duration=[]
reaching_time=[]
star_rating=[]
price=[]
seats_available=[]
route_link=[]
route_name=[]
for i in range(min_value):
    busname.append(buses_list[i])
    bustype.append(bus_type_list[i])
    departing_time.append(departing_time_list[i])
    duration.append(duration_list[i])
    reaching_time.append(reaching_time_list[i])
    star_rating.append(star_rating_list[i])
    price.append(price_list[i])
    seats_available.append(seats_available_list[i])
    route_link.append("https://www.redbus.in/bus-tickets/goa-to-bangalore")
    route_name.append("Goa to Bangalore")

# %%
import pandas as pd

# Dictionary with data
data = {
    'route_name': route_name,
    'route_link': route_link,
    'busname':busname,
    'bustype':bustype,
    'duparting_time': departing_time,
    'duration':duration,
    'reaching_time': reaching_time,
    'star_rating': star_rating,
    'Price': price,
    'Seats Available': seats_available
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Add automated ID column
df['ID'] = range(1, len(df) + 1)

print(df)
# Out:
#           route_name                                         route_link  \
# 0   Goa to Bangalore  https://www.redbus.in/bus-tickets/goa-to-banga...
# 1   Goa to Bangalore  https://www.redbus.in/bus-tickets/goa-to-banga...
# 2   Goa to Bangalore  https://www.redbus.in/bus-tickets/goa-to-banga...
# 3   Goa to Bangalore  https://www.redbus.in/bus-tickets/goa-to-banga...
# 4   Goa to Bangalore  https://www.redbus.in/bus-tickets/goa-to-banga...
# 5   Goa to Bangalore  https://www.redbus.in/bus-tickets/goa-to-banga...
# 6   Goa to Bangalore  https://www.redbus.in/bus-tickets/goa-to-banga...
# 7   Goa to Bangalore  https://www.redbus.in/bus-tickets/goa-to-banga...
# 8   Goa to Bangalore  https://www.redbus.in/bus-tickets/goa-to-banga...
# 9   Goa to Bangalore  https://www.redbus.in/bus-tickets/goa-to-banga...
# 10  Goa to Bangalore  https://www.redbus.in/bus-tickets/goa-to-banga...
# 11  Goa to Bangalore  https://www.redbus.in/bus-tickets/goa-to-banga...
# 12  Goa to Bangalore  https://www.redbus.in/bus-tickets/goa-to-banga...
# 13  Goa to Bangalore  https://www.redbus.in/bus-tickets/goa-to-banga...
# 14  Goa to Bangalore  https://www.redbus.in/bus-tickets/goa-to-banga...
# 15  Goa to Bangalore  https://www.redbus.in/bus-tickets/goa-to-banga...
# 16  Goa to Bangalore  https://www.redbus.in/bus-tickets/goa-to-banga...
# 17  Goa to Bangalore  https://www.redbus.in/bus-tickets/goa-to-banga...
# 18  Goa to Bangalore  https://www.redbus.in/bus-tickets/goa-to-banga...
# 19  Goa to Bangalore  https://www.redbus.in/bus-tickets/goa-to-banga...
# 20  Goa to Bangalore  https://www.redbus.in/bus-tickets/goa-to-banga...
# 21  Goa to Bangalore  https://www.redbus.in/bus-tickets/goa-to-banga...
# 22  Goa to Bangalore  https://www.redbus.in/bus-tickets/goa-to-banga...
# 23  Goa to Bangalore  https://www.redbus.in/bus-tickets/goa-to-banga...
# 24  Goa to Bangalore  https://www.redbus.in/bus-tickets/goa-to-banga...
# 25  Goa to Bangalore  https://www.redbus.in/bus-tickets/goa-to-banga...
# 26  Goa to Bangalore  https://www.redbus.in/bus-tickets/goa-to-banga...
# 27  Goa to Bangalore  https://www.redbus.in/bus-tickets/goa-to-banga...
# 28  Goa to Bangalore  https://www.redbus.in/bus-tickets/goa-to-banga...
# 29  Goa to Bangalore  https://www.redbus.in/bus-tickets/goa-to-banga...
# 30  Goa to Bangalore  https://www.redbus.in/bus-tickets/goa-to-banga...
# 31  Goa to Bangalore  https://www.redbus.in/bus-tickets/goa-to-banga...
#
#                                               busname  \
# 0   Kadamba Transport Corporation Limited (KTCL) -...
# 1                                   IntrCity SmartBus
# 2                                   Intercity travels
# 3                           Sunrise Tours and Travels
# 4                                   IntrCity SmartBus
# 5                        Streamline tours and travels
# 6                           Sunrise Tours and Travels
# 7                                   Intercity travels
# 8                             Jolly Tours and Travels
# 9                                         Sri Tourist
# 10                       Streamline tours and travels
# 11                                      Rajat Travels
# 12                          Limousine Tours & Travels
# 13                                   National travels
# 14                                        VRL Travels
# 15                       Streamline tours and travels
# 16                                        VKV Travels
# 17                              PVS Tours and Travels
# 18                                    PSR Travels Goa
# 19                                     Sugama Tourist
# 20                                    GR Travels (RJ)
# 21                                        VRL Travels
# 22                                      Anand Travels
# 23                                   Sea Bird Tourist
# 24                                   National travels
# 25                                   Sea Bird Tourist
# 26                                        VRL Travels
# 27                                   Sea Bird Tourist
# 28                                   Sea Bird Tourist
# 29                                        SRS Travels
# 30                                     Sugama Tourist
# 31                         GOWTHAMI TOURS AND TRAVELS
#
#                           bustype duparting_time duration reaching_time  \
# 0             Volvo AC Seater 2+2          18:30  14h 00m         08:30
# 1                AC Sleeper (2+1)          18:00  13h 50m         07:50
# 2   Bharat Benz A/C Sleeper (2+1)          18:00  13h 15m         07:15
# 3               A/C Sleeper (2+1)          18:30  12h 40m         07:10
# 4                AC Sleeper (2+1)          17:00  13h 40m         06:40
# 5               A/C Sleeper (2+1)          18:00  12h 30m         06:30
# 6               A/C Sleeper (2+1)          18:00  12h 05m         06:05
# 7   Bharat Benz A/C Sleeper (2+1)          17:15  13h 15m         06:30
# 8               A/C Sleeper (2+1)          17:00  14h 10m         07:10
# 9               A/C Sleeper (2+1)          17:30  13h 20m         06:50
# 10              A/C Sleeper (2+1)          19:00  12h 30m         07:30
# 11     A/C Seater / Sleeper (2+1)          18:00  12h 35m         06:35
# 12              A/C Sleeper (2+1)          17:30  13h 00m         06:30
# 13  Bharat Benz A/C Sleeper (2+1)          19:45  12h 00m         07:45
# 14          NON A/C Sleeper (2+1)          18:00  14h 00m         08:00
# 15              A/C Sleeper (2+1)          17:00  12h 30m         05:30
# 16              A/C Sleeper (2+1)          13:00  12h 05m         01:05
# 17              A/C Sleeper (2+1)          20:15  14h 00m         10:15
# 18     A/C Seater / Sleeper (2+1)          20:05  11h 25m         07:30
# 19          NON A/C Sleeper (2+1)          18:30  12h 45m         07:15
# 20              A/C Sleeper (2+1)          18:00  11h 20m         05:20
# 21              A/C Sleeper (2+1)          20:00  14h 00m         10:00
# 22          NON A/C Sleeper (2+1)          18:30  12h 15m         06:45
# 23              A/C Sleeper (2+1)          20:30  13h 00m         09:30
# 24  Bharat Benz A/C Sleeper (2+1)          17:00  12h 30m         05:30
# 25          NON A/C Sleeper (2+1)          18:30  14h 00m         08:30
# 26     A/C Seater / Sleeper (2+1)          19:00  14h 00m         09:00
# 27              A/C Sleeper (2+1)          17:00  14h 00m         07:00
# 28          NON A/C Sleeper (2+1)          17:30  14h 00m         07:30
# 29    NON AC Seater / Sleeper 2+1          18:00  13h 30m         07:30
# 30          NON A/C Sleeper (2+1)          17:30  13h 48m         07:18
# 31     Volvo Multi-Axle A/C (2+1)          21:45  10h 15m         08:00
#
#    star_rating     Price     Seats Available  ID
# 0          3.6   INR 800  30 Seats available   1
# 1          4.4   INR 799  15 Seats available   2
# 2          4.5   INR 999  16 Seats available   3
# 3          4.4   INR 999  13 Seats available   4
# 4          4.4   INR 799  18 Seats available   5
# 5          4.3  INR 1000  17 Seats available   6
# 6          4.5   INR 999  20 Seats available   7
# 7          4.7   INR 999  15 Seats available   8
# 8          4.3   INR 900  17 Seats available   9
# 9          3.6   INR 999  36 Seats available  10
# 10         3.9       900  26 Seats available  11
# 11         2.9       810  24 Seats available  12
# 12         3.7   INR 900  22 Seats available  13
# 13         3.3  INR 1100  27 Seats available  14
# 14         3.9   INR 800   9 Seats available  15
# 15         3.2   INR 999  26 Seats available  16
# 16         3.9      1040  20 Seats available  17
# 17         3.4  INR 3000  32 Seats available  18
# 18         3.5  INR 3199  40 Seats available  19
# 19         3.2   INR 900  15 Seats available  20
# 20         3.1  INR 3999  34 Seats available  21
# 21         2.8   INR 900  13 Seats available  22
# 22         2.8       722  18 Seats available  23
# 23         2.9  INR 1000  23 Seats available  24
# 24         1.2   INR 950  26 Seats available  25
# 25         2.5   INR 700  27 Seats available  26
# 26         2.7   INR 800  35 Seats available  27
# 27         2.4   INR 900  25 Seats available  28
# 28         2.9   INR 700  28 Seats available  29
# 29         2.6   INR 799  30 Seats available  30
# 30         2.5   INR 900  13 Seats available  31
# 31         2.7  INR 3000   4 Seats available  32
