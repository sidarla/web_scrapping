# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('https://www.redbus.in/travels/nbstc')
time.sleep(2)  # Let the page load

body = driver.find_element(By.TAG_NAME, "body")
telangana_buses_list=[]
telangana_buses_links=[]

for page_num in range(1, 5):  # Loop over pages (or scroll actions)
    # Get all elements with class 'route'
    result1 = driver.find_elements(By.CSS_SELECTOR, "a[class='route']")
    
    # Print the text of each element found
    for element in result1:
        telangana_buses_list.append(element.text)
        telangana_buses_links.append(element.get_attribute('href'))
    
    # Scroll down the page
    body.send_keys(Keys.PAGE_DOWN)
    time.sleep(2)  # Give some time for new elements to load
    
    # Find an element matching the XPATH and click (if needed)
    result = driver.find_elements(By.XPATH, f"//div[contains(text(),'{page_num+1}')]")
    #print(result)
    if result:
        result[0].click()  # Click the first element found with matching XPATH

#driver.quit()  # Close the browser after task completion

# %%
for i in telangana_buses_links:
    print(i)
# Out:
# https://www.redbus.in/bus-tickets/kolkata-to-siliguri
# https://www.redbus.in/bus-tickets/siliguri-to-kolkata
# https://www.redbus.in/bus-tickets/siliguri-to-darjeeling
# https://www.redbus.in/bus-tickets/raiganj-to-kolkata
# https://www.redbus.in/bus-tickets/kolkata-to-raiganj
# https://www.redbus.in/bus-tickets/kolkata-to-cooch-behar-west-bengal
# https://www.redbus.in/bus-tickets/malda-to-kolkata
# https://www.redbus.in/bus-tickets/kolkata-to-malda
# https://www.redbus.in/bus-tickets/cooch-behar-west-bengal-to-kolkata
# https://www.redbus.in/bus-tickets/cooch-behar-west-bengal-to-berhampore
# https://www.redbus.in/bus-tickets/kolkata-to-balurghat
# https://www.redbus.in/bus-tickets/balurghat-to-kolkata
# https://www.redbus.in/bus-tickets/berhampore-to-cooch-behar-west-bengal
# https://www.redbus.in/bus-tickets/berhampore-to-siliguri
# https://www.redbus.in/bus-tickets/siliguri-to-berhampore
# https://www.redbus.in/bus-tickets/malda-to-cooch-behar-west-bengal
# https://www.redbus.in/bus-tickets/kolkata-to-gangarampur
# https://www.redbus.in/bus-tickets/gangarampur-to-kolkata
# https://www.redbus.in/bus-tickets/cooch-behar-west-bengal-to-malda
# https://www.redbus.in/bus-tickets/siliguri-to-krishnanagar
# https://www.redbus.in/bus-tickets/kolkata-to-falakata
# https://www.redbus.in/bus-tickets/kolkata-to-jalpaiguri
# https://www.redbus.in/bus-tickets/kolkata-to-farakka
# https://www.redbus.in/bus-tickets/kolkata-to-islampur-west-bengal
# https://www.redbus.in/bus-tickets/cooch-behar-west-bengal-to-raiganj
# https://www.redbus.in/bus-tickets/berhampore-to-falakata
# https://www.redbus.in/bus-tickets/falakata-to-berhampore
# https://www.redbus.in/bus-tickets/falakata-to-kolkata
# https://www.redbus.in/bus-tickets/siliguri-to-ranaghat
# https://www.redbus.in/bus-tickets/kolkata-to-buniadpur
# https://www.redbus.in/bus-tickets/kolkata-to-itahar-west-bengal
# https://www.redbus.in/bus-tickets/falakata-to-malda
# https://www.redbus.in/bus-tickets/buniadpur-to-kolkata
# https://www.redbus.in/bus-tickets/raiganj-to-siliguri
# https://www.redbus.in/bus-tickets/gazole-to-kolkata
# https://www.redbus.in/bus-tickets/malda-to-siliguri
# https://www.redbus.in/bus-tickets/kolkata-to-dhupguri-west-bengal
# https://www.redbus.in/bus-tickets/kolkata-to-gazole
# https://www.redbus.in/bus-tickets/raiganj-to-krishnanagar
# https://www.redbus.in/bus-tickets/raiganj-to-balurghat

# %%
for i in telangana_buses_list:
    print(i)
# Out:
# Kolkata to Siliguri
# Siliguri to Kolkata
# Siliguri to Darjeeling
# Raiganj to Kolkata
# Kolkata to Raiganj
# Kolkata to Cooch Behar (West Bengal)
# Malda to Kolkata
# Kolkata to Malda
# Cooch Behar (West Bengal) to Kolkata
# Cooch Behar (West Bengal) to Berhampore (West Bengal)
# Kolkata to Balurghat
# Balurghat to Kolkata
# Berhampore (West Bengal) to Cooch Behar (West Bengal)
# Berhampore (West Bengal) to Siliguri
# Siliguri to Berhampore (West Bengal)
# Malda to Cooch Behar (West Bengal)
# Kolkata to Gangarampur
# Gangarampur to Kolkata
# Cooch Behar (West Bengal) to Malda
# Siliguri to Krishnanagar (West Bengal)
# Kolkata to Falakata (west bengal)
# Kolkata to Jalpaiguri
# Kolkata to Farakka
# Kolkata to Islampur (West Bengal)
# Cooch Behar (West Bengal) to Raiganj
# Berhampore (West Bengal) to Falakata (west bengal)
# Falakata (west bengal) to Berhampore (West Bengal)
# Falakata (west bengal) to Kolkata
# Siliguri to Ranaghat
# Kolkata to Buniadpur
# Kolkata to Itahar (West Bengal)
# Falakata (west bengal) to Malda
# Buniadpur to Kolkata
# Raiganj to Siliguri
# Gazole to Kolkata
# Malda to Siliguri
# Kolkata to Dhupguri (West Bengal)
# Kolkata to Gazole
# Raiganj to Krishnanagar (West Bengal)
# Raiganj to Balurghat

# %%
 # Let the page load
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('https://www.redbus.in/bus-tickets/kolkata-to-siliguri?fromCityId=74820&toCityId=74694&fromCityName=Kolkata&toCityName=Siliguri&busType=Any&srcCountry=IND&destCountry=IND&onward=22-Nov-2024')
time.sleep(2)  # Let the page load

body = driver.find_element(By.TAG_NAME, "body")
hide_details_TS=driver.find_elements(By.XPATH, "//div[@class='button']")
if hide_details_TS:
    hide_details_TS[0].click()
for i in range(40):
    buses_list_result = driver.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type_result = driver.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    departing_time_result = driver.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    reaching_time_result = driver.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    duration_list_result = driver.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")
    star_rating_result = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
    price_result = driver.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats_available_result = driver.find_elements(By.XPATH, "//div[@class='seat-left m-top-30']")
    body.send_keys(Keys.PAGE_DOWN)
buses_list=[]
bus_type_list=[]
departing_time_list=[]
reaching_time_list=[]
duration_list=[]
star_rating_list=[]
price_list=[]
seats_available_list=[]
for i in buses_list_result:
    buses_list.append(i.text)
for i in bus_type_result:
    bus_type_list.append(i.text)
for i in departing_time_result:
    departing_time_list.append(i.text)
for i in reaching_time_result:
    reaching_time_list.append(i.text)
for i in duration_list_result:
    duration_list.append(i.text)
for i in star_rating_result:
    star_rating_list.append(i.text)
for i in price_result:
    price_list.append(i.text)
for i in seats_available_result:
    seats_available_list.append(i.text)

# %%
min_value=min(len(buses_list),len(bus_type_list),len(departing_time_list),len(reaching_time_list),len(duration_list),len(star_rating_list),len(price_list),len(seats_available_list))
print(min_value)
# Out:
# 30

# %%
busname=[]
bustype=[]
departing_time=[]
duration=[]
reaching_time=[]
star_rating=[]
price=[]
seats_available=[]
route_link=[]
route_name=[]
for i in range(min_value):
    busname.append(buses_list[i])
    bustype.append(bus_type_list[i])
    departing_time.append(departing_time_list[i])
    duration.append(duration_list[i])
    reaching_time.append(reaching_time_list[i])
    star_rating.append(star_rating_list[i])
    price.append(price_list[i])
    seats_available.append(seats_available_list[i])
    route_link.append("https://www.redbus.in/bus-tickets/kolkata-to-siliguri")
    route_name.append("Kolkata to Siliguri")

# %%
import pandas as pd

# Dictionary with data
data = {
    'route_name': route_name,
    'route_link': route_link,
    'busname':busname,
    'bustype':bustype,
    'duparting_time': departing_time,
    'duration':duration,
    'reaching_time': reaching_time,
    'star_rating': star_rating,
    'Price': price,
    'Seats Available': seats_available
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Add automated ID column
df['ID'] = range(1, len(df) + 1)

print(df)
# Out:
#              route_name                                         route_link  \
# 0   Kolkata to Siliguri  https://www.redbus.in/bus-tickets/kolkata-to-s...
# 1   Kolkata to Siliguri  https://www.redbus.in/bus-tickets/kolkata-to-s...
# 2   Kolkata to Siliguri  https://www.redbus.in/bus-tickets/kolkata-to-s...
# 3   Kolkata to Siliguri  https://www.redbus.in/bus-tickets/kolkata-to-s...
# 4   Kolkata to Siliguri  https://www.redbus.in/bus-tickets/kolkata-to-s...
# 5   Kolkata to Siliguri  https://www.redbus.in/bus-tickets/kolkata-to-s...
# 6   Kolkata to Siliguri  https://www.redbus.in/bus-tickets/kolkata-to-s...
# 7   Kolkata to Siliguri  https://www.redbus.in/bus-tickets/kolkata-to-s...
# 8   Kolkata to Siliguri  https://www.redbus.in/bus-tickets/kolkata-to-s...
# 9   Kolkata to Siliguri  https://www.redbus.in/bus-tickets/kolkata-to-s...
# 10  Kolkata to Siliguri  https://www.redbus.in/bus-tickets/kolkata-to-s...
# 11  Kolkata to Siliguri  https://www.redbus.in/bus-tickets/kolkata-to-s...
# 12  Kolkata to Siliguri  https://www.redbus.in/bus-tickets/kolkata-to-s...
# 13  Kolkata to Siliguri  https://www.redbus.in/bus-tickets/kolkata-to-s...
# 14  Kolkata to Siliguri  https://www.redbus.in/bus-tickets/kolkata-to-s...
# 15  Kolkata to Siliguri  https://www.redbus.in/bus-tickets/kolkata-to-s...
# 16  Kolkata to Siliguri  https://www.redbus.in/bus-tickets/kolkata-to-s...
# 17  Kolkata to Siliguri  https://www.redbus.in/bus-tickets/kolkata-to-s...
# 18  Kolkata to Siliguri  https://www.redbus.in/bus-tickets/kolkata-to-s...
# 19  Kolkata to Siliguri  https://www.redbus.in/bus-tickets/kolkata-to-s...
# 20  Kolkata to Siliguri  https://www.redbus.in/bus-tickets/kolkata-to-s...
# 21  Kolkata to Siliguri  https://www.redbus.in/bus-tickets/kolkata-to-s...
# 22  Kolkata to Siliguri  https://www.redbus.in/bus-tickets/kolkata-to-s...
# 23  Kolkata to Siliguri  https://www.redbus.in/bus-tickets/kolkata-to-s...
# 24  Kolkata to Siliguri  https://www.redbus.in/bus-tickets/kolkata-to-s...
# 25  Kolkata to Siliguri  https://www.redbus.in/bus-tickets/kolkata-to-s...
# 26  Kolkata to Siliguri  https://www.redbus.in/bus-tickets/kolkata-to-s...
# 27  Kolkata to Siliguri  https://www.redbus.in/bus-tickets/kolkata-to-s...
# 28  Kolkata to Siliguri  https://www.redbus.in/bus-tickets/kolkata-to-s...
# 29  Kolkata to Siliguri  https://www.redbus.in/bus-tickets/kolkata-to-s...
#
#                                               busname  \
# 0                   NBSTC-KOL-COB-E2-3:00 pm - 171781
# 1                    NBSTC-KOL-RAI-SLG-19:30 - 176649
# 2   SBSTC-KOLKATA - SILIGURI - VOLVO - 20:05 (BEL ...
# 3                          Shyamoli Paribahan Pvt Ltd
# 4                                        Express Line
# 5                                           Easy Ride
# 6                                           Easy Ride
# 7                                           Greenline
# 8                                           Easy Ride
# 9                                Lokenath Bus Service
# 10                         Shyamoli Paribahan Pvt Ltd
# 11                                          Greenline
# 12                                       Express Line
# 13                                   Rubi Paribahan
# 14                               Lokenath Bus Service
# 15                                     Modern Travels
# 16                         Shyamoli Paribahan Pvt Ltd
# 17                                   Aitiana Airwings
# 18                         Shyamoli Paribahan Pvt Ltd
# 19                         Shyamoli Paribahan Pvt Ltd
# 20                                   Rubi Paribahan
# 21                                              RAYAN
# 22                                   Aitiana Airwings
# 23                                     Modern Travels
# 24                              Prarthana Bus Service
# 25                                   Maulik Paribahan
# 26                              Maa Durga Bus Service
# 27                                    Annesha Travels
# 28                                     Renuka Travels
# 29                               Aradhana Bus Service
#
#                                           bustype duparting_time duration  \
# 0                             Non AC Seater (2+3)          15:00  13h 20m
# 1                                 AC Seater (2+2)          19:30  12h 00m
# 2                           Volvo AC Seater (2+2)          20:05  13h 00m
# 3       Volvo Multi-Axle A/C seater/sleeper (2+1)          18:30  13h 15m
# 4         Volvo 9600 Multi-Axle A/C Sleeper (2+1)          18:30  13h 10m
# 5         Volvo 9600 Multi-Axle A/C Sleeper (2+1)          19:50  12h 55m
# 6         Volvo 9600 Multi-Axle A/C Sleeper (2+1)          18:30  12h 55m
# 7         Volvo 9600 Multi-Axle A/C Sleeper (2+1)          18:30  13h 15m
# 8         Volvo 9600 Multi-Axle A/C Sleeper (2+1)          20:30  12h 55m
# 9   Volvo Multi Axle B11R AC Seater\Sleeper (2+1)          20:00  12h 00m
# 10            Volvo 9600 A/C Seater/Sleeper (2+1)          21:00  13h 00m
# 11            Volvo 9600 A/C Seater/Sleeper (2+1)          19:00  13h 00m
# 12            Volvo 9600 A/C Seater/Sleeper (2+1)          19:30  12h 55m
# 13  Volvo Multi Axle B11R AC Seater\Sleeper (2+1)          18:45  13h 15m
# 14      Volvo Multi-Axle A/C Seater/Sleeper (2+1)          18:15  12h 15m
# 15                  Bharat Benz A/C Sleeper (2+1)          19:30  12h 45m
# 16        Volvo 9600 Multi-Axle A/C Sleeper (2+1)          18:00  12h 50m
# 17                         Benz A/C Sleeper (2+1)          18:00  13h 30m
# 18             Volvo B11R Multi Axle Seater (2+2)          20:45  12h 00m
# 19        Volvo 9600 Multi-Axle A/C Sleeper (2+1)          19:15  13h 00m
# 20        Volvo 9600 Multi-Axle A/C Sleeper (2+1)          19:00  12h 30m
# 21                     A/C Seater / Sleeper (2+1)          17:00  12h 00m
# 22             Volvo Multi-Axle Sleeper A/C (2+1)          18:30  13h 00m
# 23          Bharat Benz A/C Seater /Sleeper (2+1)          18:30  13h 15m
# 24                     A/C Seater / Sleeper (2+1)          19:30  12h 00m
# 25                     A/C Seater / Sleeper (2+2)          18:30  13h 15m
# 26                 NON A/C Seater / Sleeper (2+2)          19:00  14h 00m
# 27                 NON A/C Seater / Sleeper (2+2)          17:30  13h 30m
# 28                     A/C Seater / Sleeper (2+2)          20:00  13h 00m
# 29                 NON A/C Seater / Sleeper (2+2)          16:45  14h 15m
#
#    reaching_time star_rating     Price     Seats Available  ID
# 0          04:20         3.7   INR 450  11 Seats available   1
# 1          07:30         3.8   INR 800  23 Seats available   2
# 2          09:05         3.9  INR 1210  51 Seats available   3
# 3          07:45         4.4  INR 1200  11 Seats available   4
# 4          07:40         4.5  INR 1499  12 Seats available   5
# 5          08:45         4.7  INR 1500  14 Seats available   6
# 6          07:25         4.6  INR 1500  12 Seats available   7
# 7          07:45         4.4  INR 1500   9 Seats available   8
# 8          09:25         4.7  INR 1500   8 Seats available   9
# 9          08:00         4.4  INR 1200  16 Seats available  10
# 10         10:00         4.3  INR 1200  25 Seats available  11
# 11         08:00         4.4  INR 1200  19 Seats available  12
# 12         08:25         4.5  INR 1199  19 Seats available  13
# 13         08:00         4.3  INR 1199  23 Seats available  14
# 14         06:30         4.3  INR 1200  27 Seats available  15
# 15         08:15         4.2  INR 1450   6 Seats available  16
# 16         06:50         4.5  INR 1500   5 Seats available  17
# 17         07:30         4.4  INR 1300   3 Seats available  18
# 18         08:45         4.0  INR 1200  36 Seats available  19
# 19         08:15         4.6  INR 1500  12 Seats available  20
# 20         07:30         4.2  INR 1500  13 Seats available  21
# 21         05:00         4.2  INR 1500  46 Seats available  22
# 22         07:30         4.5  INR 1500   5 Seats available  23
# 23         07:45         3.4   INR 850  31 Seats available  24
# 24         07:30         3.9   INR 800  40 Seats available  25
# 25         07:45         3.0   INR 800  46 Seats available  26
# 26         09:00         3.0   INR 600   5 Seats available  27
# 27         07:00         1.4   INR 600  30 Seats available  28
# 28         09:00         1.3  INR 1500  65 Seats available  29
# 29         07:00         2.2   INR 750  11 Seats available  30

# %%
 # Let the page load
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('https://www.redbus.in/bus-tickets/siliguri-to-kolkata?fromCityId=74694&toCityId=74820&fromCityName=Siliguri&toCityName=Kolkata&busType=Any&srcCountry=IND&destCountry=null&onward=22-Nov-2024')
time.sleep(2)  # Let the page load

body = driver.find_element(By.TAG_NAME, "body")
hide_details_TS=driver.find_elements(By.XPATH, "//div[@class='button']")
if hide_details_TS:
    hide_details_TS[0].click()
for i in range(40):
    buses_list_result = driver.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type_result = driver.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    departing_time_result = driver.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    reaching_time_result = driver.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    duration_list_result = driver.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")
    star_rating_result = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
    price_result = driver.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats_available_result = driver.find_elements(By.XPATH, "//div[@class='seat-left m-top-30']")
    body.send_keys(Keys.PAGE_DOWN)
buses_list=[]
bus_type_list=[]
departing_time_list=[]
reaching_time_list=[]
duration_list=[]
star_rating_list=[]
price_list=[]
seats_available_list=[]
for i in buses_list_result:
    buses_list.append(i.text)
for i in bus_type_result:
    bus_type_list.append(i.text)
for i in departing_time_result:
    departing_time_list.append(i.text)
for i in reaching_time_result:
    reaching_time_list.append(i.text)
for i in duration_list_result:
    duration_list.append(i.text)
for i in star_rating_result:
    star_rating_list.append(i.text)
for i in price_result:
    price_list.append(i.text)
for i in seats_available_result:
    seats_available_list.append(i.text)

# %%
min_value=min(len(buses_list),len(bus_type_list),len(departing_time_list),len(reaching_time_list),len(duration_list),len(star_rating_list),len(price_list),len(seats_available_list))
print(min_value)
# Out:
# 27

# %%
busname=[]
bustype=[]
departing_time=[]
duration=[]
reaching_time=[]
star_rating=[]
price=[]
seats_available=[]
route_link=[]
route_name=[]
for i in range(min_value):
    busname.append(buses_list[i])
    bustype.append(bus_type_list[i])
    departing_time.append(departing_time_list[i])
    duration.append(duration_list[i])
    reaching_time.append(reaching_time_list[i])
    star_rating.append(star_rating_list[i])
    price.append(price_list[i])
    seats_available.append(seats_available_list[i])
    route_link.append("https://www.redbus.in/bus-tickets/siliguri-to-kolkata")
    route_name.append("Siliguri to Kolkata")

# %%
import pandas as pd

# Dictionary with data
data = {
    'route_name': route_name,
    'route_link': route_link,
    'busname':busname,
    'bustype':bustype,
    'duparting_time': departing_time,
    'duration':duration,
    'reaching_time': reaching_time,
    'star_rating': star_rating,
    'Price': price,
    'Seats Available': seats_available
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Add automated ID column
df['ID'] = range(1, len(df) + 1)

print(df)
# Out:
#              route_name                                         route_link  \
# 0   Siliguri to Kolkata  https://www.redbus.in/bus-tickets/siliguri-to-...
# 1   Siliguri to Kolkata  https://www.redbus.in/bus-tickets/siliguri-to-...
# 2   Siliguri to Kolkata  https://www.redbus.in/bus-tickets/siliguri-to-...
# 3   Siliguri to Kolkata  https://www.redbus.in/bus-tickets/siliguri-to-...
# 4   Siliguri to Kolkata  https://www.redbus.in/bus-tickets/siliguri-to-...
# 5   Siliguri to Kolkata  https://www.redbus.in/bus-tickets/siliguri-to-...
# 6   Siliguri to Kolkata  https://www.redbus.in/bus-tickets/siliguri-to-...
# 7   Siliguri to Kolkata  https://www.redbus.in/bus-tickets/siliguri-to-...
# 8   Siliguri to Kolkata  https://www.redbus.in/bus-tickets/siliguri-to-...
# 9   Siliguri to Kolkata  https://www.redbus.in/bus-tickets/siliguri-to-...
# 10  Siliguri to Kolkata  https://www.redbus.in/bus-tickets/siliguri-to-...
# 11  Siliguri to Kolkata  https://www.redbus.in/bus-tickets/siliguri-to-...
# 12  Siliguri to Kolkata  https://www.redbus.in/bus-tickets/siliguri-to-...
# 13  Siliguri to Kolkata  https://www.redbus.in/bus-tickets/siliguri-to-...
# 14  Siliguri to Kolkata  https://www.redbus.in/bus-tickets/siliguri-to-...
# 15  Siliguri to Kolkata  https://www.redbus.in/bus-tickets/siliguri-to-...
# 16  Siliguri to Kolkata  https://www.redbus.in/bus-tickets/siliguri-to-...
# 17  Siliguri to Kolkata  https://www.redbus.in/bus-tickets/siliguri-to-...
# 18  Siliguri to Kolkata  https://www.redbus.in/bus-tickets/siliguri-to-...
# 19  Siliguri to Kolkata  https://www.redbus.in/bus-tickets/siliguri-to-...
# 20  Siliguri to Kolkata  https://www.redbus.in/bus-tickets/siliguri-to-...
# 21  Siliguri to Kolkata  https://www.redbus.in/bus-tickets/siliguri-to-...
# 22  Siliguri to Kolkata  https://www.redbus.in/bus-tickets/siliguri-to-...
# 23  Siliguri to Kolkata  https://www.redbus.in/bus-tickets/siliguri-to-...
# 24  Siliguri to Kolkata  https://www.redbus.in/bus-tickets/siliguri-to-...
# 25  Siliguri to Kolkata  https://www.redbus.in/bus-tickets/siliguri-to-...
# 26  Siliguri to Kolkata  https://www.redbus.in/bus-tickets/siliguri-to-...
#
#                                               busname  \
# 0   SBSTC-SILIGURI - KOLKATA - VOLVO - 19:35 (BEL ...
# 1                                Lokenath Bus Service
# 2                          Shyamoli Paribahan Pvt Ltd
# 3                                Lokenath Bus Service
# 4                               Prarthana Bus Service
# 5                                           Easy Ride
# 6                          Shyamoli Paribahan Pvt Ltd
# 7                                        Express Line
# 8                                           Easy Ride
# 9                                      Modern Travels
# 10                                          Greenline
# 11                                   Rubi Paribahan
# 12                                          Easy Ride
# 13                                   Aitiana Airwings
# 14                         Shyamoli Paribahan Pvt Ltd
# 15                         Shyamoli Paribahan Pvt Ltd
# 16                                   Aitiana Airwings
# 17                                       Express Line
# 18                         Shyamoli Paribahan Pvt Ltd
# 19                                     Modern Travels
# 20                                Lokenath (Maa Tara)
# 21                                    Annesha Travels
# 22                                   Maulik Paribahan
# 23                              Maa Durga Bus Service
# 24                                   Shantanu Travels
# 25                               Aradhana Bus Service
# 26                                      Gopal Travels
#
#                                           bustype duparting_time duration  \
# 0                           Volvo AC Seater (2+2)          19:35  13h 00m
# 1       Volvo Multi-Axle A/C Seater/Sleeper (2+1)          18:45  12h 00m
# 2       Volvo Multi-Axle A/C seater/sleeper (2+1)          20:30  13h 00m
# 3   Volvo Multi Axle B11R AC Seater\Sleeper (2+1)          20:30  12h 00m
# 4                      A/C Seater / Sleeper (2+1)          19:30  13h 00m
# 5         Volvo 9600 Multi-Axle A/C Sleeper (2+1)          20:30  12h 55m
# 6              Volvo B11R Multi Axle Seater (2+2)          20:00  12h 30m
# 7             Volvo 9600 A/C Seater/Sleeper (2+1)          19:30  12h 30m
# 8         Volvo 9600 Multi-Axle A/C Sleeper (2+1)          19:50  12h 55m
# 9                   Bharat Benz A/C Sleeper (2+1)          19:30  12h 15m
# 10        Volvo 9600 Multi-Axle A/C Sleeper (2+1)          18:30  13h 00m
# 11        Volvo 9600 Multi-Axle A/C Sleeper (2+1)          19:00  12h 30m
# 12        Volvo 9600 Multi-Axle A/C Sleeper (2+1)          18:30  12h 55m
# 13             Volvo Multi-Axle Sleeper A/C (2+1)          18:30  13h 00m
# 14        Volvo 9600 Multi-Axle A/C Sleeper (2+1)          19:15  12h 50m
# 15        Volvo 9600 Multi-Axle A/C Sleeper (2+1)          18:00  12h 05m
# 16                         Benz A/C Sleeper (2+1)          18:00  14h 00m
# 17        Volvo 9600 Multi-Axle A/C Sleeper (2+1)          18:30  12h 40m
# 18      Volvo Multi-Axle A/C seater/sleeper (2+1)          18:30  12h 50m
# 19          Bharat Benz A/C Seater /Sleeper (2+1)          18:45  12h 50m
# 20                 NON A/C Seater / Sleeper (2+2)          15:15  14h 30m
# 21                 NON A/C Seater / Sleeper (2+2)          18:00  13h 00m
# 22                     A/C Seater / Sleeper (2+2)          18:30  11h 30m
# 23                 NON A/C Seater / Sleeper (2+2)          18:00  14h 00m
# 24                     A/C Seater / Sleeper (2+2)          19:00  14h 30m
# 25                 NON A/C Seater / Sleeper (2+2)          14:50  15h 40m
# 26                     A/C Seater / Sleeper (2+2)          20:00  12h 10m
#
#    reaching_time star_rating     Price     Seats Available  ID
# 0          08:35         3.4  INR 1210  51 Seats available   1
# 1          06:45         4.1  INR 1200  38 Seats available   2
# 2          09:30         4.1  INR 1200  26 Seats available   3
# 3          08:30         4.4  INR 1200  26 Seats available   4
# 4          08:30         4.2   INR 800  34 Seats available   5
# 5          09:25         4.8  INR 1500  15 Seats available   6
# 6          08:30         4.3  INR 1200  34 Seats available   7
# 7          08:00         4.5  INR 1199  17 Seats available   8
# 8          08:45         4.8  INR 1500  16 Seats available   9
# 9          07:45         4.5  INR 1400  20 Seats available  10
# 10         07:30         4.3  INR 1500  11 Seats available  11
# 11         07:30         4.3  INR 1500  10 Seats available  12
# 12         07:25         4.7  INR 1500  12 Seats available  13
# 13         07:30         4.4  INR 1499  12 Seats available  14
# 14         08:05         4.6  INR 1500   8 Seats available  15
# 15         06:05         4.4  INR 1500   6 Seats available  16
# 16         08:00         4.2  INR 1200   7 Seats available  17
# 17         07:10         4.4  INR 1499   9 Seats available  18
# 18         07:20         3.9  INR 1200  25 Seats available  19
# 19         07:35         3.5   INR 825  24 Seats available  20
# 20         05:45         2.6       540   9 Seats available  21
# 21         07:00         2.3   INR 500  22 Seats available  22
# 22         06:00         2.0   INR 800  50 Seats available  23
# 23         08:00         2.8   INR 600   8 Seats available  24
# 24         09:30         1.9  INR 1200  47 Seats available  25
# 25         06:30         2.7   INR 700  31 Seats available  26
# 26         08:10         2.0  INR 1100  65 Seats available  27

# %%
 # Let the page load
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('https://www.redbus.in/bus-tickets/raiganj-to-kolkata?fromCityId=74691&toCityId=74820&fromCityName=Raiganj&toCityName=Kolkata&busType=Any&srcCountry=IND&destCountry=IND&onward=22-Nov-2024')
time.sleep(2)  # Let the page load

body = driver.find_element(By.TAG_NAME, "body")
hide_details_TS=driver.find_elements(By.XPATH, "//div[@class='button']")
if hide_details_TS:
    hide_details_TS[0].click()
for i in range(40):
    buses_list_result = driver.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type_result = driver.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    departing_time_result = driver.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    reaching_time_result = driver.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    duration_list_result = driver.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")
    star_rating_result = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
    price_result = driver.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats_available_result = driver.find_elements(By.XPATH, "//div[@class='seat-left m-top-30']")
    body.send_keys(Keys.PAGE_DOWN)
buses_list=[]
bus_type_list=[]
departing_time_list=[]
reaching_time_list=[]
duration_list=[]
star_rating_list=[]
price_list=[]
seats_available_list=[]
for i in buses_list_result:
    buses_list.append(i.text)
for i in bus_type_result:
    bus_type_list.append(i.text)
for i in departing_time_result:
    departing_time_list.append(i.text)
for i in reaching_time_result:
    reaching_time_list.append(i.text)
for i in duration_list_result:
    duration_list.append(i.text)
for i in star_rating_result:
    star_rating_list.append(i.text)
for i in price_result:
    price_list.append(i.text)
for i in seats_available_result:
    seats_available_list.append(i.text)

# %%
min_value=min(len(buses_list),len(bus_type_list),len(departing_time_list),len(reaching_time_list),len(duration_list),len(star_rating_list),len(price_list),len(seats_available_list))
print(min_value)

# %%
busname=[]
bustype=[]
departing_time=[]
duration=[]
reaching_time=[]
star_rating=[]
price=[]
seats_available=[]
route_link=[]
route_name=[]
for i in range(min_value):
    busname.append(buses_list[i])
    bustype.append(bus_type_list[i])
    departing_time.append(departing_time_list[i])
    duration.append(duration_list[i])
    reaching_time.append(reaching_time_list[i])
    star_rating.append(star_rating_list[i])
    price.append(price_list[i])
    seats_available.append(seats_available_list[i])
    route_link.append("https://www.redbus.in/bus-tickets/raiganj-to-kolkata")
    route_name.append("Raiganj to Kolkata")

# %%
import pandas as pd

# Dictionary with data
data = {
    'route_name': route_name,
    'route_link': route_link,
    'busname':busname,
    'bustype':bustype,
    'duparting_time': departing_time,
    'duration':duration,
    'reaching_time': reaching_time,
    'star_rating': star_rating,
    'Price': price,
    'Seats Available': seats_available
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Add automated ID column
df['ID'] = range(1, len(df) + 1)

print(df)

# %%
 # Let the page load
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('https://www.redbus.in/bus-tickets/kolkata-to-raiganj?fromCityId=74820&toCityId=74691&fromCityName=Kolkata&toCityName=Raiganj&busType=Any&srcCountry=IND&destCountry=IND&onward=22-Nov-2024')
time.sleep(2)  # Let the page load

body = driver.find_element(By.TAG_NAME, "body")
hide_details_TS=driver.find_elements(By.XPATH, "//div[@class='button']")
if hide_details_TS:
    hide_details_TS[0].click()
for i in range(40):
    buses_list_result = driver.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type_result = driver.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    departing_time_result = driver.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    reaching_time_result = driver.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    duration_list_result = driver.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")
    star_rating_result = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
    price_result = driver.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats_available_result = driver.find_elements(By.XPATH, "//div[@class='seat-left m-top-30']")
    body.send_keys(Keys.PAGE_DOWN)
buses_list=[]
bus_type_list=[]
departing_time_list=[]
reaching_time_list=[]
duration_list=[]
star_rating_list=[]
price_list=[]
seats_available_list=[]
for i in buses_list_result:
    buses_list.append(i.text)
for i in bus_type_result:
    bus_type_list.append(i.text)
for i in departing_time_result:
    departing_time_list.append(i.text)
for i in reaching_time_result:
    reaching_time_list.append(i.text)
for i in duration_list_result:
    duration_list.append(i.text)
for i in star_rating_result:
    star_rating_list.append(i.text)
for i in price_result:
    price_list.append(i.text)
for i in seats_available_result:
    seats_available_list.append(i.text)

# %%
min_value=min(len(buses_list),len(bus_type_list),len(departing_time_list),len(reaching_time_list),len(duration_list),len(star_rating_list),len(price_list),len(seats_available_list))
print(min_value)

# %%
busname=[]
bustype=[]
departing_time=[]
duration=[]
reaching_time=[]
star_rating=[]
price=[]
seats_available=[]
route_link=[]
route_name=[]
for i in range(min_value):
    busname.append(buses_list[i])
    bustype.append(bus_type_list[i])
    departing_time.append(departing_time_list[i])
    duration.append(duration_list[i])
    reaching_time.append(reaching_time_list[i])
    star_rating.append(star_rating_list[i])
    price.append(price_list[i])
    seats_available.append(seats_available_list[i])
    route_link.append("https://www.redbus.in/bus-tickets/kolkata-to-raiganj")
    route_name.append("Kolkata to Raiganj")

# %%
import pandas as pd

# Dictionary with data
data = {
    'route_name': route_name,
    'route_link': route_link,
    'busname':busname,
    'bustype':bustype,
    'duparting_time': departing_time,
    'duration':duration,
    'reaching_time': reaching_time,
    'star_rating': star_rating,
    'Price': price,
    'Seats Available': seats_available
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Add automated ID column
df['ID'] = range(1, len(df) + 1)

print(df)

# %%
 # Let the page load
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('https://www.redbus.in/bus-tickets/malda-to-kolkata?fromCityId=74687&toCityId=74820&fromCityName=Malda&toCityName=Kolkata&busType=Any&srcCountry=IND&destCountry=IND&onward=22-Nov-2024')
time.sleep(2)  # Let the page load

body = driver.find_element(By.TAG_NAME, "body")
hide_details_TS=driver.find_elements(By.XPATH, "//div[@class='button']")
if hide_details_TS:
    hide_details_TS[0].click()
for i in range(40):
    buses_list_result = driver.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type_result = driver.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    departing_time_result = driver.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    reaching_time_result = driver.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    duration_list_result = driver.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")
    star_rating_result = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
    price_result = driver.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats_available_result = driver.find_elements(By.XPATH, "//div[@class='seat-left m-top-30']")
    body.send_keys(Keys.PAGE_DOWN)
buses_list=[]
bus_type_list=[]
departing_time_list=[]
reaching_time_list=[]
duration_list=[]
star_rating_list=[]
price_list=[]
seats_available_list=[]
for i in buses_list_result:
    buses_list.append(i.text)
for i in bus_type_result:
    bus_type_list.append(i.text)
for i in departing_time_result:
    departing_time_list.append(i.text)
for i in reaching_time_result:
    reaching_time_list.append(i.text)
for i in duration_list_result:
    duration_list.append(i.text)
for i in star_rating_result:
    star_rating_list.append(i.text)
for i in price_result:
    price_list.append(i.text)
for i in seats_available_result:
    seats_available_list.append(i.text)

# %%
min_value=min(len(buses_list),len(bus_type_list),len(departing_time_list),len(reaching_time_list),len(duration_list),len(star_rating_list),len(price_list),len(seats_available_list))
print(min_value)

# %%
busname=[]
bustype=[]
departing_time=[]
duration=[]
reaching_time=[]
star_rating=[]
price=[]
seats_available=[]
route_link=[]
route_name=[]
for i in range(min_value):
    busname.append(buses_list[i])
    bustype.append(bus_type_list[i])
    departing_time.append(departing_time_list[i])
    duration.append(duration_list[i])
    reaching_time.append(reaching_time_list[i])
    star_rating.append(star_rating_list[i])
    price.append(price_list[i])
    seats_available.append(seats_available_list[i])
    route_link.append("https://www.redbus.in/bus-tickets/malda-to-kolkata")
    route_name.append("Malda to Kolkata")

# %%
import pandas as pd

# Dictionary with data
data = {
    'route_name': route_name,
    'route_link': route_link,
    'busname':busname,
    'bustype':bustype,
    'duparting_time': departing_time,
    'duration':duration,
    'reaching_time': reaching_time,
    'star_rating': star_rating,
    'Price': price,
    'Seats Available': seats_available
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Add automated ID column
df['ID'] = range(1, len(df) + 1)

print(df)

# %%
 # Let the page load
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('https://www.redbus.in/bus-tickets/kolkata-to-malda?fromCityId=74820&toCityId=74687&fromCityName=Kolkata&toCityName=Malda&busType=Any&onward=22-Nov-2024')
time.sleep(2)  # Let the page load

body = driver.find_element(By.TAG_NAME, "body")
hide_details_TS=driver.find_elements(By.XPATH, "//div[@class='button']")
if hide_details_TS:
    hide_details_TS[0].click()
for i in range(40):
    buses_list_result = driver.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type_result = driver.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    departing_time_result = driver.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    reaching_time_result = driver.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    duration_list_result = driver.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")
    star_rating_result = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
    price_result = driver.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats_available_result = driver.find_elements(By.XPATH, "//div[@class='seat-left m-top-30']")
    body.send_keys(Keys.PAGE_DOWN)
buses_list=[]
bus_type_list=[]
departing_time_list=[]
reaching_time_list=[]
duration_list=[]
star_rating_list=[]
price_list=[]
seats_available_list=[]
for i in buses_list_result:
    buses_list.append(i.text)
for i in bus_type_result:
    bus_type_list.append(i.text)
for i in departing_time_result:
    departing_time_list.append(i.text)
for i in reaching_time_result:
    reaching_time_list.append(i.text)
for i in duration_list_result:
    duration_list.append(i.text)
for i in star_rating_result:
    star_rating_list.append(i.text)
for i in price_result:
    price_list.append(i.text)
for i in seats_available_result:
    seats_available_list.append(i.text)

# %%
min_value=min(len(buses_list),len(bus_type_list),len(departing_time_list),len(reaching_time_list),len(duration_list),len(star_rating_list),len(price_list),len(seats_available_list))
print(min_value)

# %%
busname=[]
bustype=[]
departing_time=[]
duration=[]
reaching_time=[]
star_rating=[]
price=[]
seats_available=[]
route_link=[] 
route_name=[]
for i in range(min_value):
    busname.append(buses_list[i])
    bustype.append(bus_type_list[i])
    departing_time.append(departing_time_list[i])
    duration.append(duration_list[i])
    reaching_time.append(reaching_time_list[i])
    star_rating.append(star_rating_list[i])
    price.append(price_list[i])
    seats_available.append(seats_available_list[i])
    route_link.append("https://www.redbus.in/bus-tickets/kolkata-to-malda")
    route_name.append("Kolkata to Malda")

# %%
import pandas as pd

# Dictionary with data
data = {
    'route_name': route_name,
    'route_link': route_link,
    'busname':busname,
    'bustype':bustype,
    'duparting_time': departing_time,
    'duration':duration,
    'reaching_time': reaching_time,
    'star_rating': star_rating,
    'Price': price,
    'Seats Available': seats_available
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Add automated ID column
df['ID'] = range(1, len(df) + 1)

print(df)
