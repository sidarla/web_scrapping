# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('https://www.redbus.in/online-booking/apsrtc/?utm_source=rtchometile')
time.sleep(2)  # Let the page load

body = driver.find_element(By.TAG_NAME, "body")
telangana_buses_list=[]
telangana_buses_links=[]

for page_num in range(1,5):  # Loop over pages (or scroll actions)
    # Get all elements with class 'route'
    result1 = driver.find_elements(By.CSS_SELECTOR, "a[class='route']")
    
    # Print the text of each element found
    for element in result1:
        telangana_buses_list.append(element.text)
        telangana_buses_links.append(element.get_attribute('href'))
    
    # Scroll down the page
    body.send_keys(Keys.PAGE_DOWN)
    time.sleep(2)  # Give some time for new elements to load 
    
    # Find an element matching the XPATH and click (if needed)
    result = driver.find_elements(By.XPATH, f"//div[contains(text(),'{page_num+1}')]")
    #print(result)
    if result:
        result[0].click()  # Click the first element found with matching XPATH

#driver.quit()  # Close the browser after task completion

# %%
for i in telangana_buses_links:
    print(i)
# Out:
# https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada
# https://www.redbus.in/bus-tickets/vijayawada-to-hyderabad
# https://www.redbus.in/bus-tickets/kakinada-to-visakhapatnam
# https://www.redbus.in/bus-tickets/chittoor-andhra-pradesh-to-bangalore
# https://www.redbus.in/bus-tickets/bangalore-to-tirupathi
# https://www.redbus.in/bus-tickets/tirupathi-to-bangalore
# https://www.redbus.in/bus-tickets/kadapa-to-bangalore
# https://www.redbus.in/bus-tickets/hyderabad-to-ongole
# https://www.redbus.in/bus-tickets/ananthapur-to-bangalore
# https://www.redbus.in/bus-tickets/bangalore-to-kadapa
# https://www.redbus.in/bus-tickets/ongole-to-hyderabad
# https://www.redbus.in/bus-tickets/bangalore-to-chittoor-andhra-pradesh
# https://www.redbus.in/bus-tickets/bangalore-to-ananthapur
# https://www.redbus.in/bus-tickets/visakhapatnam-to-kakinada
# https://www.redbus.in/bus-tickets/kadiri-to-bangalore
# https://www.redbus.in/bus-tickets/vinukonda-to-hyderabad
# https://www.redbus.in/bus-tickets/bangalore-to-kadiri
# https://www.redbus.in/bus-tickets/hyderabad-to-narsaraopet
# https://www.redbus.in/bus-tickets/madanapalli-to-bangalore
# https://www.redbus.in/bus-tickets/narsaraopet-to-hyderabad
# https://www.redbus.in/bus-tickets/rajahmundry-to-visakhapatnam
# https://www.redbus.in/bus-tickets/eluru-to-hyderabad
# https://www.redbus.in/bus-tickets/chennai-to-tirupathi
# https://www.redbus.in/bus-tickets/bangalore-to-madanapalli
# https://www.redbus.in/bus-tickets/guntur-to-hyderabad
# https://www.redbus.in/bus-tickets/rayachoti-to-bangalore
# https://www.redbus.in/bus-tickets/hyderabad-to-kurnool
# https://www.redbus.in/bus-tickets/tirupathi-to-chennai
# https://www.redbus.in/bus-tickets/visakhapatnam-to-vijayawada
# https://www.redbus.in/bus-tickets/rajahmundry-to-vijayawada
# https://www.redbus.in/bus-tickets/hyderabad-to-guntur
# https://www.redbus.in/bus-tickets/macherla-to-hyderabad
# https://www.redbus.in/bus-tickets/nandyala-to-hyderabad
# https://www.redbus.in/bus-tickets/hyderabad-to-eluru
# https://www.redbus.in/bus-tickets/bangalore-to-rayachoti
# https://www.redbus.in/bus-tickets/kurnool-to-hyderabad
# https://www.redbus.in/bus-tickets/hyderabad-to-vinukonda
# https://www.redbus.in/bus-tickets/vijayawada-to-visakhapatnam
# https://www.redbus.in/bus-tickets/kurnool-to-bangalore
# https://www.redbus.in/bus-tickets/rajahmundry-to-hyderabad

# %%
for i in telangana_buses_list:
    print(i)
# Out:
# Hyderabad to Vijayawada
# Vijayawada to Hyderabad
# Kakinada to Visakhapatnam
# Chittoor (Andhra Pradesh) to Bangalore
# Bangalore to Tirupati
# Tirupati to Bangalore
# Kadapa to Bangalore
# Hyderabad to Ongole
# Anantapur (andhra pradesh) to Bangalore
# Bangalore to Kadapa
# Ongole to Hyderabad
# Bangalore to Chittoor (Andhra Pradesh)
# Bangalore to Anantapur (andhra pradesh)
# Visakhapatnam to Kakinada
# Kadiri to Bangalore
# Vinukonda to Hyderabad
# Bangalore to Kadiri
# Hyderabad to Narasaraopet
# Madanapalli to Bangalore
# Narasaraopet to Hyderabad
# Rajahmundry to Visakhapatnam
# Eluru to Hyderabad
# Chennai to Tirupati
# Bangalore to Madanapalli
# Guntur (Andhra Pradesh) to Hyderabad
# Rayachoti to Bangalore
# Hyderabad to Kurnool
# Tirupati to Chennai
# Visakhapatnam to Vijayawada
# Rajahmundry to Vijayawada
# Hyderabad to Guntur (Andhra Pradesh)
# Macherla (andhra pradesh) to Hyderabad
# Nandyal to Hyderabad
# Hyderabad to Eluru
# Bangalore to Rayachoti
# Kurnool to Hyderabad
# Hyderabad to Vinukonda
# Vijayawada to Visakhapatnam
# Kurnool to Bangalore
# Rajahmundry to Hyderabad

# %%
buses_list=[]
bus_type_list=[]
departing_time_list=[]
reaching_time_list=[]
duration_list=[]
star_rating_list=[]
price_list=[]
seats_available_list=[]
route_name=[]
route_link=[]

# %%
 # Let the page load
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada?fromCityId=124&toCityId=134&fromCityName=Hyderabad&toCityName=Vijayawada&busType=Any&srcCountry=IND&destCountry=null&onward=22-Nov-2024')
time.sleep(2)  # Let the page load

body = driver.find_element(By.TAG_NAME, "body")
hide_details_TS=driver.find_elements(By.XPATH, "//div[@class='button']")
if hide_details_TS:
    hide_details_TS[0].click()
for i in range(80):
    buses_list_result = driver.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type_result = driver.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    departing_time_result = driver.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    reaching_time_result = driver.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    duration_list_result = driver.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")
    star_rating_result = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
    price_result = driver.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats_available_result = driver.find_elements(By.XPATH, "//div[@class='seat-left m-top-30']")
    body.send_keys(Keys.PAGE_DOWN)

for i in buses_list_result:
    buses_list.append(i.text)
for i in bus_type_result:
    bus_type_list.append(i.text)
for i in departing_time_result:
    departing_time_list.append(i.text)
for i in reaching_time_result:
    reaching_time_list.append(i.text)
for i in duration_list_result:
    duration_list.append(i.text)
for i in star_rating_result:
    star_rating_list.append(i.text)
for i in price_result:
    price_list.append(i.text)
for i in seats_available_result:
    seats_available_list.append(i.text)

# %%
no_of_buses=len(buses_list)
no_of_buses
# Out:
# 175

# %%
for i in range(no_of_buses):
    route_name.append("Hyderabad to Vijayawada")
    route_link.append("https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada")

# %%
len(route_name)
# Out:
# 175

# %%
 # Let the page load
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('https://www.redbus.in/bus-tickets/vijayawada-to-hyderabad?fromCityId=134&toCityId=124&fromCityName=Vijayawada&toCityName=Hyderabad&busType=Any&srcCountry=IND&destCountry=IND&onward=22-Nov-2024')
time.sleep(2)  # Let the page load

body = driver.find_element(By.TAG_NAME, "body")
hide_details_TS=driver.find_elements(By.XPATH, "//div[@class='button']")
if hide_details_TS:
    hide_details_TS[0].click()
for i in range(40):
    buses_list_result = driver.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type_result = driver.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    departing_time_result = driver.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    reaching_time_result = driver.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    duration_list_result = driver.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")
    star_rating_result = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
    price_result = driver.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats_available_result = driver.find_elements(By.XPATH, "//div[@class='seat-left m-top-30']")
    body.send_keys(Keys.PAGE_DOWN)
count=0
for i in buses_list_result:
    buses_list.append(i.text)
    count+=1
for i in bus_type_result:
    bus_type_list.append(i.text)
for i in departing_time_result:
    departing_time_list.append(i.text)
for i in reaching_time_result:
    reaching_time_list.append(i.text)
for i in duration_list_result:
    duration_list.append(i.text)
for i in star_rating_result:
    star_rating_list.append(i.text)
for i in price_result:
    price_list.append(i.text)
for i in seats_available_result:
    seats_available_list.append(i.text)

# %%
for i in range(count):
    route_name.append("Vijayawada to Hyderabad")
    route_link.append("https://www.redbus.in/bus-tickets/vijayawada-to-hyderabad")

# %%
 # Let the page load
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('https://www.redbus.in/bus-tickets/kakinada-to-visakhapatnam?fromCityId=316&toCityId=248&fromCityName=Kakinada&toCityName=Visakhapatnam&busType=Any&srcCountry=IND&destCountry=IND&onward=22-Nov-2024')
time.sleep(2)  # Let the page load

body = driver.find_element(By.TAG_NAME, "body")
hide_details_TS=driver.find_elements(By.XPATH, "//div[@class='button']")
if hide_details_TS:
    hide_details_TS[0].click()
for i in range(40):
    buses_list_result = driver.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type_result = driver.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    departing_time_result = driver.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    reaching_time_result = driver.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    duration_list_result = driver.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")
    star_rating_result = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
    price_result = driver.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats_available_result = driver.find_elements(By.XPATH, "//div[@class='seat-left m-top-30']")
    body.send_keys(Keys.PAGE_DOWN)
count=0
for i in buses_list_result:
    buses_list.append(i.text)
    count+=1
for i in bus_type_result:
    bus_type_list.append(i.text)
for i in departing_time_result:
    departing_time_list.append(i.text)
for i in reaching_time_result:
    reaching_time_list.append(i.text)
for i in duration_list_result:
    duration_list.append(i.text)
for i in star_rating_result:
    star_rating_list.append(i.text)
for i in price_result:
    price_list.append(i.text)
for i in seats_available_result:
    seats_available_list.append(i.text)

# %%
for i in range(count):
    route_name.append("Kakinada to Visakhapatnam")
    route_link.append("https://www.redbus.in/bus-tickets/Kakinada to Visakhapatnam")

# %%
 # Let the page load
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('https://www.redbus.in/bus-tickets/bangalore-to-tirupathi?fromCityId=122&toCityId=71756&fromCityName=Bangalore&toCityName=Tirupati&busType=Any&srcCountry=IND&destCountry=IND&onward=22-Nov-2024')
time.sleep(2)  # Let the page load

body = driver.find_element(By.TAG_NAME, "body")
hide_details_TS=driver.find_elements(By.XPATH, "//div[@class='button']")
if hide_details_TS:
    hide_details_TS[0].click()
for i in range(40):
    buses_list_result = driver.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type_result = driver.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    departing_time_result = driver.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    reaching_time_result = driver.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    duration_list_result = driver.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")
    star_rating_result = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
    price_result = driver.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats_available_result = driver.find_elements(By.XPATH, "//div[@class='seat-left m-top-30']")
    body.send_keys(Keys.PAGE_DOWN)

count=0
for i in buses_list_result:
    buses_list.append(i.text)
    count+=1
for i in bus_type_result:
    bus_type_list.append(i.text)
for i in departing_time_result:
    departing_time_list.append(i.text)
for i in reaching_time_result:
    reaching_time_list.append(i.text)
for i in duration_list_result:
    duration_list.append(i.text)
for i in star_rating_result:
    star_rating_list.append(i.text)
for i in price_result:
    price_list.append(i.text)
for i in seats_available_result:
    seats_available_list.append(i.text)

# %%
for i in range(count):
    route_name.append("Bangalore to Tirupati")
    route_link.append("https://www.redbus.in/bus-tickets/bangalore-to-tirupati")

# %%
 # Let the page load
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('https://www.redbus.in/bus-tickets/tirupathi-to-bangalore?fromCityId=71756&toCityId=122&fromCityName=Tirupati&toCityName=Bangalore&busType=Any&srcCountry=IND&destCountry=IND&onward=22-Nov-2024')
time.sleep(2)  # Let the page load

body = driver.find_element(By.TAG_NAME, "body")
hide_details_TS=driver.find_elements(By.XPATH, "//div[@class='button']")
if hide_details_TS:
    hide_details_TS[0].click()
for i in range(40):
    buses_list_result = driver.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type_result = driver.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    departing_time_result = driver.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    reaching_time_result = driver.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    duration_list_result = driver.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")
    star_rating_result = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
    price_result = driver.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats_available_result = driver.find_elements(By.XPATH, "//div[@class='seat-left m-top-30']")
    body.send_keys(Keys.PAGE_DOWN)
count=0
for i in buses_list_result:
    buses_list.append(i.text)
    count+=1
for i in bus_type_result:
    bus_type_list.append(i.text)
for i in departing_time_result:
    departing_time_list.append(i.text)
for i in reaching_time_result:
    reaching_time_list.append(i.text)
for i in duration_list_result:
    duration_list.append(i.text)
for i in star_rating_result:
    star_rating_list.append(i.text)
for i in price_result:
    price_list.append(i.text)
for i in seats_available_result:
    seats_available_list.append(i.text)

# %%
for i in range(count):
    route_name.append("Tirupati to Bangalore")
    route_link.append("https://www.redbus.in/bus-tickets/tirupati-to-bangalore")

# %%
 # Let the page load
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('https://www.redbus.in/bus-tickets/hyderabad-to-ongole?fromCityId=124&toCityId=135&fromCityName=Hyderabad&toCityName=Ongole&busType=Any&srcCountry=IND&destCountry=IND&onward=22-Nov-2024')
time.sleep(2)  # Let the page load

body = driver.find_element(By.TAG_NAME, "body")
hide_details_TS=driver.find_elements(By.XPATH, "//div[@class='button']")
if hide_details_TS:
    hide_details_TS[0].click()
for i in range(40):
    buses_list_result = driver.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type_result = driver.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    departing_time_result = driver.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    reaching_time_result = driver.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    duration_list_result = driver.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")
    star_rating_result = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
    price_result = driver.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats_available_result = driver.find_elements(By.XPATH, "//div[@class='seat-left m-top-30']")
    body.send_keys(Keys.PAGE_DOWN)
count=0
for i in buses_list_result:
    buses_list.append(i.text)
    count+=1
for i in bus_type_result:
    bus_type_list.append(i.text)
for i in departing_time_result:
    departing_time_list.append(i.text)
for i in reaching_time_result:
    reaching_time_list.append(i.text)
for i in duration_list_result:
    duration_list.append(i.text)
for i in star_rating_result:
    star_rating_list.append(i.text)
for i in price_result:
    price_list.append(i.text)
for i in seats_available_result:
    seats_available_list.append(i.text)

# %%
for i in range(count):
    route_name.append("Hyderabad to Ongole")
    route_link.append("https://www.redbus.in/bus-tickets/Hyderabad to Ongole")

# %%
 # Let the page load
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('https://www.redbus.in/bus-tickets/bangalore-to-kadapa?fromCityId=122&toCityId=284&fromCityName=Bangalore&toCityName=Kadapa&busType=Any&srcCountry=IND&destCountry=IND&onward=22-Nov-2024')
time.sleep(2)  # Let the page load

body = driver.find_element(By.TAG_NAME, "body")
hide_details_TS=driver.find_elements(By.XPATH, "//div[@class='button']")
if hide_details_TS:
    hide_details_TS[0].click()
for i in range(40):
    buses_list_result = driver.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type_result = driver.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    departing_time_result = driver.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    reaching_time_result = driver.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    duration_list_result = driver.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")
    star_rating_result = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
    price_result = driver.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats_available_result = driver.find_elements(By.XPATH, "//div[@class='seat-left m-top-30']")
    body.send_keys(Keys.PAGE_DOWN)
count=0
for i in buses_list_result:
    buses_list.append(i.text)
    count+=1
for i in bus_type_result:
    bus_type_list.append(i.text)
for i in departing_time_result:
    departing_time_list.append(i.text)
for i in reaching_time_result:
    reaching_time_list.append(i.text)
for i in duration_list_result:
    duration_list.append(i.text)
for i in star_rating_result:
    star_rating_list.append(i.text)
for i in price_result:
    price_list.append(i.text)
for i in seats_available_result:
    seats_available_list.append(i.text)

# %%
for i in range(count):
    route_name.append("Bangalore to Kadapa")
    route_link.append("https://www.redbus.in/bus-tickets/Bangalore-to-Kadapa")

# %%
 # Let the page load
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome()  # Optional argument, if not specified will search path.
driver.get('https://www.redbus.in/bus-tickets/hyderabad-to-narsaraopet?fromCityId=124&toCityId=729&fromCityName=Hyderabad&toCityName=Narasaraopet&busType=Any&srcCountry=IND&destCountry=IND&onward=22-Nov-2024')
time.sleep(2)  # Let the page load

body = driver.find_element(By.TAG_NAME, "body")
hide_details_TS=driver.find_elements(By.XPATH, "//div[@class='button']")
if hide_details_TS:
    hide_details_TS[0].click()
for i in range(40):
    buses_list_result = driver.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
    bus_type_result = driver.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
    departing_time_result = driver.find_elements(By.XPATH, "//div[@class='dp-time f-19 d-color f-bold']")
    reaching_time_result = driver.find_elements(By.XPATH, "//div[@class='bp-time f-19 d-color disp-Inline']")
    duration_list_result = driver.find_elements(By.XPATH, "//div[@class='dur l-color lh-24']")
    star_rating_result = driver.find_elements(By.XPATH, "//div[@class='rating-sec lh-24']")
    price_result = driver.find_elements(By.XPATH, "//div[@class='fare d-block']")
    seats_available_result = driver.find_elements(By.XPATH, "//div[@class='seat-left m-top-30']")
    body.send_keys(Keys.PAGE_DOWN)
count=0
for i in buses_list_result:
    buses_list.append(i.text)
    count+=1
for i in bus_type_result:
    bus_type_list.append(i.text)
for i in departing_time_result:
    departing_time_list.append(i.text)
for i in reaching_time_result:
    reaching_time_list.append(i.text)
for i in duration_list_result:
    duration_list.append(i.text)
for i in star_rating_result:
    star_rating_list.append(i.text)
for i in price_result:
    price_list.append(i.text)
for i in seats_available_result:
    seats_available_list.append(i.text)

# %%
for i in range(count):
    route_name.append("Hyderabad to Narasaraopet")
    route_link.append("https://www.redbus.in/bus-tickets/hyderabad-to-narasaraopet")

# %%
min_value=min(len(buses_list),len(bus_type_list),len(departing_time_list),len(reaching_time_list),len(duration_list),len(star_rating_list),len(price_list),len(seats_available_list),len(route_name),len(route_link))
print(min_value)
# Out:
# 536

# %%
busname=[]
bustype=[]
departing_time=[]
duration=[]
reaching_time=[]
star_rating=[]
price=[]
seats_available=[]
route_link1=[]
route_name1=[]
for i in range(1,min_value):
    busname.append(buses_list[i])
    bustype.append(bus_type_list[i])
    departing_time.append(departing_time_list[i])
    duration.append(duration_list[i])
    reaching_time.append(reaching_time_list[i])
    star_rating.append(star_rating_list[i])
    price.append(price_list[i])
    seats_available.append(seats_available_list[i])
    route_link1.append(route_link[i])
    route_name1.append(route_name[i])

# %%
import pandas as pd

# Dictionary with data
data = {
    'route_name': route_name1,
    'route_link': route_link1,
    'busname':busname,
    'bustype':bustype,
    'duparting_time': departing_time,
    'duration':duration,
    'reaching_time': reaching_time,
    'star_rating': star_rating,
    'Price': price,
    'Seats Available': seats_available
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Add automated ID column
df['ID'] = range(1, len(df) + 1)

print(df)
# Out:
#                   route_name  \
# 0    Hyderabad to Vijayawada
# 1    Hyderabad to Vijayawada
# 2    Hyderabad to Vijayawada
# 3    Hyderabad to Vijayawada
# 4    Hyderabad to Vijayawada
# ..                       ...
# 530    Tirupati to Bangalore
# 531    Tirupati to Bangalore
# 532    Tirupati to Bangalore
# 533    Tirupati to Bangalore
# 534    Tirupati to Bangalore
#
#                                             route_link             busname  \
# 0    https://www.redbus.in/bus-tickets/hyderabad-to...            FRESHBUS
# 1    https://www.redbus.in/bus-tickets/hyderabad-to...            FRESHBUS
# 2    https://www.redbus.in/bus-tickets/hyderabad-to...          AdYolo Bus
# 3    https://www.redbus.in/bus-tickets/hyderabad-to...            FRESHBUS
# 4    https://www.redbus.in/bus-tickets/hyderabad-to...            FRESHBUS
# ..                                                 ...                 ...
# 530  https://www.redbus.in/bus-tickets/tirupati-to-...      CHOPPA TRAVELS
# 531  https://www.redbus.in/bus-tickets/tirupati-to-...          RK Travels
# 532  https://www.redbus.in/bus-tickets/tirupati-to-...  Sai Sindhu Travels
# 533  https://www.redbus.in/bus-tickets/tirupati-to-...      CHOPPA TRAVELS
# 534  https://www.redbus.in/bus-tickets/tirupati-to-...   Rajeswari Travels
#
#                             bustype duparting_time duration reaching_time  \
# 0         Electric A/C Seater (2+2)          10:25  07h 30m         17:55
# 1         Electric A/C Seater (2+2)          11:20  07h 30m         18:50
# 2     Bharat Benz A/C Sleeper (2+1)          19:40  06h 49m         02:29
# 3         Electric A/C Seater (2+2)          23:05  07h 10m         06:15
# 4         Electric A/C Seater (2+2)          22:10  07h 30m         05:40
# ..                              ...            ...      ...           ...
# 530           NON A/C Sleeper (2+1)          23:30  05h 30m         05:00
# 531      A/C Seater / Sleeper (2+1)          23:30  06h 10m         05:40
# 532           NON A/C Sleeper (2+1)          23:30  05h 30m         05:00
# 533  Non A/C Seater / Sleeper (2+1)          23:30  05h 45m         05:15
# 534               A/C Sleeper (2+1)          23:44  06h 01m         05:45
#
#     star_rating     Price     Seats Available   ID
# 0           4.7       500  37 Seats available    1
# 1           4.7       500  30 Seats available    2
# 2           4.6  INR 1000  40 Seats available    3
# 3           4.6       348  38 Seats available    4
# 4           4.6       500  43 Seats available    5
# ..          ...       ...                 ...  ...
# 530         3.4   INR 799  40 Seats available  531
# 531         4.6   INR 499  36 Seats available  532
# 532         3.1   INR 590  18 Seats available  533
# 533         3.5   INR 499  21 Seats available  534
# 534         3.2   INR 650  40 Seats available  535
#
# [535 rows x 11 columns]

# %%
df.to_csv(r'C:/Users/Dell/OneDrive/Desktop/streamlit/Andhra_buses.csv', index=False)
